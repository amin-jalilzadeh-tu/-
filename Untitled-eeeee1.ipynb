# %%
import os
import re
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from calendar import month_name

def merge_all_results(
    base_output_dir,
    output_csv,
    convert_to_daily=False,
    daily_aggregator="mean",
    convert_to_monthly=False,
    monthly_aggregator="mean",
    postproc_log=None
):
    """
    Merges multiple simulation CSV files into one wide CSV.

    Modified to:
      - NOT skip _Meter.csv or _sz.csv files
      - Loosen the filename regex so that filenames like "simulation_bldg2Meter.csv"
        are included and we correctly parse building_id = 2.
      - Default to "merge as is" (convert_to_daily=False, convert_to_monthly=False).
    """

    if postproc_log is not None:
        postproc_log["base_output_dir"] = base_output_dir
        postproc_log["output_csv"] = output_csv
        postproc_log["convert_to_daily"] = convert_to_daily
        postproc_log["daily_aggregator"] = daily_aggregator
        postproc_log["convert_to_monthly"] = convert_to_monthly
        postproc_log["monthly_aggregator"] = monthly_aggregator

    data_dict = {}
    all_times = set()
    time_to_dt = {}  # Mapping from time_str to parsed_dt

    aggregator_funcs = {
        "sum": np.sum,
        "mean": np.mean,
        "max": np.max,
        "min": np.min,
        "pick_first_hour": lambda x: x.iloc[0] if not x.empty else np.nan
    }

    if convert_to_daily and daily_aggregator not in aggregator_funcs:
        print(f"Warning: Aggregator '{daily_aggregator}' not recognized. Defaulting to 'mean'.")
        daily_aggregator = "mean"

    if convert_to_monthly and monthly_aggregator not in aggregator_funcs:
        print(f"Warning: Aggregator '{monthly_aggregator}' not recognized. Defaulting to 'mean'.")
        monthly_aggregator = "mean"

    def aggregate_series(s, how):
        return aggregator_funcs.get(how, np.mean)(s)

    month_to_num = {month: index for index, month in enumerate(month_name) if month}

    ###########################################################################
    # 1) Traverse the directory and read each CSV (no skipping of _Meter.csv)
    ###########################################################################
    for root, dirs, files in os.walk(base_output_dir):
        for f in files:
            # Only process CSV files
            if not f.lower().endswith(".csv"):
                continue

            # Loosen the filename pattern to capture something like "simulation_bldg2Meter.csv":
            #   e.g., "simulation_bldg(\d+).*\.csv"
            # which means "simulation_bldg" + one or more digits + optional anything + ".csv"
            match = re.search(r'_bldg(\d+).*\.csv$', f, re.IGNORECASE)
            if not match:
                # If you have files that do not follow the naming with "_bldg<number>",
                # you can decide what building_id should be, or skip them.
                print(f"Skipping file (no building ID match): {f}")
                continue

            bldg_id = int(match.group(1))

            file_path = os.path.join(root, f)
            print(f"[merge_all_results] Reading {file_path}, Building {bldg_id}")

            # 2) Read CSV into a DataFrame
            try:
                df = pd.read_csv(file_path, header=0, low_memory=False)
            except Exception as e:
                print(f"Error reading {file_path}: {e}")
                continue

            if "Date/Time" not in df.columns:
                print(f"Warning: No 'Date/Time' column in {file_path}, skipping.")
                continue

            ###########################################################################
            # 3) Correct '24:00:00' => '00:00:00' next day
            ###########################################################################
            def correct_time(x):
                """
                Handle '24:00:00' by converting it to '00:00:00' of the next day.
                """
                x = str(x).strip()
                if '24:00:00' in x:
                    parts = x.split()
                    if len(parts) >= 1:
                        date_part = parts[0]
                        try:
                            if date_part in month_to_num:
                                # e.g. if it was "January 24:00:00" – next month start
                                month_num = month_to_num[date_part]
                                if month_num == 12:
                                    corrected_date = datetime(2022, 1, 1)
                                else:
                                    corrected_date = datetime(2022, month_num + 1, 1)
                                return corrected_date.strftime("%m/%d 00:00:00")
                            else:
                                # Assume MM/DD format
                                date_obj = datetime.strptime(date_part, "%m/%d")
                                corrected_date = date_obj + timedelta(days=1)
                                return corrected_date.strftime("%m/%d 00:00:00")
                        except ValueError:
                            print(f"Warning: Unable to parse date part '{date_part}' in '{x}'.")
                            return x
                return x

            df["Date/Time_corrected"] = df["Date/Time"].astype(str).apply(correct_time)

            ###########################################################################
            # 4) Parse the corrected date/time into a datetime
            ###########################################################################
            def parse_dt(x):
                """
                Attempts to parse strings like:
                  - "01/21 00:10:00"
                  - "MonthName" (Monthly data)
                  - "01/21 4"
                  - etc.
                """
                x = x.strip()
                parts = x.split()
                if len(parts) == 1:
                    # Could be a month name or a single hour
                    single_part = parts[0]
                    if single_part in month_to_num:
                        return datetime(2022, month_to_num[single_part], 1)
                    try:
                        hr = int(single_part)
                        if 0 <= hr <= 23:
                            return datetime(2022, 1, 1, hr, 0, 0)
                        else:
                            return pd.NaT
                    except:
                        return pd.NaT
                elif len(parts) == 2:
                    # Typically "MM/DD HH:MM:SS" or "MM/DD HH"
                    date_part, time_part = parts
                    # If date_part is a month name => skip
                    if date_part in month_to_num:
                        return pd.NaT
                    # parse date
                    try:
                        date_obj = datetime.strptime(date_part, "%m/%d")
                    except ValueError:
                        return pd.NaT

                    # parse time
                    if ":" in time_part:
                        for fmt in ["%H:%M:%S", "%H:%M"]:
                            try:
                                t_obj = datetime.strptime(time_part, fmt)
                                dt_combined = datetime(
                                    2022, date_obj.month, date_obj.day,
                                    t_obj.hour, t_obj.minute, t_obj.second
                                )
                                return dt_combined
                            except ValueError:
                                pass
                        return pd.NaT
                    else:
                        # If there's no colon, interpret as hour
                        try:
                            hr = int(time_part)
                            if 0 <= hr <= 23:
                                return datetime(2022, date_obj.month, date_obj.day, hr, 0, 0)
                            else:
                                return pd.NaT
                        except:
                            return pd.NaT
                else:
                    return pd.NaT

            df["parsed_dt"] = df["Date/Time_corrected"].apply(parse_dt)

            ###########################################################################
            # 5) Process each numeric column
            ###########################################################################
            for col in df.columns:
                if col in ["Date/Time", "Date/Time_corrected", "parsed_dt"]:
                    continue

                # Identify frequency from the column name
                freq_mode = "Unknown"
                if "(Hourly)" in col or "(TimeStep)" in col:
                    freq_mode = "Hourly"
                elif "(Daily)" in col:
                    freq_mode = "Daily"
                elif "(Monthly)" in col:
                    freq_mode = "Monthly"

                key = (bldg_id, col)

                ########################################################################
                # 6) If converting to daily/monthly, do the aggregations
                ########################################################################
                if convert_to_daily or convert_to_monthly:
                    subdf = pd.DataFrame({
                        "dt": df["parsed_dt"],
                        "val": pd.to_numeric(df[col], errors='coerce')
                    })

                    if freq_mode == "Hourly":
                        # Convert Hourly (or TimeStep) to daily if requested
                        if convert_to_daily:
                            subdf.dropna(subset=["dt", "val"], inplace=True)
                            subdf["day_str"] = subdf["dt"].dt.strftime("%m/%d")
                            grouped = subdf.groupby("day_str")["val"]
                            day_vals = grouped.apply(lambda x: aggregate_series(x, daily_aggregator))
                            for day_s, v in day_vals.items():
                                if key not in data_dict:
                                    data_dict[key] = {}
                                data_dict[key][day_s] = v

                    elif freq_mode == "Daily":
                        # Convert daily to monthly if requested
                        if convert_to_monthly:
                            subdf.dropna(subset=["dt", "val"], inplace=True)
                            subdf["month_str"] = subdf["dt"].dt.strftime("%B")
                            grouped = subdf.groupby("month_str")["val"]
                            month_vals = grouped.apply(lambda x: aggregate_series(x, monthly_aggregator))
                            for month_s, v in month_vals.items():
                                if key not in data_dict:
                                    data_dict[key] = {}
                                data_dict[key][month_s] = v
                        else:
                            # Keep daily as is
                            subdf.dropna(subset=["val"], inplace=True)
                            for i, row in subdf.iterrows():
                                dt_val = row["dt"]
                                val = row["val"]
                                if pd.isna(dt_val):
                                    day_s = f"Day_{i}"
                                else:
                                    day_s = dt_val.strftime("%m/%d")
                                if key not in data_dict:
                                    data_dict[key] = {}
                                data_dict[key][day_s] = val

                    elif freq_mode == "Monthly":
                        # Keep monthly as is or reconvert if needed
                        subdf.dropna(subset=["val"], inplace=True)
                        for i, row in subdf.iterrows():
                            dt_val = row["dt"]
                            val = row["val"]
                            if pd.isna(dt_val):
                                month_s = f"Month_{i}"
                            else:
                                month_s = dt_val.strftime("%B")
                            if key not in data_dict:
                                data_dict[key] = {}
                            data_dict[key][month_s] = val
                    else:
                        # Unknown frequency
                        print(f"Warning: Unknown frequency for column '{col}' in Building {bldg_id}. Skipping.")
                        continue

                ########################################################################
                # 7) If not converting => keep as-is (time_str keys)
                ########################################################################
                else:
                    subdf = pd.DataFrame({
                        "time_str": df["Date/Time_corrected"].astype(str).apply(lambda x: x.strip()),
                        "val": pd.to_numeric(df[col], errors='coerce'),
                        "parsed_dt": df["parsed_dt"]
                    })
                    subdf.dropna(subset=["val"], inplace=True)

                    for i, row in subdf.iterrows():
                        tstr = row["time_str"]
                        val = row["val"]
                        parsed_dt = row["parsed_dt"]
                        if key not in data_dict:
                            data_dict[key] = {}
                        data_dict[key][tstr] = val
                        all_times.add(tstr)
                        if tstr not in time_to_dt:
                            time_to_dt[tstr] = parsed_dt

    ###########################################################################
    # 8) Figure out the sorted "time" axis depending on daily/monthly flags
    ###########################################################################
    if convert_to_monthly and convert_to_daily:
        # Rare case: Hourly -> Daily -> Monthly
        # This would yield a mixture of day_str and month_str if not carefully handled.
        # For simplicity, let’s just gather them all.
        day_strings = set()
        month_strings = set()
        for submap in data_dict.values():
            for key_str in submap.keys():
                if re.match(r'\d{2}/\d{2}', key_str):
                    day_strings.add(key_str)
                elif key_str in month_to_num:
                    month_strings.add(key_str)

        try:
            sorted_days = sorted(list(day_strings), key=lambda x: datetime.strptime(x, "%m/%d"))
        except ValueError:
            sorted_days = sorted(list(day_strings))
        try:
            sorted_months = sorted(list(month_strings), key=lambda x: month_to_num.get(x, 0))
        except ValueError:
            sorted_months = sorted(list(month_strings))

        sorted_times = sorted_months + sorted_days
        columns = ["BuildingID", "VariableName"] + sorted_times

    elif convert_to_monthly:
        # Only monthly
        month_strings = set()
        for submap in data_dict.values():
            for key_str in submap.keys():
                if key_str in month_to_num:
                    month_strings.add(key_str)
        try:
            sorted_times = sorted(list(month_strings), key=lambda x: month_to_num.get(x, 0))
        except ValueError:
            sorted_times = sorted(list(month_strings))
        columns = ["BuildingID", "VariableName"] + sorted_times

    elif convert_to_daily:
        # Only daily
        day_strings = set()
        for submap in data_dict.values():
            for key_str in submap.keys():
                day_strings.add(key_str)
        try:
            sorted_times = sorted(list(day_strings), key=lambda x: datetime.strptime(x, "%m/%d"))
        except ValueError:
            sorted_times = sorted(list(day_strings))
        columns = ["BuildingID", "VariableName"] + sorted_times

    else:
        # As-is (Hourly or TimeStep data)
        def safe_dt(tstr):
            dtval = time_to_dt.get(tstr)
            return dtval if pd.notna(dtval) else datetime.min

        try:
            sorted_times = sorted(list(all_times), key=lambda x: safe_dt(x))
        except Exception as e:
            print(f"Error in sorting times: {e}")
            sorted_times = sorted(list(all_times))

        columns = ["BuildingID", "VariableName"] + sorted_times

    ###########################################################################
    # 9) Build final DataFrame and write to CSV
    ###########################################################################
    rows = []
    for (bldg_id, var_name), tmap in data_dict.items():
        rowdata = [bldg_id, var_name]
        for t in sorted_times:
            rowdata.append(tmap.get(t, np.nan))
        rows.append(rowdata)

    final_df = pd.DataFrame(rows, columns=columns)
    final_df.sort_values(by=["BuildingID", "VariableName"], inplace=True)

    try:
        final_df.to_csv(output_csv, index=False)
        print(f"[merge_all_results] Successfully wrote merged CSV to {output_csv}")
    except Exception as e:
        print(f"Error writing to {output_csv}: {e}")

# %%
base_dir = r"D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020"
output_csv = r"D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\merged_as_is.csv"

merge_all_results(
    base_output_dir=base_dir,
    output_csv=output_csv,
    convert_to_daily=False,    # "as is"
    convert_to_monthly=False,  # "as is"
    daily_aggregator="mean",
    monthly_aggregator="mean"
)
# Out:
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg0.csv, Building 0
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg0Meter.csv, Building 0
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg0Zsz.csv, Building 0
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg0Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg1.csv, Building 1
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg10.csv, Building 10
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg100.csv, Building 100
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg100Meter.csv, Building 100
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg100Zsz.csv, Building 100
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg100Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg101.csv, Building 101
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg101Meter.csv, Building 101
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg101Zsz.csv, Building 101
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg101Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg102.csv, Building 102
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg102Meter.csv, Building 102
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg102Zsz.csv, Building 102
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg102Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg103.csv, Building 103
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg103Meter.csv, Building 103
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg103Zsz.csv, Building 103
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg103Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg104.csv, Building 104
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg104Meter.csv, Building 104
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg104Zsz.csv, Building 104
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg104Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg105.csv, Building 105
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg105Meter.csv, Building 105
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg105Zsz.csv, Building 105
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg105Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg106.csv, Building 106
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg106Meter.csv, Building 106
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg106Zsz.csv, Building 106
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg106Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg107.csv, Building 107
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg107Meter.csv, Building 107
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg107Zsz.csv, Building 107
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg107Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg108.csv, Building 108
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg108Meter.csv, Building 108
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg108Zsz.csv, Building 108
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg108Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg109.csv, Building 109
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg109Meter.csv, Building 109
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg109Zsz.csv, Building 109
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg109Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg10Meter.csv, Building 10
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg10Zsz.csv, Building 10
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg10Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg11.csv, Building 11
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg110.csv, Building 110
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg110Meter.csv, Building 110
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg110Zsz.csv, Building 110
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg110Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg111.csv, Building 111
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg111Meter.csv, Building 111
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg111Zsz.csv, Building 111
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg111Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg112.csv, Building 112
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg112Meter.csv, Building 112
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg112Zsz.csv, Building 112
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg112Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg113.csv, Building 113
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg113Meter.csv, Building 113
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg113Zsz.csv, Building 113
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg113Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg114.csv, Building 114
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg114Meter.csv, Building 114
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg114Zsz.csv, Building 114
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg114Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg115.csv, Building 115
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg115Meter.csv, Building 115
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg115Zsz.csv, Building 115
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg115Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg116.csv, Building 116
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg116Meter.csv, Building 116
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg116Zsz.csv, Building 116
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg116Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg117.csv, Building 117
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg117Meter.csv, Building 117
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg117Zsz.csv, Building 117
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg117Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg118.csv, Building 118
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg118Meter.csv, Building 118
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg118Zsz.csv, Building 118
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg118Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg119.csv, Building 119
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg119Meter.csv, Building 119
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg119Zsz.csv, Building 119
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg119Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg11Meter.csv, Building 11
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg11Zsz.csv, Building 11
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg11Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg12.csv, Building 12
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg120.csv, Building 120
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg120Meter.csv, Building 120
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg120Zsz.csv, Building 120
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg120Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg121.csv, Building 121
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg121Meter.csv, Building 121
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg121Zsz.csv, Building 121
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg121Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg122.csv, Building 122
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg122Meter.csv, Building 122
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg122Zsz.csv, Building 122
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg122Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg123.csv, Building 123
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg123Meter.csv, Building 123
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg123Zsz.csv, Building 123
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg123Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg124.csv, Building 124
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg124Meter.csv, Building 124
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg124Zsz.csv, Building 124
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg124Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg125.csv, Building 125
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg125Meter.csv, Building 125
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg125Zsz.csv, Building 125
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg125Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg126.csv, Building 126
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg126Meter.csv, Building 126
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg126Zsz.csv, Building 126
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg126Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg127.csv, Building 127
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg127Meter.csv, Building 127
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg127Zsz.csv, Building 127
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg127Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg128.csv, Building 128
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg128Meter.csv, Building 128
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg128Zsz.csv, Building 128
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg128Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg129.csv, Building 129
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg129Meter.csv, Building 129
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg129Zsz.csv, Building 129
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg129Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg12Meter.csv, Building 12
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg12Zsz.csv, Building 12
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg12Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg13.csv, Building 13
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg130.csv, Building 130
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg130Meter.csv, Building 130
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg130Zsz.csv, Building 130
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg130Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg131.csv, Building 131
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg131Meter.csv, Building 131
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg131Zsz.csv, Building 131
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg131Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg132.csv, Building 132
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg132Meter.csv, Building 132
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg132Zsz.csv, Building 132
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg132Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg133.csv, Building 133
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg133Meter.csv, Building 133
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg133Zsz.csv, Building 133
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg133Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg134.csv, Building 134
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg134Meter.csv, Building 134
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg134Zsz.csv, Building 134
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg134Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg135.csv, Building 135
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg135Meter.csv, Building 135
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg135Zsz.csv, Building 135
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg135Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg136.csv, Building 136
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg136Meter.csv, Building 136
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg136Zsz.csv, Building 136
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg136Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg137.csv, Building 137
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg137Meter.csv, Building 137
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg137Zsz.csv, Building 137
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg137Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg138.csv, Building 138
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg138Meter.csv, Building 138
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg138Zsz.csv, Building 138
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg138Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg139.csv, Building 139
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg139Meter.csv, Building 139
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg139Zsz.csv, Building 139
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg139Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg13Meter.csv, Building 13
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg13Zsz.csv, Building 13
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg13Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg14.csv, Building 14
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg140.csv, Building 140
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg140Meter.csv, Building 140
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg140Zsz.csv, Building 140
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg140Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg141.csv, Building 141
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg141Meter.csv, Building 141
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg141Zsz.csv, Building 141
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg141Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg142.csv, Building 142
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg142Meter.csv, Building 142
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg142Zsz.csv, Building 142
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg142Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg143.csv, Building 143
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg143Meter.csv, Building 143
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg143Zsz.csv, Building 143
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg143Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg144.csv, Building 144
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg144Meter.csv, Building 144
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg144Zsz.csv, Building 144
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg144Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg145.csv, Building 145
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg145Meter.csv, Building 145
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg145Zsz.csv, Building 145
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg145Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg146.csv, Building 146
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg146Meter.csv, Building 146
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg146Zsz.csv, Building 146
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg146Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg147.csv, Building 147
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg147Meter.csv, Building 147
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg147Zsz.csv, Building 147
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg147Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg148.csv, Building 148
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg148Meter.csv, Building 148
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg148Zsz.csv, Building 148
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg148Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg149.csv, Building 149
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg149Meter.csv, Building 149
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg149Zsz.csv, Building 149
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg149Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg14Meter.csv, Building 14
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg14Zsz.csv, Building 14
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg14Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg15.csv, Building 15
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg150.csv, Building 150
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg150Meter.csv, Building 150
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg150Zsz.csv, Building 150
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg150Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg151.csv, Building 151
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg151Meter.csv, Building 151
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg151Zsz.csv, Building 151
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg151Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg152.csv, Building 152
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg152Meter.csv, Building 152
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg152Zsz.csv, Building 152
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg152Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg153.csv, Building 153
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg153Meter.csv, Building 153
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg153Zsz.csv, Building 153
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg153Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg154.csv, Building 154
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg154Meter.csv, Building 154
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg154Zsz.csv, Building 154
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg154Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg155.csv, Building 155
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg155Meter.csv, Building 155
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg155Zsz.csv, Building 155
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg155Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg156.csv, Building 156
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg156Meter.csv, Building 156
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg156Zsz.csv, Building 156
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg156Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg157.csv, Building 157
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg157Meter.csv, Building 157
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg157Zsz.csv, Building 157
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg157Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg158.csv, Building 158
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg158Meter.csv, Building 158
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg158Zsz.csv, Building 158
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg158Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg159.csv, Building 159
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg159Meter.csv, Building 159
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg159Zsz.csv, Building 159
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg159Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg15Meter.csv, Building 15
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg15Zsz.csv, Building 15
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg15Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg16.csv, Building 16
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg160.csv, Building 160
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg160Meter.csv, Building 160
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg160Zsz.csv, Building 160
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg160Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg161.csv, Building 161
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg161Meter.csv, Building 161
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg161Zsz.csv, Building 161
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg161Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg162.csv, Building 162
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg162Meter.csv, Building 162
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg162Zsz.csv, Building 162
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg162Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg163.csv, Building 163
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg163Meter.csv, Building 163
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg163Zsz.csv, Building 163
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg163Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg164.csv, Building 164
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg164Meter.csv, Building 164
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg164Zsz.csv, Building 164
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg164Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg165.csv, Building 165
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg165Meter.csv, Building 165
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg165Zsz.csv, Building 165
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg165Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg166.csv, Building 166
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg166Meter.csv, Building 166
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg166Zsz.csv, Building 166
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg166Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg167.csv, Building 167
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg167Meter.csv, Building 167
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg167Zsz.csv, Building 167
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg167Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg168.csv, Building 168
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg168Meter.csv, Building 168
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg168Zsz.csv, Building 168
# ...
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg77Zsz.csv, Building 77
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg77Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg78.csv, Building 78
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg78Meter.csv, Building 78
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg78Zsz.csv, Building 78
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg78Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg79.csv, Building 79
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg79Meter.csv, Building 79
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg79Zsz.csv, Building 79
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg79Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg7Meter.csv, Building 7
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg7Zsz.csv, Building 7
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg7Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg8.csv, Building 8
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg80.csv, Building 80
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg80Meter.csv, Building 80
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg80Zsz.csv, Building 80
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg80Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg81.csv, Building 81
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg81Meter.csv, Building 81
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg81Zsz.csv, Building 81
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg81Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg82.csv, Building 82
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg82Meter.csv, Building 82
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg82Zsz.csv, Building 82
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg82Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg83.csv, Building 83
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg83Meter.csv, Building 83
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg83Zsz.csv, Building 83
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg83Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg84.csv, Building 84
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg84Meter.csv, Building 84
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg84Zsz.csv, Building 84
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg84Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg85.csv, Building 85
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg85Meter.csv, Building 85
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg85Zsz.csv, Building 85
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg85Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg86.csv, Building 86
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg86Meter.csv, Building 86
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg86Zsz.csv, Building 86
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg86Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg87.csv, Building 87
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg87Meter.csv, Building 87
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg87Zsz.csv, Building 87
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg87Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg88.csv, Building 88
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg88Meter.csv, Building 88
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg88Zsz.csv, Building 88
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg88Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg89.csv, Building 89
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg89Meter.csv, Building 89
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg89Zsz.csv, Building 89
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg89Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg8Meter.csv, Building 8
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg8Zsz.csv, Building 8
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg8Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg9.csv, Building 9
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg90.csv, Building 90
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg90Meter.csv, Building 90
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg90Zsz.csv, Building 90
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg90Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg91.csv, Building 91
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg91Meter.csv, Building 91
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg91Zsz.csv, Building 91
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg91Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg92.csv, Building 92
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg92Meter.csv, Building 92
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg92Zsz.csv, Building 92
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg92Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg93.csv, Building 93
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg93Meter.csv, Building 93
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg93Zsz.csv, Building 93
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg93Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg94.csv, Building 94
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg94Meter.csv, Building 94
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg94Zsz.csv, Building 94
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg94Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg95.csv, Building 95
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg95Meter.csv, Building 95
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg95Zsz.csv, Building 95
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg95Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg96.csv, Building 96
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg96Meter.csv, Building 96
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg96Zsz.csv, Building 96
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg96Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg97.csv, Building 97
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg97Meter.csv, Building 97
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg97Zsz.csv, Building 97
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg97Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg98.csv, Building 98
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg98Meter.csv, Building 98
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg98Zsz.csv, Building 98
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg98Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg99.csv, Building 99
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg99Meter.csv, Building 99
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg99Zsz.csv, Building 99
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg99Zsz.csv, skipping.
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg9Meter.csv, Building 9
# [merge_all_results] Reading D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg9Zsz.csv, Building 9
# Warning: No 'Date/Time' column in D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\simulation_bldg9Zsz.csv, skipping.
# [merge_all_results] Successfully wrote merged CSV to D:\Documents\E_Plus_2030_py\output\edfc6efe-fcb0-4276-8f77-81989745744e\Sim_Results\2020\merged_as_is.csv
