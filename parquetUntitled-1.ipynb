# %%
#!/usr/bin/env python3
"""
Diagnostic script to investigate sensitivity analysis data structure issues
"""

import pandas as pd
import numpy as np
from pathlib import Path
import json

def diagnose_sensitivity_data(job_output_dir):
    """Diagnose the data structures causing the sensitivity analysis error"""
    
    job_output_dir = Path(job_output_dir)
    print(f"Analyzing job output directory: {job_output_dir}")
    print("="*80)
    
    # 1. Check modification tracking data
    print("\n1. MODIFICATION TRACKING DATA:")
    mod_files = list((job_output_dir / "modified_idfs").glob("modifications_detail_*.parquet"))
    if mod_files:
        latest_file = max(mod_files, key=lambda x: x.stat().st_mtime)
        print(f"   Loading: {latest_file}")
        mod_df = pd.read_parquet(latest_file)
        print(f"   Shape: {mod_df.shape}")
        print(f"   Columns: {list(mod_df.columns)}")
        print(f"   Building IDs: {sorted(mod_df['building_id'].unique())}")
        print(f"   Data types:\n{mod_df.dtypes}")
        print(f"\n   Sample (first 3 rows):")
        print(mod_df.head(3))
    
    # 2. Check base simulation results
    print("\n\n2. BASE SIMULATION RESULTS:")
    base_path = job_output_dir / "parsed_data/sql_results/timeseries/aggregated/daily"
    if base_path.exists():
        for category in ['hvac', 'energy', 'electricity', 'zones']:
            file_path = base_path / f"{category}_daily.parquet"
            if file_path.exists():
                print(f"\n   {category}_daily.parquet:")
                df = pd.read_parquet(file_path)
                print(f"   Shape: {df.shape}")
                print(f"   Columns: {list(df.columns)[:10]}..." if len(df.columns) > 10 else f"   Columns: {list(df.columns)}")
                print(f"   Index: {df.index.names}, dtype: {df.index.dtype}")
                if 'building_id' in df.columns:
                    print(f"   Building IDs: {sorted(df['building_id'].unique())}")
                    print(f"   building_id dtype: {df['building_id'].dtype}")
                print(f"   First few rows:")
                print(df.head(2))
    
    # 3. Check modified simulation results
    print("\n\n3. MODIFIED SIMULATION RESULTS:")
    mod_path = job_output_dir / "parsed_modified_results/sql_results/timeseries/aggregated/daily"
    if mod_path.exists():
        for category in ['hvac', 'energy', 'electricity', 'zones']:
            file_path = mod_path / f"{category}_daily.parquet"
            if file_path.exists():
                print(f"\n   {category}_daily.parquet:")
                df = pd.read_parquet(file_path)
                print(f"   Shape: {df.shape}")
                print(f"   Index: {df.index.names}, dtype: {df.index.dtype}")
                if 'building_id' in df.columns:
                    print(f"   Building IDs: {sorted(df['building_id'].unique())}")
                    print(f"   building_id dtype: {df['building_id'].dtype}")
    
    # 4. Simulate output delta calculation
    print("\n\n4. SIMULATING OUTPUT DELTA CALCULATION:")
    try:
        # Load sample data to simulate the delta calculation
        base_hvac = None
        mod_hvac = None
        
        base_hvac_path = base_path / "hvac_daily.parquet"
        mod_hvac_path = mod_path / "hvac_daily.parquet"
        
        if base_hvac_path.exists() and mod_hvac_path.exists():
            base_hvac = pd.read_parquet(base_hvac_path)
            mod_hvac = pd.read_parquet(mod_hvac_path)
            
            print(f"   Base HVAC shape: {base_hvac.shape}")
            print(f"   Modified HVAC shape: {mod_hvac.shape}")
            
            # Try to create a sample delta
            if 'building_id' in base_hvac.columns and 'building_id' in mod_hvac.columns:
                # Group by building_id
                base_grouped = base_hvac.groupby('building_id').first()
                mod_grouped = mod_hvac.groupby('building_id').first()
                
                print(f"\n   After grouping:")
                print(f"   Base grouped index: {base_grouped.index.name}, dtype: {base_grouped.index.dtype}")
                print(f"   Mod grouped index: {mod_grouped.index.name}, dtype: {mod_grouped.index.dtype}")
                
                # Create a sample delta dataframe
                delta_records = []
                for building_id in base_grouped.index:
                    if building_id in mod_grouped.index:
                        delta_records.append({
                            'building_id': building_id,
                            'test_delta': 100.0
                        })
                
                if delta_records:
                    delta_df = pd.DataFrame(delta_records)
                    print(f"\n   Sample delta DataFrame:")
                    print(f"   Shape: {delta_df.shape}")
                    print(f"   Columns: {list(delta_df.columns)}")
                    print(f"   Index: {delta_df.index.name}, dtype: {delta_df.index.dtype}")
                    print(f"   building_id dtype: {delta_df['building_id'].dtype}")
                    print(f"   Data:")
                    print(delta_df)
                    
                    # Test the problematic comparison
                    test_building_id = delta_df['building_id'].iloc[0]
                    print(f"\n   Testing comparison with building_id = {test_building_id} (type: {type(test_building_id)})")
                    try:
                        # This is what causes the error
                        mask = delta_df['building_id'] == test_building_id
                        print(f"   Comparison successful! Mask shape: {mask.shape}")
                        filtered = delta_df[mask]
                        print(f"   Filtered shape: {filtered.shape}")
                    except Exception as e:
                        print(f"   ERROR during comparison: {e}")
                        print(f"   Delta df index: {delta_df.index}")
                        print(f"   Building_id series index: {delta_df['building_id'].index}")
                        
    except Exception as e:
        print(f"   Error during delta simulation: {e}")
        import traceback
        traceback.print_exc()
    
    # 5. Check zone mappings
    print("\n\n5. ZONE MAPPINGS:")
    zone_map_path = job_output_dir / "parsed_data/relationships/zone_mappings.parquet"
    if zone_map_path.exists():
        zone_df = pd.read_parquet(zone_map_path)
        print(f"   Shape: {zone_df.shape}")
        print(f"   Columns: {list(zone_df.columns)}")
        print(f"   Sample:")
        print(zone_df.head(3))
    
    # 6. Configuration check
    print("\n\n6. SENSITIVITY CONFIGURATION:")
    print("   Multi-level analysis: Enabled")
    print("   Cross-level analysis: Enabled")
    print("   Output variables: Heating, Cooling, Electricity, Zone Air Temp, Zone Heating/Cooling")
    print("   Method: elasticity")
    print("   Aggregation: daily, sum")

if __name__ == "__main__":
    # Replace with your actual job output directory
    job_dir = r"D:\Documents\daily\E_Plus_2040_py\output\bfbc7c27-d9df-4e32-b8fe-b627ed32189e"
    diagnose_sensitivity_data(job_dir)
# Out:
# Analyzing job output directory: D:\Documents\daily\E_Plus_2040_py\output\bfbc7c27-d9df-4e32-b8fe-b627ed32189e
# ================================================================================
#
# 1. MODIFICATION TRACKING DATA:
#    Loading: D:\Documents\daily\E_Plus_2040_py\output\bfbc7c27-d9df-4e32-b8fe-b627ed32189e\modified_idfs\modifications_detail_20250623_174326.parquet
#    Shape: (363, 10)
#    Columns: ['building_id', 'variant_id', 'category', 'object_type', 'object_name', 'field_name', 'original_value', 'new_value', 'change_type', 'timestamp']
#    Building IDs: ['4136733', '4136737', '4136738']
#    Data types:
# building_id       object
# variant_id        object
# category          object
# object_type       object
# object_name       object
# field_name        object
# original_value    object
# new_value         object
# change_type       object
# timestamp         object
# dtype: object
#
#    Sample (first 3 rows):
#   building_id variant_id  category object_type       object_name field_name  \
# 0     4136733  variant_0  lighting      LIGHTS  Lights_ALL_ZONES
# 1     4136733  variant_0  lighting      LIGHTS  Lights_ALL_ZONES
# 2     4136733  variant_0  lighting      LIGHTS  Lights_ALL_ZONES
#
#   original_value new_value change_type                   timestamp
# 0            0.1       0.2    absolute  2025-06-23T17:43:26.667130
# 1            0.1       0.2    absolute  2025-06-23T17:43:26.667144
# 2            0.8      0.55    absolute  2025-06-23T17:43:26.667147
#
#
# 2. BASE SIMULATION RESULTS:
#
#    hvac_daily.parquet:
#    Shape: (30295, 6)
#    Columns: ['building_id', 'Zone', 'Variable', 'DateTime', 'TimeIndex', 'Value']
#    Index: [None], dtype: int64
#    Building IDs: ['4136733', '4136737', '4136738']
#    building_id dtype: object
#    First few rows:
#   building_id                 Zone                     Variable   DateTime  \
# 0     4136733  MYDHW_0_WATERHEATER  Water Heater Heating Energy 2013-01-02
# 1     4136733  MYDHW_0_WATERHEATER  Water Heater Heating Energy 2013-01-03
#
#    TimeIndex         Value
# 0        1.0  3.357376e+07
# 1        2.0  3.364953e+07
#
#    zones_daily.parquet:
#    Shape: (155855, 6)
#    Columns: ['building_id', 'Zone', 'Variable', 'DateTime', 'TimeIndex', 'Value']
#    Index: [None], dtype: int64
#    Building IDs: ['4136733', '4136737', '4136738']
#    building_id dtype: object
#    First few rows:
#   building_id        Zone                   Variable   DateTime  TimeIndex  \
# 0     4136733  ZONE1_CORE  Zone Mean Air Temperature 2013-01-02        1.0
# 1     4136733  ZONE1_CORE  Zone Mean Air Temperature 2013-01-03        2.0
#
#        Value
# 0  18.054905
# 1  18.057089
#
#
# 3. MODIFIED SIMULATION RESULTS:
#
#    hvac_daily.parquet:
#    Shape: (30295, 6)
#    Index: [None], dtype: int64
#    Building IDs: ['4136733', '4136737', '4136738']
#    building_id dtype: object
#
#    zones_daily.parquet:
#    Shape: (155855, 6)
#    Index: [None], dtype: int64
#    Building IDs: ['4136733', '4136737', '4136738']
#    building_id dtype: object
#
#
# 4. SIMULATING OUTPUT DELTA CALCULATION:
#    Base HVAC shape: (30295, 6)
#    Modified HVAC shape: (30295, 6)
#
#    After grouping:
#    Base grouped index: building_id, dtype: object
#    Mod grouped index: building_id, dtype: object
#
#    Sample delta DataFrame:
#    Shape: (3, 2)
#    Columns: ['building_id', 'test_delta']
#    Index: None, dtype: int64
#    building_id dtype: object
#    Data:
#   building_id  test_delta
# 0     4136733       100.0
# 1     4136737       100.0
# 2     4136738       100.0
#
#    Testing comparison with building_id = 4136733 (type: <class 'str'>)
#    Comparison successful! Mask shape: (3,)
#    Filtered shape: (1, 2)
#
#
# 5. ZONE MAPPINGS:
#    Shape: (19, 6)
#    Columns: ['building_id', 'idf_zone_name', 'sql_zone_name', 'zone_type', 'multiplier', 'mapping_confidence']
#    Sample:
#   building_id         idf_zone_name         sql_zone_name zone_type  \
# 0     4136733  Zone1_FrontPerimeter  ZONE1_FRONTPERIMETER      None
# 1     4136733  Zone1_RightPerimeter  ZONE1_RIGHTPERIMETER      None
# 2     4136733   Zone1_RearPerimeter   ZONE1_REARPERIMETER      None
#
#    multiplier  mapping_confidence
# 0         NaN                 0.8
# 1         NaN                 0.8
# 2         NaN                 0.8
#
#
# 6. SENSITIVITY CONFIGURATION:
#    Multi-level analysis: Enabled
#    Cross-level analysis: Enabled
#    Output variables: Heating, Cooling, Electricity, Zone Air Temp, Zone Heating/Cooling
#    Method: elasticity
#    Aggregation: daily, sum

# %%
import os
import json
import pandas as pd
from pathlib import Path
import glob

def explore_directory_contents(base_path="output/2dae68d1-4b75-4c75-9471-7b6d931af865"):
    """Explore and display contents of analysis output directories"""
    
    directories = {
        "modified_idfs": "Modified IDF files",
        "Modified_Sim_Results": "Modified simulation results",
        "output_IDFs": "Output IDF files",
        "parsed_data": "Parsed data from original simulations",
        "parsed_modified_results": "Parsed modified simulation results",
        "sensitivity_results": "Sensitivity analysis results",
        "Sim_Results": "Original simulation results",
        "validation_results": "Validation results"
    }
    
    results = {}
    
    for dir_name, description in directories.items():
        dir_path = Path(base_path) / dir_name
        print(f"\n{'='*60}")
        print(f"Directory: {dir_name}")
        print(f"Description: {description}")
        print(f"Path: {dir_path}")
        print(f"{'='*60}")
        
        if not dir_path.exists():
            print(f"Directory does not exist!")
            continue
            
        # List files in directory
        files = list(dir_path.iterdir())
        print(f"\nNumber of files: {len(files)}")
        
        # Group files by extension
        file_types = {}
        for file in files:
            if file.is_file():
                ext = file.suffix.lower()
                if ext not in file_types:
                    file_types[ext] = []
                file_types[ext].append(file.name)
        
        print("\nFile types found:")
        for ext, file_list in file_types.items():
            print(f"  {ext or 'no extension'}: {len(file_list)} files")
            # Show first 3 files as examples
            for i, fname in enumerate(file_list[:3]):
                print(f"    - {fname}")
            if len(file_list) > 3:
                print(f"    ... and {len(file_list) - 3} more")
        
        # Try to read and display sample content
        if dir_name == "sensitivity_results":
            print("\n--- SENSITIVITY RESULTS SAMPLE ---")
            csv_files = list(dir_path.glob("*.csv"))
            if csv_files:
                df = pd.read_csv(csv_files[0])
                print(f"\nFile: {csv_files[0].name}")
                print(f"Shape: {df.shape}")
                print(f"\nColumns: {list(df.columns)}")
                print(f"\nFirst 5 rows:")
                print(df.head())
                
                # Show unique values for key columns
                if 'parameter' in df.columns:
                    print(f"\nUnique parameters ({len(df['parameter'].unique())}):")
                    for param in sorted(df['parameter'].unique())[:10]:
                        print(f"  - {param}")
                    if len(df['parameter'].unique()) > 10:
                        print(f"  ... and {len(df['parameter'].unique()) - 10} more")
                
                if 'output_variable' in df.columns:
                    print(f"\nUnique output variables:")
                    for var in df['output_variable'].unique():
                        print(f"  - {var}")
        
        elif dir_name == "parsed_data" or dir_name == "parsed_modified_results":
            print(f"\n--- {dir_name.upper()} SAMPLE ---")
            csv_files = list(dir_path.glob("*.csv"))
            if csv_files:
                df = pd.read_csv(csv_files[0])
                print(f"\nFile: {csv_files[0].name}")
                print(f"Shape: {df.shape}")
                print(f"\nColumns: {list(df.columns)}")
                print(f"\nFirst 5 rows:")
                print(df.head())
                
                # Check if it has time data
                time_cols = [col for col in df.columns if 'time' in col.lower() or 'date' in col.lower()]
                if time_cols:
                    print(f"\nTime columns found: {time_cols}")
        
        elif dir_name == "modified_idfs" or dir_name == "output_IDFs":
            print(f"\n--- {dir_name.upper()} SAMPLE ---")
            idf_files = list(dir_path.glob("*.idf"))
            if idf_files:
                print(f"\nReading first 50 lines of: {idf_files[0].name}")
                with open(idf_files[0], 'r') as f:
                    lines = f.readlines()[:50]
                    for i, line in enumerate(lines):
                        if line.strip() and not line.strip().startswith('!'):
                            print(f"{i:3d}: {line.rstrip()}")
        
        elif dir_name == "validation_results":
            print("\n--- VALIDATION RESULTS SAMPLE ---")
            # Try JSON files first
            json_files = list(dir_path.glob("*.json"))
            if json_files:
                with open(json_files[0], 'r') as f:
                    data = json.load(f)
                print(f"\nFile: {json_files[0].name}")
                print(f"JSON structure:")
                print(json.dumps(data, indent=2)[:500] + "...")
            
            # Try CSV files
            csv_files = list(dir_path.glob("*.csv"))
            if csv_files:
                df = pd.read_csv(csv_files[0])
                print(f"\nFile: {csv_files[0].name}")
                print(f"Shape: {df.shape}")
                print(df.head())

def analyze_parameter_structure(base_path="output/2dae68d1-4b75-4c75-9471-7b6d931af865"):
    """Analyze the parameter structure from sensitivity results"""
    
    sensitivity_path = Path(base_path) / "sensitivity_results"
    if not sensitivity_path.exists():
        print("Sensitivity results directory not found!")
        return
    
    print("\n" + "="*60)
    print("PARAMETER STRUCTURE ANALYSIS")
    print("="*60)
    
    # Read all CSV files
    all_params = set()
    param_examples = {}
    
    for csv_file in sensitivity_path.glob("*.csv"):
        df = pd.read_csv(csv_file)
        if 'parameter' in df.columns:
            for param in df['parameter'].unique():
                all_params.add(param)
                if param not in param_examples:
                    # Get an example row for this parameter
                    example_row = df[df['parameter'] == param].iloc[0].to_dict()
                    param_examples[param] = example_row
    
    # Analyze parameter patterns
    print(f"\nTotal unique parameters: {len(all_params)}")
    
    # Group parameters by pattern
    param_groups = {
        'materials': [],
        'schedules': [],
        'equipment': [],
        'constructions': [],
        'zones': [],
        'other': []
    }
    
    for param in sorted(all_params):
        param_lower = param.lower()
        if 'material' in param_lower:
            param_groups['materials'].append(param)
        elif 'schedule' in param_lower:
            param_groups['schedules'].append(param)
        elif any(equip in param_lower for equip in ['coil', 'fan', 'pump', 'chiller', 'boiler']):
            param_groups['equipment'].append(param)
        elif 'construction' in param_lower:
            param_groups['constructions'].append(param)
        elif 'zone' in param_lower:
            param_groups['zones'].append(param)
        else:
            param_groups['other'].append(param)
    
    # Display grouped parameters
    for group, params in param_groups.items():
        if params:
            print(f"\n{group.upper()} ({len(params)} parameters):")
            for param in params[:5]:
                print(f"  - {param}")
                if param in param_examples:
                    example = param_examples[param]
                    print(f"    Example: zone={example.get('zone_name', 'N/A')}, "
                          f"score={example.get('sensitivity_score', 'N/A'):.2e}, "
                          f"p_value={example.get('p_value', 'N/A')}")
            if len(params) > 5:
                print(f"  ... and {len(params) - 5} more")

def analyze_time_structure(base_path="output/2dae68d1-4b75-4c75-9471-7b6d931af865"):
    """Analyze the time structure in simulation results"""
    
    print("\n" + "="*60)
    print("TIME STRUCTURE ANALYSIS")
    print("="*60)
    
    # Check parsed data for time information
    parsed_path = Path(base_path) / "parsed_data"
    if parsed_path.exists():
        csv_files = list(parsed_path.glob("*.csv"))
        if csv_files:
            df = pd.read_csv(csv_files[0], nrows=1000)  # Read first 1000 rows
            print(f"\nAnalyzing time structure in: {csv_files[0].name}")
            
            # Look for time-related columns
            time_cols = [col for col in df.columns if any(t in col.lower() for t in ['time', 'date', 'month', 'hour', 'day'])]
            
            if time_cols:
                print(f"\nTime columns found: {time_cols}")
                for col in time_cols:
                    print(f"\n{col}:")
                    print(f"  Sample values: {df[col].head(10).tolist()}")
                    print(f"  Unique values: {df[col].nunique()}")
            
            # If numeric columns exist, check if they represent time series
            numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns
            if len(numeric_cols) > 0:
                print(f"\nNumeric columns that might be time series: {len(numeric_cols)}")
                print(f"Data shape suggests {len(df)} time steps")

if __name__ == "__main__":
    # Update this path to match your actual output directory
    base_path = "output/2dae68d1-4b75-4c75-9471-7b6d931af865"
    
    print("ENERGYPLUS SENSITIVITY ANALYSIS OUTPUT EXPLORER")
    print("=" * 60)
    
    # Explore all directories
    explore_directory_contents(base_path)
    
    # Analyze parameter structure
    analyze_parameter_structure(base_path)
    
    # Analyze time structure
    analyze_time_structure(base_path)
    
    print("\n" + "="*60)
    print("ANALYSIS COMPLETE")
    print("="*60)
# Out:
# ENERGYPLUS SENSITIVITY ANALYSIS OUTPUT EXPLORER
# ============================================================
#
# ============================================================
# Directory: modified_idfs
# Description: Modified IDF files
# Path: output\2dae68d1-4b75-4c75-9471-7b6d931af865\modified_idfs
# ============================================================
#
# Number of files: 12
#
# File types found:
#   .idf: 9 files
#     - building_4136733_variant_0.idf
#     - building_4136733_variant_1.idf
#     - building_4136733_variant_2.idf
#     ... and 6 more
#   .parquet: 2 files
#     - modifications_detail_20250623_182931.parquet
#     - modifications_summary_20250623_182931.parquet
#   .json: 1 files
#     - modification_report_20250623_182931.json
#
# --- MODIFIED_IDFS SAMPLE ---
#
# Reading first 50 lines of: building_4136733_variant_0.idf
#   7: Version,
#   8:     22.2;  !- Version Identifier, Version Identifier
#  10: SimulationControl,
#  11:     Yes,  !- Do Zone Sizing Calculation, Do Zone Sizing Calculation
#  12:     Yes,  !- Do System Sizing Calculation, Do System Sizing Calculation
#  13:     Yes,  !- Do Plant Sizing Calculation, Do Plant Sizing Calculation
#  14:     No,  !- Run Simulation for Sizing Periods, Run Simulation for Sizing Periods
#  15:     Yes,  !- Run Simulation for Weather File Run Periods, Run Simulation for Weather File Run Periods
#  16:     No,  !- Do HVAC Sizing Simulation for Sizing Periods, Do HVAC Sizing Simulation for Sizing Periods
#  17:     ;  !- Maximum Number of HVAC Sizing Simulation Passes, Maximum Number of HVAC Sizing Simulation Passes
#  19: BUILDING,
#  20:     Sample_Building_0,  !- Name, Name
#  21:     0,  !- North Axis, North Axis
#  22:     Suburbs,  !- Terrain, Terrain
#  23:     0.04,  !- Loads Convergence Tolerance Value, Loads Convergence Tolerance Value
#  24:     0.4,  !- Temperature Convergence Tolerance Value, Temperature Convergence Tolerance Value
#  25:     FullExterior,  !- Solar Distribution, Solar Distribution
#  26:     25,  !- Maximum Number of Warmup Days, Maximum Number of Warmup Days
#  27:     1;  !- Minimum Number of Warmup Days, Minimum Number of Warmup Days
#  29: Timestep,
#  30:     6;  !- Number of Timesteps per Hour, Number of Timesteps per Hour
#  32: Site:Location,
#  33:     Amsterdam_Netherlands,  !- Name, Name
#  34:     52.37,  !- Latitude, Latitude
#  35:     4.89,  !- Longitude, Longitude
#  36:     1,  !- Time Zone, Time Zone
#  37:     0;  !- Elevation, Elevation
#  39: SITE:GROUNDTEMPERATURE:BUILDINGSURFACE,
#  40:     4.550571800011037,  !- January Ground Temperature, January Ground Temperature
#  41:     5.448661134387153,  !- February Ground Temperature, February Ground Temperature
#  42:     6.461203638291392,  !- March Ground Temperature, March Ground Temperature
#  43:     9.46917184692521,  !- April Ground Temperature, April Ground Temperature
#  44:     16.384087429881177,  !- May Ground Temperature, May Ground Temperature
#  45:     18.087844488976064,  !- June Ground Temperature, June Ground Temperature
#  46:     20.695504136962843,  !- July Ground Temperature, July Ground Temperature
#  47:     19.585022666811984,  !- August Ground Temperature, August Ground Temperature
#  48:     16.754988640923692,  !- September Ground Temperature, September Ground Temperature
#  49:     10.970739440429295,  !- October Ground Temperature, October Ground Temperature
#
# ============================================================
# Directory: Modified_Sim_Results
# Description: Modified simulation results
# Path: output\2dae68d1-4b75-4c75-9471-7b6d931af865\Modified_Sim_Results
# ============================================================
#
# Number of files: 1
#
# File types found:
#
# ============================================================
# Directory: output_IDFs
# Description: Output IDF files
# Path: output\2dae68d1-4b75-4c75-9471-7b6d931af865\output_IDFs
# ============================================================
#
# Number of files: 3
#
# File types found:
#   .idf: 3 files
#     - building_4136733.idf
#     - building_4136737.idf
#     - building_4136738.idf
#
# --- OUTPUT_IDFS SAMPLE ---
#
# Reading first 50 lines of: building_4136733.idf
#   2: Version,
#   3:     22.2;                     !- Version Identifier
#   5: SimulationControl,
#   6:     Yes,                      !- Do Zone Sizing Calculation
#   7:     Yes,                      !- Do System Sizing Calculation
#   8:     Yes,                      !- Do Plant Sizing Calculation
#   9:     No,                       !- Run Simulation for Sizing Periods
#  10:     Yes,                      !- Run Simulation for Weather File Run Periods
#  11:     No,                       !- Do HVAC Sizing Simulation for Sizing Periods
#  12:     ;                         !- Maximum Number of HVAC Sizing Simulation Passes
#  14: BUILDING,
#  15:     Sample_Building_0,        !- Name
#  16:     0,                        !- North Axis
#  17:     Suburbs,                  !- Terrain
#  18:     0.04,                     !- Loads Convergence Tolerance Value
#  19:     0.4,                      !- Temperature Convergence Tolerance Value
#  20:     FullExterior,             !- Solar Distribution
#  21:     25,                       !- Maximum Number of Warmup Days
#  22:     1;                        !- Minimum Number of Warmup Days
#  24: Timestep,
#  25:     4;                        !- Number of Timesteps per Hour
#  27: Site:Location,
#  28:     Amsterdam_Netherlands,    !- Name
#  29:     52.37,                    !- Latitude
#  30:     4.89,                     !- Longitude
#  31:     1,                        !- Time Zone
#  32:     -2;                       !- Elevation
#  34: SizingPeriod:DesignDay,
#  35:     Netherlands Ann Htg 99.6% Condns DB,    !- Name
#  36:     1,                        !- Month
#  37:     21,                       !- Day of Month
#  38:     WinterDesignDay,          !- Day Type
#  39:     -5,                       !- Maximum DryBulb Temperature
#  40:     0,                        !- Daily DryBulb Temperature Range
#  41:     ,                         !- DryBulb Temperature Range Modifier Type
#  42:     ,                         !- DryBulb Temperature Range Modifier Day Schedule Name
#  43:     Wetbulb,                  !- Humidity Condition Type
#  44:     -5,                       !- Wetbulb or DewPoint at Maximum DryBulb
#  45:     ,                         !- Humidity Condition Day Schedule Name
#  46:     ,                         !- Humidity Ratio at Maximum DryBulb
#  47:     ,                         !- Enthalpy at Maximum DryBulb
#  48:     ,                         !- Daily WetBulb Temperature Range
#  49:     102000,                   !- Barometric Pressure
#
# ============================================================
# Directory: parsed_data
# Description: Parsed data from original simulations
# Path: output\2dae68d1-4b75-4c75-9471-7b6d931af865\parsed_data
# ============================================================
#
# Number of files: 6
#
# File types found:
#   .json: 1 files
#     - parsing_summary.json
#
# --- PARSED_DATA SAMPLE ---
#
# ============================================================
# Directory: parsed_modified_results
# Description: Parsed modified simulation results
# Path: output\2dae68d1-4b75-4c75-9471-7b6d931af865\parsed_modified_results
# ============================================================
#
# Number of files: 6
#
# File types found:
#   .json: 1 files
#     - parsing_summary.json
#
# --- PARSED_MODIFIED_RESULTS SAMPLE ---
#
# ============================================================
# Directory: sensitivity_results
# Description: Sensitivity analysis results
# Path: output\2dae68d1-4b75-4c75-9471-7b6d931af865\sensitivity_results
# ============================================================
#
# Number of files: 9
#
# File types found:
#   .csv: 2 files
#     - calibration_parameters.csv
#     - top_sensitive_parameters.csv
#   .json: 5 files
#     - calibration_parameters.json
#     - modification_sensitivity_report.json
#     - sensitive_parameters_for_calibration.json
#     ... and 2 more
#   .parquet: 1 files
#     - modification_sensitivity_results.parquet
#
# --- SENSITIVITY RESULTS SAMPLE ---
#
# File: calibration_parameters.csv
# Shape: (5, 9)
#
# Columns: ['parameter', 'sensitivity_score', 'analysis_method', 'category', 'output_variable', 'p_value', 'significant', 'confidence_interval', 'suggested_range_multiplier']
#
# First 5 rows:
#                                 parameter  sensitivity_score analysis_method  \
# 0                     materials_MATERIAL_       3.934207e+11    modification
# 1                        lighting_LIGHTS_       1.229734e+11    modification
# 2  geometry_FENESTRATIONSURFACE:DETAILED_       7.872814e+10    modification
# 3                              param_mean       1.890769e+10    modification
# 4                               param_std       1.450744e+10    modification
#
#     category                          output_variable  p_value  significant  \
# 0  materials  Zone Air System Sensible Heating Energy      0.1        False
# 1   lighting  Zone Air System Sensible Heating Energy      0.1        False
# 2   geometry  Zone Air System Sensible Heating Energy      0.1        False
# 3      param  Zone Air System Sensible Heating Energy      0.1        False
# 4      param  Zone Air System Sensible Heating Energy      0.1        False
#
#                           confidence_interval  suggested_range_multiplier
# 0  [-314736557814.70135, -472104836722.05194]                3.934207e+11
# 1      [98378724314.37015, 147568086471.5552]                1.229734e+11
# 2    [-62982512037.11984, -94473768055.67975]                7.872814e+10
# 3     [15126154557.051239, 22689231835.57686]                1.890769e+10
# 4    [-11605954644.229534, -17408931966.3443]                1.450744e+10
#
# Unique parameters (5):
#   - geometry_FENESTRATIONSURFACE:DETAILED_
#   - lighting_LIGHTS_
#   - materials_MATERIAL_
#   - param_mean
#   - param_std
#
# Unique output variables:
#   - Zone Air System Sensible Heating Energy
#
# ============================================================
# Directory: Sim_Results
# Description: Original simulation results
# Path: output\2dae68d1-4b75-4c75-9471-7b6d931af865\Sim_Results
# ============================================================
#
# Number of files: 1
#
# File types found:
#
# ============================================================
# Directory: validation_results
# Description: Validation results
# Path: output\2dae68d1-4b75-4c75-9471-7b6d931af865\validation_results
# ============================================================
#
# Number of files: 3
#
# File types found:
#   .json: 1 files
#     - combined_summary.json
#
# --- VALIDATION RESULTS SAMPLE ---
#
# File: combined_summary.json
# JSON structure:
# {
#   "timestamp": "2025-06-23T18:30:21.738862",
#   "job_id": "2dae68d1-4b75-4c75-9471-7b6d931af865",
#   "stages_completed": [
#     "baseline",
#     "modified"
#   ],
#   "stage_summaries": {
#     "baseline": {
#       "status": "No validation results"
#     },
#     "modified": {
#       "status": "No validation results"
#     }
#   },
#   "overall_metrics": {
#     "total_validations": 0,
#     "total_passed": 0,
#     "buildings_validated": 0,
#     "variables_validated": 0,
#     "average_pass_rate": 0.0
#   },
#   "improvement_m...
#
# ============================================================
# PARAMETER STRUCTURE ANALYSIS
# ============================================================
#
# Total unique parameters: 5
#
# MATERIALS (1 parameters):
#   - materials_MATERIAL_
#     Example: zone=N/A, score=3.93e+11, p_value=0.1
#
# OTHER (4 parameters):
#   - geometry_FENESTRATIONSURFACE:DETAILED_
#     Example: zone=N/A, score=7.87e+10, p_value=0.1
#   - lighting_LIGHTS_
#     Example: zone=N/A, score=1.23e+11, p_value=0.1
#   - param_mean
#     Example: zone=N/A, score=1.89e+10, p_value=0.1
#   - param_std
#     Example: zone=N/A, score=1.45e+10, p_value=0.1
#
# ============================================================
# TIME STRUCTURE ANALYSIS
# ============================================================
#
# ============================================================
# ANALYSIS COMPLETE
# ============================================================

# %%
import os
import json
import pandas as pd
import sqlite3
from pathlib import Path
import glob
from collections import defaultdict

def analyze_parameter_structure(base_path):
    """Analyze how parameters are currently structured"""
    print("\n" + "="*80)
    print("PARAMETER STRUCTURE ANALYSIS")
    print("="*80)
    
    # Look for parameter files in parsed_data
    param_files = glob.glob(os.path.join(base_path, "parsed_data", "**/*param*.json"), recursive=True)
    param_files += glob.glob(os.path.join(base_path, "parsed_data", "**/*extracted*.json"), recursive=True)
    
    parameter_types = defaultdict(list)
    
    for param_file in param_files:
        print(f"\nAnalyzing: {param_file}")
        try:
            with open(param_file, 'r') as f:
                data = json.load(f)
            
            # Analyze structure
            if isinstance(data, dict):
                for key, value in data.items():
                    if 'material' in key.lower():
                        print(f"\n  Material parameters found:")
                        if isinstance(value, dict):
                            for mat_name, mat_props in list(value.items())[:3]:
                                print(f"    {mat_name}: {list(mat_props.keys()) if isinstance(mat_props, dict) else type(mat_props)}")
                                parameter_types['materials'].append(mat_props)
                    
                    elif 'construction' in key.lower():
                        print(f"\n  Construction parameters found:")
                        if isinstance(value, dict):
                            for const_name, const_props in list(value.items())[:3]:
                                print(f"    {const_name}: {const_props}")
                                parameter_types['constructions'].append(const_props)
                    
                    elif 'schedule' in key.lower():
                        print(f"\n  Schedule parameters found:")
                        print(f"    Type: {type(value)}, Length: {len(value) if hasattr(value, '__len__') else 'N/A'}")
                        parameter_types['schedules'].append(value)
                        
        except Exception as e:
            print(f"  Error: {e}")
    
    # Look for sensitivity results to see current parameter categorization
    sensitivity_files = glob.glob(os.path.join(base_path, "sensitivity_results", "**/*.json"), recursive=True)
    
    print("\n\nCurrent Parameter Categories in Sensitivity Results:")
    unique_params = set()
    
    for sens_file in sensitivity_files[:5]:
        try:
            with open(sens_file, 'r') as f:
                data = json.load(f)
            
            if isinstance(data, list):
                for item in data[:10]:
                    if isinstance(item, dict) and 'parameter' in item:
                        param = item['parameter']
                        category = item.get('category', 'unknown')
                        unique_params.add((category, param))
        except:
            pass
    
    # Group by category
    by_category = defaultdict(list)
    for category, param in unique_params:
        by_category[category].append(param)
    
    for category, params in by_category.items():
        print(f"\n  {category}:")
        for param in params[:5]:
            print(f"    {param}")

def analyze_time_resolution(base_path):
    """Analyze available time resolution in simulation results"""
    print("\n" + "="*80)
    print("TIME RESOLUTION ANALYSIS")
    print("="*80)
    
    # Look for simulation result files
    result_files = glob.glob(os.path.join(base_path, "Sim_Results", "**/*.csv"), recursive=True)
    result_files += glob.glob(os.path.join(base_path, "Modified_Sim_Results", "**/*.csv"), recursive=True)
    
    time_resolutions = {}
    
    for result_file in result_files[:5]:
        print(f"\nAnalyzing: {os.path.basename(result_file)}")
        try:
            # Read first few rows to understand structure
            df = pd.read_csv(result_file, nrows=100)
            
            # Look for time columns
            time_cols = [col for col in df.columns if any(t in col.lower() for t in ['time', 'date', 'hour', 'month', 'day', 'minute'])]
            
            if time_cols:
                print(f"  Time columns found: {time_cols}")
                
                # Analyze time data
                for col in time_cols:
                    if pd.api.types.is_numeric_dtype(df[col]):
                        print(f"    {col}: numeric, range {df[col].min()} - {df[col].max()}")
                    else:
                        print(f"    {col}: {df[col].dtype}, samples: {df[col].head(3).tolist()}")
                        
                        # Try to parse as datetime
                        try:
                            df[col] = pd.to_datetime(df[col])
                            time_diff = df[col].diff().dropna()
                            if len(time_diff) > 0:
                                common_diff = time_diff.mode()[0]
                                print(f"      Time resolution: {common_diff}")
                                time_resolutions[result_file] = common_diff
                        except:
                            pass
            
            # Check for EnergyPlus standard columns
            if 'Date/Time' in df.columns:
                print("  EnergyPlus Date/Time column found")
                sample = df['Date/Time'].head(5).tolist()
                print(f"    Samples: {sample}")
            
            # Show all columns for context
            print(f"\n  All columns ({len(df.columns)}):")
            for i, col in enumerate(df.columns):
                if i < 10 or 'zone' in col.lower() or 'time' in col.lower():
                    print(f"    {col}")
            if len(df.columns) > 10:
                print(f"    ... and {len(df.columns) - 10} more columns")
                
        except Exception as e:
            print(f"  Error: {e}")
    
    return time_resolutions

def analyze_idf_parameters(base_path):
    """Analyze how parameters are modified in IDFs"""
    print("\n" + "="*80)
    print("IDF PARAMETER MODIFICATION ANALYSIS")  
    print("="*80)
    
    # Compare original and modified IDFs
    original_idfs = glob.glob(os.path.join(base_path, "output_IDFs", "*.idf"), recursive=True)
    modified_idfs = glob.glob(os.path.join(base_path, "modified_idfs", "*.idf"), recursive=True)
    
    if original_idfs and modified_idfs:
        print(f"\nFound {len(original_idfs)} original and {len(modified_idfs)} modified IDFs")
        
        # Analyze first pair
        if original_idfs and modified_idfs:
            orig_file = original_idfs[0]
            # Try to find corresponding modified file
            orig_name = os.path.basename(orig_file)
            
            print(f"\nComparing: {orig_name}")
            
            # Read both files and look for differences
            try:
                with open(orig_file, 'r') as f:
                    orig_content = f.read()
                
                # Find a modified version
                for mod_file in modified_idfs[:5]:
                    with open(mod_file, 'r') as f:
                        mod_content = f.read()
                    
                    if len(mod_content) != len(orig_content):
                        print(f"\n  Modified file: {os.path.basename(mod_file)}")
                        print(f"  Size difference: {len(mod_content) - len(orig_content)} characters")
                        
                        # Look for specific changes in materials
                        orig_materials = extract_idf_objects(orig_content, 'Material')
                        mod_materials = extract_idf_objects(mod_content, 'Material')
                        
                        if len(orig_materials) != len(mod_materials):
                            print(f"  Material count: {len(orig_materials)} -> {len(mod_materials)}")
                        
                        # Show sample differences
                        for obj_type in ['Material', 'Construction', 'Schedule']:
                            orig_objs = extract_idf_objects(orig_content, obj_type)
                            mod_objs = extract_idf_objects(mod_content, obj_type)
                            if orig_objs != mod_objs:
                                print(f"\n  {obj_type} changes detected")
                                break
                        
                        break
                        
            except Exception as e:
                print(f"  Error comparing: {e}")

def extract_idf_objects(content, object_type):
    """Extract objects of a specific type from IDF content"""
    objects = []
    lines = content.split('\n')
    in_object = False
    current_object = []
    
    for line in lines:
        line = line.strip()
        if line.startswith(object_type + ','):
            in_object = True
            current_object = [line]
        elif in_object:
            current_object.append(line)
            if line.endswith(';'):
                objects.append('\n'.join(current_object))
                in_object = False
                current_object = []
    
    return objects

def summarize_findings(base_path):
    """Summarize key findings for planning enhancements"""
    print("\n" + "="*80)
    print("SUMMARY OF FINDINGS")
    print("="*80)
    
    print("\n1. CURRENT PARAMETER STRUCTURE:")
    print("   - Parameters appear to be grouped by high-level categories")
    print("   - Need to extract specific sub-parameters like:")
    print("     * Material properties: conductivity, density, specific heat")
    print("     * Construction layers: individual layer properties")
    print("     * Schedule values: time-specific values")
    
    print("\n2. TIME RESOLUTION AVAILABLE:")
    print("   - Check simulation output files for hourly/sub-hourly data")
    print("   - EnergyPlus typically provides hourly or sub-hourly resolution")
    print("   - Need to identify time columns for filtering")
    
    print("\n3. REQUIRED ENHANCEMENTS:")
    print("   a) Parameter Extraction:")
    print("      - Parse IDF objects to extract individual properties")
    print("      - Create mapping of high-level to sub-parameters")
    print("      - Store parameter hierarchy in database")
    print("   ")
    print("   b) Time-Slice Analysis:")
    print("      - Add time filtering to sensitivity calculation")
    print("      - Define time periods (peak hours, months, day types)")
    print("      - Store time-specific sensitivity results")
    
    print("\n4. FILES TO UPDATE:")
    print("   - parameter_extractor.py: Add sub-parameter extraction")
    print("   - sensitivity_analysis.py: Add time filtering")
    print("   - database schema: Add time dimension to results")
    print("   - API endpoints: Add time-slice query parameters")

def main():
    """Run all analyses"""
    base_path = "output/2dae68d1-4b75-4c75-9471-7b6d931af865"
    
    # Run analyses
    analyze_parameter_structure(base_path)
    time_resolutions = analyze_time_resolution(base_path)
    analyze_idf_parameters(base_path)
    summarize_findings(base_path)
    
    print("\n" + "="*80)
    print("ANALYSIS COMPLETE - Please run and share the output!")
    print("="*80)

if __name__ == "__main__":
    main()
# Out:
# ================================================================================
# PARAMETER STRUCTURE ANALYSIS
# ================================================================================
#
#
# Current Parameter Categories in Sensitivity Results:
#
# ================================================================================
# TIME RESOLUTION ANALYSIS
# ================================================================================
#
# Analyzing: simulation_bldg0_4136733.csv
#   Time columns found: ['Date/Time', 'Environment:Site Outdoor Air Drybulb Temperature [C](Monthly)', 'Environment:Site Outdoor Air Relative Humidity [%](Monthly)', 'Environment:Site Diffuse Solar Radiation Rate per Area [W/m2](Monthly)', 'ZONE1_FRONTPERIMETER:Zone Mean Radiant Temperature [C](Monthly)', 'ZONE1_RIGHTPERIMETER:Zone Mean Radiant Temperature [C](Monthly)', 'ZONE1_REARPERIMETER:Zone Mean Radiant Temperature [C](Monthly)', 'ZONE1_LEFTPERIMETER:Zone Mean Radiant Temperature [C](Monthly)', 'ZONE1_CORE:Zone Mean Radiant Temperature [C](Monthly)', 'ZONE2_FRONTPERIMETER:Zone Mean Radiant Temperature [C](Monthly)', 'ZONE2_RIGHTPERIMETER:Zone Mean Radiant Temperature [C](Monthly)', 'ZONE2_REARPERIMETER:Zone Mean Radiant Temperature [C](Monthly)', 'ZONE2_LEFTPERIMETER:Zone Mean Radiant Temperature [C](Monthly)', 'ZONE2_CORE:Zone Mean Radiant Temperature [C](Monthly)', 'ZONE1_FRONTPERIMETER:Zone Windows Total Transmitted Solar Radiation Rate [W](Monthly)', 'ZONE1_FRONTPERIMETER:Zone Windows Total Transmitted Solar Radiation Energy [J](Monthly)', 'ZONE1_RIGHTPERIMETER:Zone Windows Total Transmitted Solar Radiation Rate [W](Monthly)', 'ZONE1_RIGHTPERIMETER:Zone Windows Total Transmitted Solar Radiation Energy [J](Monthly)', 'ZONE1_REARPERIMETER:Zone Windows Total Transmitted Solar Radiation Rate [W](Monthly)', 'ZONE1_REARPERIMETER:Zone Windows Total Transmitted Solar Radiation Energy [J](Monthly)', 'ZONE1_LEFTPERIMETER:Zone Windows Total Transmitted Solar Radiation Rate [W](Monthly)', 'ZONE1_LEFTPERIMETER:Zone Windows Total Transmitted Solar Radiation Energy [J](Monthly)', 'ZONE1_CORE:Zone Windows Total Transmitted Solar Radiation Rate [W](Monthly)', 'ZONE1_CORE:Zone Windows Total Transmitted Solar Radiation Energy [J](Monthly)', 'ZONE2_FRONTPERIMETER:Zone Windows Total Transmitted Solar Radiation Rate [W](Monthly)', 'ZONE2_FRONTPERIMETER:Zone Windows Total Transmitted Solar Radiation Energy [J](Monthly)', 'ZONE2_RIGHTPERIMETER:Zone Windows Total Transmitted Solar Radiation Rate [W](Monthly)', 'ZONE2_RIGHTPERIMETER:Zone Windows Total Transmitted Solar Radiation Energy [J](Monthly)', 'ZONE2_REARPERIMETER:Zone Windows Total Transmitted Solar Radiation Rate [W](Monthly)', 'ZONE2_REARPERIMETER:Zone Windows Total Transmitted Solar Radiation Energy [J](Monthly)', 'ZONE2_LEFTPERIMETER:Zone Windows Total Transmitted Solar Radiation Rate [W](Monthly)', 'ZONE2_LEFTPERIMETER:Zone Windows Total Transmitted Solar Radiation Energy [J](Monthly)', 'ZONE2_CORE:Zone Windows Total Transmitted Solar Radiation Rate [W](Monthly)', 'ZONE2_CORE:Zone Windows Total Transmitted Solar Radiation Energy [J](Monthly)', 'ZONE1_FRONTPERIMETER_WALL_0:Surface Outside Face Incident Solar Radiation Rate per Area [W/m2](Monthly)', 'ZONE1_FRONTPERIMETER_WALL_0 WINDOW:Surface Outside Face Incident Solar Radiation Rate per Area [W/m2](Monthly)', 'ZONE1_FRONTPERIMETER_WALL_0 WINDOW:Surface Window Transmitted Solar Radiation Rate [W](Monthly)', 'ZONE1_FRONTPERIMETER_WALL_0 WINDOW:Surface Window Transmitted Beam Solar Radiation Rate [W](Monthly)', 'ZONE1_FRONTPERIMETER_WALL_0 WINDOW:Surface Window Transmitted Diffuse Solar Radiation Rate [W](Monthly)', 'ZONE1_FRONTPERIMETER_WALL_0 WINDOW:Surface Window Heat Gain Rate [W](Monthly)', 'ZONE1_FRONTPERIMETER_WALL_0 WINDOW:Surface Window Heat Loss Rate [W](Monthly)', 'ZONE1_FRONTPERIMETER_WALL_0 WINDOW:Surface Window Shading Device Absorbed Solar Radiation Rate [W](Monthly)', 'ZONE1_FRONTPERIMETER_WALL_0 WINDOW:Surface Window Heat Gain Energy [J](Monthly)', 'ZONE1_FRONTPERIMETER_WALL_0 WINDOW:Surface Window Heat Loss Energy [J](Monthly)', 'ZONE1_REARPERIMETER_WALL_0:Surface Outside Face Incident Solar Radiation Rate per Area [W/m2](Monthly)', 'ZONE1_REARPERIMETER_WALL_0 WINDOW:Surface Outside Face Incident Solar Radiation Rate per Area [W/m2](Monthly)', 'ZONE1_REARPERIMETER_WALL_0 WINDOW:Surface Window Transmitted Solar Radiation Rate [W](Monthly)', 'ZONE1_REARPERIMETER_WALL_0 WINDOW:Surface Window Transmitted Beam Solar Radi ...
#     Date/Time: object, samples: [' 01/01', ' 01/02', ' 01/03']
#     Environment:Site Outdoor Air Drybulb Temperature [C](Monthly): numeric, range 3.69605174731183 - 5.679032258064516
#     Environment:Site Outdoor Air Relative Humidity [%](Monthly): numeric, range 82.00168010752688 - 91.42261904761904
#     Environment:Site Diffuse Solar Radiation Rate per Area [W/m2](Monthly): numeric, range 16.168430779569892 - 50.771673387096776
#     ZONE1_FRONTPERIMETER:Zone Mean Radiant Temperature [C](Monthly): numeric, range 14.755256667912832 - 15.42561931456805
#     ZONE1_RIGHTPERIMETER:Zone Mean Radiant Temperature [C](Monthly): numeric, range 15.793842438697434 - 16.04456739626744
#     ZONE1_REARPERIMETER:Zone Mean Radiant Temperature [C](Monthly): numeric, range 14.430262679167756 - 14.973945227640154
#     ZONE1_LEFTPERIMETER:Zone Mean Radiant Temperature [C](Monthly): numeric, range 14.59604678966464 - 15.226306546600382
#     ZONE1_CORE:Zone Mean Radiant Temperature [C](Monthly): numeric, range 16.363010270313726 - 16.62241826280507
#     ZONE2_FRONTPERIMETER:Zone Mean Radiant Temperature [C](Monthly): numeric, range 16.07228599326114 - 16.783176206913403
#     ZONE2_RIGHTPERIMETER:Zone Mean Radiant Temperature [C](Monthly): numeric, range 17.332975702090266 - 17.49795456377327
#     ZONE2_REARPERIMETER:Zone Mean Radiant Temperature [C](Monthly): numeric, range 15.67962007529633 - 16.168544472168477
#     ZONE2_LEFTPERIMETER:Zone Mean Radiant Temperature [C](Monthly): numeric, range 15.75716216022071 - 16.354600991694802
#     ZONE2_CORE:Zone Mean Radiant Temperature [C](Monthly): numeric, range 16.31026105853198 - 16.817381763554163
#     ZONE1_FRONTPERIMETER:Zone Windows Total Transmitted Solar Radiation Rate [W](Monthly): numeric, range 38.282806275677984 - 63.23097317279285
#     ZONE1_FRONTPERIMETER:Zone Windows Total Transmitted Solar Radiation Energy [J](Monthly): numeric, range 102536668.32877594 - 169357838.54600856
#     ZONE1_RIGHTPERIMETER:Zone Windows Total Transmitted Solar Radiation Rate [W](Monthly): numeric, range 0.0 - 0.0
#     ZONE1_RIGHTPERIMETER:Zone Windows Total Transmitted Solar Radiation Energy [J](Monthly): numeric, range 0.0 - 0.0
#     ZONE1_REARPERIMETER:Zone Windows Total Transmitted Solar Radiation Rate [W](Monthly): numeric, range 8.605876689700064 - 28.40195514407641
#     ZONE1_REARPERIMETER:Zone Windows Total Transmitted Solar Radiation Energy [J](Monthly): numeric, range 23049980.125692643 - 76071796.65789422
#     ZONE1_LEFTPERIMETER:Zone Windows Total Transmitted Solar Radiation Rate [W](Monthly): numeric, range 10.619615597640292 - 33.144175959477515
#     ZONE1_LEFTPERIMETER:Zone Windows Total Transmitted Solar Radiation Energy [J](Monthly): numeric, range 28443578.41671975 - 88773360.88986461
#     ZONE1_CORE:Zone Windows Total Transmitted Solar Radiation Rate [W](Monthly): numeric, range 0.0 - 0.0
#     ZONE1_CORE:Zone Windows Total Transmitted Solar Radiation Energy [J](Monthly): numeric, range 0.0 - 0.0
#     ZONE2_FRONTPERIMETER:Zone Windows Total Transmitted Solar Radiation Rate [W](Monthly): numeric, range 38.282806275677984 - 63.23097317279285
#     ZONE2_FRONTPERIMETER:Zone Windows Total Transmitted Solar Radiation Energy [J](Monthly): numeric, range 102536668.32877596 - 169357838.5460086
#     ZONE2_RIGHTPERIMETER:Zone Windows Total Transmitted Solar Radiation Rate [W](Monthly): numeric, range 0.0 - 0.0
#     ZONE2_RIGHTPERIMETER:Zone Windows Total Transmitted Solar Radiation Energy [J](Monthly): numeric, range 0.0 - 0.0
#     ZONE2_REARPERIMETER:Zone Windows Total Transmitted Solar Radiation Rate [W](Monthly): numeric, range 8.605876689700068 - 28.40195514407642
#     ZONE2_REARPERIMETER:Zone Windows Total Transmitted Solar Radiation Energy [J](Monthly): numeric, range 23049980.12569265 - 76071796.65789422
#     ZONE2_LEFTPERIMETER:Zone Windows Total Transmitted Solar Radiation Rate [W](Monthly): numeric, range 10.619615597640296 - 33.14417595947752
#     ZONE2_LEFTPERIMETER:Zone Windows Total Transmitted Solar Radiation Energy [J](Monthly): numeric, range 28443578.41671975 - 88773360.88986462
#     ZONE2_CORE:Zone Windows Total Transmitted Solar Radiation Rate [W](Monthly): numeric, range 0.0 - 0.0
#     ZONE2_CORE:Zone Windows Total Transmitted Solar Radiation Energy [J](Monthly): numeric, range 0.0 - 0.0
#     ZONE1_FRONTPERIMETER_WALL_0:Surface Outside Face Incident Solar Radiation Rate per Area [W/m2](Monthly): numeric, range 75.25538743024376 - 126.52491901235184
#     ZONE1_FRONTPERIMETER_WALL_0 WINDOW:Surface Outside Face Incident Solar Radiation Rate per Area [W/m2](Monthly): numeric, range 75.25538743024376 - 126.52491901235184
#     ZONE1_FRONTPERIMETER_WALL_0 WINDOW:Surface Window Transmitted Solar Radiation Rate [W](Monthly): numeric, range 38.282806275677984 - 63.23097317279285
#     ZONE1_FRONTPERIMETER_WALL_0 WINDOW:Surface Window Transmitted Beam Solar Radiation Rate [W](Monthly): numeric, range 23.721475826838937 - 25.97489976193163
#     ZONE1_FRONTPERIMETER_WALL_0 WINDOW:Surface Window Transmitted Diffuse Solar Radiation Rate [W](Monthly): numeric, range 14.561330448839042 - 37.25607341086123
#     ZONE1_FRONTPERIMETER_WALL_0 WINDOW:Surface Window Heat Gain Rate [W](Monthly): numeric, range 20.8014446572916 - 41.60985844017184
#     ZONE1_FRONTPERIMETER_WALL_0 WINDOW:Surface Window Heat Loss Rate [W](Monthly): numeric, range 77.79655939700734 - 107.4045098422942
#     ZONE1_FRONTPERIMETER_WALL_0 WINDOW:Surface Window Shading Device Absorbed Solar Radiation Rate [W](Monthly): numeric, range 163.36908503463138 - 261.73223579724817
#     ZONE1_FRONTPERIMETER_WALL_0 WINDOW:Surface Window Heat Gain Energy [J](Monthly): numeric, range 55714589.37008983 - 111447844.84615624
#     ZONE1_FRONTPERIMETER_WALL_0 WINDOW:Surface Window Heat Loss Energy [J](Monthly): numeric, range 208370304.6889445 - 287672239.16160023
#     ZONE1_REARPERIMETER_WALL_0:Surface Outside Face Incident Solar Radiation Rate per Area [W/m2](Monthly): numeric, range 10.356953273342857 - 31.644356352697468
#     ZONE1_REARPERIMETER_WALL_0 WINDOW:Surface Outside Face Incident Solar Radiation Rate per Area [W/m2](Monthly): numeric, range 10.356953273342857 - 31.644356352697468
#     ZONE1_REARPERIMETER_WALL_0 WINDOW:Surface Window Transmitted Solar Radiation Rate [W](Monthly): numeric, range 8.605876689700064 - 28.40195514407641
#     ZONE1_REARPERIMETER_WALL_0 WINDOW:Surface Window Transmitted Beam Solar Radiation Rate [W](Monthly): numeric, range 0.0 - 0.0068180285651012
#     ZONE1_REARPERIMETER_WALL_0 WINDOW:Surface Window Transmitted Diffuse Solar Radiation Rate [W](Monthly): numeric, range 8.605876689700064 - 28.395137115511304
#     ZONE1_REARPERIMETER_WALL_0 WINDOW:Surface Window Heat Gain Rate [W](Monthly): numeric, range 0.0 - 1.7037358393276592
#     ZONE1_REARPERIMETER_WALL_0 WINDOW:Surface Window Heat Loss Rate [W](Monthly): numeric, range 87.68234101895226 - 128.36261985569553
#     ZONE1_REARPERIMETER_WALL_0 WINDOW:Surface Window Shading Device Absorbed Solar Radiation Rate [W](Monthly): numeric, range 19.81093502665826 - 59.478399970817925
#     ZONE1_REARPERIMETER_WALL_0 WINDOW:Surface Window Heat Gain Energy [J](Monthly): numeric, range 0.0 - 4563286.072055203
#     ZONE1_REARPERIMETER_WALL_0 WINDOW:Surface Window Heat Loss Energy [J](Monthly): numeric, range 234848382.18516204 - 343806441.02149427
#     ZONE1_LEFTPERIMETER_WALL_0:Surface Outside Face Incident Solar Radiation Rate per Area [W/m2](Monthly): numeric, range 20.63738151462437 - 61.716970638070464
#     ZONE1_LEFTPERIMETER_WALL_0 WINDOW:Surface Outside Face Incident Solar Radiation Rate per Area [W/m2](Monthly): numeric, range 20.63738151462437 - 61.716970638070464
#     ZONE1_LEFTPERIMETER_WALL_0 WINDOW:Surface Window Transmitted Solar Radiation Rate [W](Monthly): numeric, range 10.619615597640292 - 33.144175959477515
#     ZONE1_LEFTPERIMETER_WALL_0 WINDOW:Surface Window Transmitted Beam Solar Radiation Rate [W](Monthly): numeric, range 2.630880418187939 - 7.1452149013350414
#     ZONE1_LEFTPERIMETER_WALL_0 WINDOW:Surface Window Transmitted Diffuse Solar Radiation Rate [W](Monthly): numeric, range 7.988735179452351 - 25.99896105814245
#     ZONE1_LEFTPERIMETER_WALL_0 WINDOW:Surface Window Heat Gain Rate [W](Monthly): numeric, range 0.3439484286931703 - 9.364245253489877
#     ZONE1_LEFTPERIMETER_WALL_0 WINDOW:Surface Window Heat Loss Rate [W](Monthly): numeric, range 68.61312579364073 - 103.4477131332195
#     ZONE1_LEFTPERIMETER_WALL_0 WINDOW:Surface Window Shading Device Absorbed Solar Radiation Rate [W](Monthly): numeric, range 34.92609695913931 - 102.92881912515102
#     ZONE1_LEFTPERIMETER_WALL_0 WINDOW:Surface Window Heat Gain Energy [J](Monthly): numeric, range 921231.4714117874 - 25081194.486947287
#     ZONE1_LEFTPERIMETER_WALL_0 WINDOW:Surface Window Heat Loss Energy [J](Monthly): numeric, range 183773396.1256871 - 277074354.8560151
#     ZONE2_FRONTPERIMETER_WALL_0:Surface Outside Face Incident Solar Radiation Rate per Area [W/m2](Monthly): numeric, range 75.25538743024376 - 126.52491901235184
#     ZONE2_FRONTPERIMETER_ROOF:Surface Outside Face Incident Solar Radiation Rate per Area [W/m2](Monthly): numeric, range 29.41863300096912 - 104.21855616964166
#     ZONE2_FRONTPERIMETER_WALL_0 WINDOW:Surface Outside Face Incident Solar Radiation Rate per Area [W/m2](Monthly): numeric, range 75.25538743024373 - 126.52491901235184
#     ZONE2_FRONTPERIMETER_WALL_0 WINDOW:Surface Window Transmitted Solar Radiation Rate [W](Monthly): numeric, range 38.282806275677984 - 63.23097317279285
#     ZONE2_FRONTPERIMETER_WALL_0 WINDOW:Surface Window Transmitted Beam Solar Radiation Rate [W](Monthly): numeric, range 23.72147582683895 - 25.974899761931635
#     ZONE2_FRONTPERIMETER_WALL_0 WINDOW:Surface Window Transmitted Diffuse Solar Radiation Rate [W](Monthly): numeric, range 14.561330448839044 - 37.256073410861234
#     ZONE2_FRONTPERIMETER_WALL_0 WINDOW:Surface Window Heat Gain Rate [W](Monthly): numeric, range 17.997692551961883 - 36.16296767200157
#     ZONE2_FRONTPERIMETER_WALL_0 WINDOW:Surface Window Heat Loss Rate [W](Monthly): numeric, range 84.92888464468793 - 116.63808514334735
#     ZONE2_FRONTPERIMETER_WALL_0 WINDOW:Surface Window Shading Device Absorbed Solar Radiation Rate [W](Monthly): numeric, range 163.3690850346314 - 261.7322357972482
#     ZONE2_FRONTPERIMETER_WALL_0 WINDOW:Surface Window Heat Gain Energy [J](Monthly): numeric, range 48205019.73117471 - 96858892.61268902
#     ZONE2_FRONTPERIMETER_WALL_0 WINDOW:Surface Window Heat Loss Energy [J](Monthly): numeric, range 227473524.63233227 - 312403447.2479419
#     ZONE2_RIGHTPERIMETER_ROOF:Surface Outside Face Incident Solar Radiation Rate per Area [W/m2](Monthly): numeric, range 29.41863300096912 - 104.21855616964166
#     ZONE2_REARPERIMETER_WALL_0:Surface Outside Face Incident Solar Radiation Rate per Area [W/m2](Monthly): numeric, range 10.356953273342857 - 31.644356352697468
#     ZONE2_REARPERIMETER_ROOF:Surface Outside Face Incident Solar Radiation Rate per Area [W/m2](Monthly): numeric, range 29.41863300096912 - 104.21855616964166
#     ZONE2_REARPERIMETER_WALL_0 WINDOW:Surface Outside Face Incident Solar Radiation Rate per Area [W/m2](Monthly): numeric, range 10.356953273342857 - 31.644356352697464
#     ZONE2_REARPERIMETER_WALL_0 WINDOW:Surface Window Transmitted Solar Radiation Rate [W](Monthly): numeric, range 8.605876689700068 - 28.40195514407642
#     ZONE2_REARPERIMETER_WALL_0 WINDOW:Surface Window Transmitted Beam Solar Radiation Rate [W](Monthly): numeric, range 0.0 - 0.0068180285651012
#     ZONE2_REARPERIMETER_WALL_0 WINDOW:Surface Window Transmitted Diffuse Solar Radiation Rate [W](Monthly): numeric, range 8.605876689700068 - 28.395137115511314
#     ZONE2_REARPERIMETER_WALL_0 WINDOW:Surface Window Heat Gain Rate [W](Monthly): numeric, range 0.0 - 0.7029543710535375
#     ZONE2_REARPERIMETER_WALL_0 WINDOW:Surface Window Heat Loss Rate [W](Monthly): numeric, range 96.9658008218888 - 138.85685988164622
#     ZONE2_REARPERIMETER_WALL_0 WINDOW:Surface Window Shading Device Absorbed Solar Radiation Rate [W](Monthly): numeric, range 19.810935026658267 - 59.47839997081795
#     ZONE2_REARPERIMETER_WALL_0 WINDOW:Surface Window Heat Gain Energy [J](Monthly): numeric, range 0.0 - 1882792.987429795
#     ZONE2_REARPERIMETER_WALL_0 WINDOW:Surface Window Heat Loss Energy [J](Monthly): numeric, range 259713200.9213464 - 371914213.5070013
#     ZONE2_LEFTPERIMETER_WALL_0:Surface Outside Face Incident Solar Radiation Rate per Area [W/m2](Monthly): numeric, range 20.63738151462437 - 61.716970638070464
#     ZONE2_LEFTPERIMETER_ROOF:Surface Outside Face Incident Solar Radiation Rate per Area [W/m2](Monthly): numeric, range 29.41863300096912 - 104.21855616964166
#     ZONE2_LEFTPERIMETER_WALL_0 WINDOW:Surface Outside Face Incident Solar Radiation Rate per Area [W/m2](Monthly): numeric, range 20.63738151462436 - 61.71697063807044
#     ZONE2_LEFTPERIMETER_WALL_0 WINDOW:Surface Window Transmitted Solar Radiation Rate [W](Monthly): numeric, range 10.619615597640296 - 33.14417595947752
#     ZONE2_LEFTPERIMETER_WALL_0 WINDOW:Surface Window Transmitted Beam Solar Radiation Rate [W](Monthly): numeric, range 2.6308804181879384 - 7.1452149013350414
#     ZONE2_LEFTPERIMETER_WALL_0 WINDOW:Surface Window Transmitted Diffuse Solar Radiation Rate [W](Monthly): numeric, range 7.988735179452352 - 25.998961058142463
#     ZONE2_LEFTPERIMETER_WALL_0 WINDOW:Surface Window Heat Gain Rate [W](Monthly): numeric, range 0.1563508880999566 - 7.091324629157893
#     ZONE2_LEFTPERIMETER_WALL_0 WINDOW:Surface Window Heat Loss Rate [W](Monthly): numeric, range 74.91382264599125 - 111.5530302109892
#     ZONE2_LEFTPERIMETER_WALL_0 WINDOW:Surface Window Shading Device Absorbed Solar Radiation Rate [W](Monthly): numeric, range 34.92609695913931 - 102.92881912515104
#     ZONE2_LEFTPERIMETER_WALL_0 WINDOW:Surface Window Heat Gain Energy [J](Monthly): numeric, range 418770.218686924 - 18993403.886736494
#     ZONE2_LEFTPERIMETER_WALL_0 WINDOW:Surface Window Heat Loss Energy [J](Monthly): numeric, range 200649182.57502288 - 298783636.11711377
#     ZONE2_CORE_ROOF:Surface Outside Face Incident Solar Radiation Rate per Area [W/m2](Monthly): numeric, range 29.41863300096912 - 104.21855616964166
#     ZONE1_FRONTPERIMETER_WALL_0:Surface Inside Face Temperature [C](Monthly): numeric, range 15.32304608493974 - 15.96320412479152
#     ZONE1_FRONTPERIMETER_WALL_0:Surface Outside Face Temperature [C](Monthly): numeric, range 6.384124149218902 - 10.098477757248869
#     ZONE1_FRONTPERIMETER_WALL_0:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -46.7077479481958 - -30.996545038816823
#     ZONE1_FRONTPERIMETER_WALL_1:Surface Inside Face Temperature [C](Monthly): numeric, range 15.630366387120205 - 16.17428622911048
#     ZONE1_FRONTPERIMETER_WALL_1:Surface Outside Face Temperature [C](Monthly): numeric, range 15.63034721726296 - 16.17422135630232
#     ZONE1_FRONTPERIMETER_WALL_1:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -0.0012769187881246 - -0.0003773283685479
#     ZONE1_FRONTPERIMETER_WALL_2:Surface Inside Face Temperature [C](Monthly): numeric, range 15.866070064389676 - 16.340543147335236
#     ZONE1_FRONTPERIMETER_WALL_2:Surface Outside Face Temperature [C](Monthly): numeric, range 16.532350332351022 - 16.785539661541506
#     ZONE1_FRONTPERIMETER_WALL_2:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range 3.632701992052015 - 5.439138463827159
#     ZONE1_FRONTPERIMETER_WALL_3:Surface Inside Face Temperature [C](Monthly): numeric, range 15.630366387120205 - 16.17428622911048
#     ZONE1_FRONTPERIMETER_WALL_3:Surface Outside Face Temperature [C](Monthly): numeric, range 15.630347217262957 - 16.17422135630232
#     ZONE1_FRONTPERIMETER_WALL_3:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -0.0012769187881245 - -0.0003773283685479
#     ZONE1_FRONTPERIMETER_FLOOR:Surface Inside Face Temperature [C](Monthly): numeric, range 11.707841955513503 - 12.689666803751516
#     ZONE1_FRONTPERIMETER_FLOOR:Surface Outside Face Temperature [C](Monthly): numeric, range 2.639426798457865 - 4.550058636738284
#     ZONE1_FRONTPERIMETER_FLOOR:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -224.51500093571784 - -201.51968161840463
#     ZONE1_FRONTPERIMETER_CEILING:Surface Inside Face Temperature [C](Monthly): numeric, range 15.816809996871102 - 16.380101776703224
#     ZONE1_FRONTPERIMETER_CEILING:Surface Outside Face Temperature [C](Monthly): numeric, range 16.365992184660563 - 17.041209891929096
#     ZONE1_FRONTPERIMETER_CEILING:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range 4.688483742749029 - 5.644018905479211
#     ZONE1_FRONTPERIMETER_WALL_0 WINDOW:Surface Inside Face Temperature [C](Monthly): numeric, range 12.33991481740647 - 13.395784212438036
#     ZONE1_FRONTPERIMETER_WALL_0 WINDOW:Surface Outside Face Temperature [C](Monthly): numeric, range 5.3035661796078015 - 7.895733631051465
#     ZONE1_FRONTPERIMETER_WALL_0 WINDOW:Surface Shading Device Is On Time Fraction [](Monthly): numeric, range 1.0 - 1.0
#     ZONE1_FRONTPERIMETER_WALL_0 WINDOW:Surface Window Blind Slat Angle [deg](Monthly): numeric, range 45.0 - 45.0
#     ZONE1_RIGHTPERIMETER_WALL_0:Surface Inside Face Temperature [C](Monthly): numeric, range 16.247840364722407 - 16.440400484341062
#     ZONE1_RIGHTPERIMETER_WALL_0:Surface Outside Face Temperature [C](Monthly): numeric, range 16.247838774287498 - 16.440302141533245
#     ZONE1_RIGHTPERIMETER_WALL_0:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -0.0029502842341367 - -4.77130469799e-05
#     ZONE1_RIGHTPERIMETER_WALL_1:Surface Inside Face Temperature [C](Monthly): numeric, range 16.320932834041223 - 16.50514038966423
#     ZONE1_RIGHTPERIMETER_WALL_1:Surface Outside Face Temperature [C](Monthly): numeric, range 16.320931335897264 - 16.505043549386805
#     ZONE1_RIGHTPERIMETER_WALL_1:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -0.0019061479409744 - -2.94885984738e-05
#     ZONE1_RIGHTPERIMETER_WALL_2:Surface Inside Face Temperature [C](Monthly): numeric, range 16.453092439562926 - 16.63370468865456
#     ZONE1_RIGHTPERIMETER_WALL_2:Surface Outside Face Temperature [C](Monthly): numeric, range 16.69560580011459 - 16.886025221804715
#     ZONE1_RIGHTPERIMETER_WALL_2:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range 0.5237584821639851 - 0.5458801347166282
#     ZONE1_RIGHTPERIMETER_WALL_3:Surface Inside Face Temperature [C](Monthly): numeric, range 16.320932834041226 - 16.505140389664234
#     ZONE1_RIGHTPERIMETER_WALL_3:Surface Outside Face Temperature [C](Monthly): numeric, range 16.32093133589726 - 16.50504354938681
#     ZONE1_RIGHTPERIMETER_WALL_3:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -0.0019061479409744 - -2.94885984738e-05
#     ZONE1_RIGHTPERIMETER_FLOOR:Surface Inside Face Temperature [C](Monthly): numeric, range 12.183506623818642 - 12.87846028358837
#     ZONE1_RIGHTPERIMETER_FLOOR:Surface Outside Face Temperature [C](Monthly): numeric, range 2.639426798457865 - 4.550058636738284
#     ZONE1_RIGHTPERIMETER_FLOOR:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -172.08682712519078 - -150.167249295453
#     ZONE1_RIGHTPERIMETER_CEILING:Surface Inside Face Temperature [C](Monthly): numeric, range 16.50093705697464 - 16.673480426997227
#     ZONE1_RIGHTPERIMETER_CEILING:Surface Outside Face Temperature [C](Monthly): numeric, range 17.30114964082682 - 17.44972524177055
#     ZONE1_RIGHTPERIMETER_CEILING:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range 4.811771696628939 - 4.975319132674064
#     ZONE1_REARPERIMETER_WALL_0:Surface Inside Face Temperature [C](Monthly): numeric, range 14.927541306809497 - 15.39794111980724
#     ZONE1_REARPERIMETER_WALL_0:Surface Outside Face Temperature [C](Monthly): numeric, range 3.427496670237674 - 6.058800013746024
#     ZONE1_REARPERIMETER_WALL_0:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -59.20772646762944 - -50.213032151828806
#     ZONE1_REARPERIMETER_WALL_1:Surface Inside Face Temperature [C](Monthly): numeric, range 15.33961078257434 - 15.768962833376504
#     ZONE1_REARPERIMETER_WALL_1:Surface Outside Face Temperature [C](Monthly): numeric, range 15.339613995350945 - 15.768866273367152
#     ZONE1_REARPERIMETER_WALL_1:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -0.001900631306442 - 6.32384343504e-05
#     ZONE1_REARPERIMETER_WALL_2:Surface Inside Face Temperature [C](Monthly): numeric, range 15.629023270616852 - 16.012350465812638
#     ZONE1_REARPERIMETER_WALL_2:Surface Outside Face Temperature [C](Monthly): numeric, range 16.492163194052658 - 16.72928088193948
#     ZONE1_REARPERIMETER_WALL_2:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range 5.85261786931574 - 7.046190294047256
#     ZONE1_REARPERIMETER_WALL_3:Surface Inside Face Temperature [C](Monthly): numeric, range 15.339610782574338 - 15.768962833376508
#     ZONE1_REARPERIMETER_WALL_3:Surface Outside Face Temperature [C](Monthly): numeric, range 15.339613995350945 - 15.768866273367154
#     ZONE1_REARPERIMETER_WALL_3:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -0.0019006313064421 - 6.32384343504e-05
#     ZONE1_REARPERIMETER_FLOOR:Surface Inside Face Temperature [C](Monthly): numeric, range 11.462540361325486 - 12.361193652983522
#     ZONE1_REARPERIMETER_FLOOR:Surface Outside Face Temperature [C](Monthly): numeric, range 2.639426798457865 - 4.550058636738284
#     ZONE1_REARPERIMETER_FLOOR:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -218.44184628908656 - -193.38737310861447
#     ZONE1_REARPERIMETER_CEILING:Surface Inside Face Temperature [C](Monthly): numeric, range 15.503863103044496 - 15.93644962719496
#     ZONE1_REARPERIMETER_CEILING:Surface Outside Face Temperature [C](Monthly): numeric, range 15.95692862725258 - 16.427782548461977
#     ZONE1_REARPERIMETER_CEILING:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range 3.867915587721216 - 4.194612397955577
#     ZONE1_REARPERIMETER_WALL_0 WINDOW:Surface Inside Face Temperature [C](Monthly): numeric, range 11.832380794530556 - 12.727200401763138
#     ZONE1_REARPERIMETER_WALL_0 WINDOW:Surface Outside Face Temperature [C](Monthly): numeric, range 3.872211029700523 - 5.988292018747721
#     ZONE1_REARPERIMETER_WALL_0 WINDOW:Surface Shading Device Is On Time Fraction [](Monthly): numeric, range 1.0 - 1.0
#     ZONE1_REARPERIMETER_WALL_0 WINDOW:Surface Window Blind Slat Angle [deg](Monthly): numeric, range 45.0 - 45.0
#     ZONE1_LEFTPERIMETER_WALL_0:Surface Inside Face Temperature [C](Monthly): numeric, range 15.086298720718592 - 15.665322965512114
#     ZONE1_LEFTPERIMETER_WALL_0:Surface Outside Face Temperature [C](Monthly): numeric, range 3.924547104305202 - 7.26364161143158
#     ZONE1_LEFTPERIMETER_WALL_0:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -47.966364703717176 - -37.60615930260381
#     ZONE1_LEFTPERIMETER_WALL_1:Surface Inside Face Temperature [C](Monthly): numeric, range 15.452690626653942 - 15.966370469698136
#     ZONE1_LEFTPERIMETER_WALL_1:Surface Outside Face Temperature [C](Monthly): numeric, range 15.452687712659309 - 15.96627673661475
#     ZONE1_LEFTPERIMETER_WALL_1:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -0.001844987732539 - -5.73573825951e-05
#     ZONE1_LEFTPERIMETER_WALL_2:Surface Inside Face Temperature [C](Monthly): numeric, range 15.77085535005235 - 16.21408256902389
#     ZONE1_LEFTPERIMETER_WALL_2:Surface Outside Face Temperature [C](Monthly): numeric, range 16.547929340558348 - 16.793782725278387
#     ZONE1_LEFTPERIMETER_WALL_2:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range 1.2541460476509 - 1.6811523395510617
#     ZONE1_LEFTPERIMETER_WALL_3:Surface Inside Face Temperature [C](Monthly): numeric, range 15.452690626653943 - 15.966370469698136
#     ZONE1_LEFTPERIMETER_WALL_3:Surface Outside Face Temperature [C](Monthly): numeric, range 15.452687712659309 - 15.96627673661475
#     ZONE1_LEFTPERIMETER_WALL_3:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -0.0018449877325392 - -5.7357382595e-05
#     ZONE1_LEFTPERIMETER_FLOOR:Surface Inside Face Temperature [C](Monthly): numeric, range 11.541387136367211 - 12.50726464618236
#     ZONE1_LEFTPERIMETER_FLOOR:Surface Outside Face Temperature [C](Monthly): numeric, range 2.639426798457865 - 4.550058636738284
#     ZONE1_LEFTPERIMETER_FLOOR:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -160.50893724447704 - -143.47431706387468
#     ZONE1_LEFTPERIMETER_CEILING:Surface Inside Face Temperature [C](Monthly): numeric, range 15.646743559255944 - 16.164055023111654
#     ZONE1_LEFTPERIMETER_CEILING:Surface Outside Face Temperature [C](Monthly): numeric, range 16.053789845119727 - 16.63694693804658
#     ZONE1_LEFTPERIMETER_CEILING:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range 2.5308089560312697 - 2.9402039402285136
#     ZONE1_LEFTPERIMETER_WALL_0 WINDOW:Surface Inside Face Temperature [C](Monthly): numeric, range 11.983934023916142 - 13.01081170992639
#     ZONE1_LEFTPERIMETER_WALL_0 WINDOW:Surface Outside Face Temperature [C](Monthly): numeric, range 4.089637708238446 - 6.548700981599092
#     ZONE1_LEFTPERIMETER_WALL_0 WINDOW:Surface Shading Device Is On Time Fraction [](Monthly): numeric, range 1.0 - 1.0
#     ZONE1_LEFTPERIMETER_WALL_0 WINDOW:Surface Window Blind Slat Angle [deg](Monthly): numeric, range 45.0 - 45.0
#     ZONE1_CORE_WALL_0:Surface Inside Face Temperature [C](Monthly): numeric, range 16.532350332351022 - 16.785539661541506
#     ZONE1_CORE_WALL_0:Surface Outside Face Temperature [C](Monthly): numeric, range 15.866070064389676 - 16.340543147335236
#     ZONE1_CORE_WALL_0:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -5.439138463827159 - -3.632701992052015
#     ZONE1_CORE_WALL_1:Surface Inside Face Temperature [C](Monthly): numeric, range 16.69560580011459 - 16.886025221804715
#     ZONE1_CORE_WALL_1:Surface Outside Face Temperature [C](Monthly): numeric, range 16.453092439562926 - 16.63370468865456
#     ZONE1_CORE_WALL_1:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -0.5458801347166282 - -0.5237584821639851
#     ZONE1_CORE_WALL_2:Surface Inside Face Temperature [C](Monthly): numeric, range 16.492163194052658 - 16.72928088193948
#     ZONE1_CORE_WALL_2:Surface Outside Face Temperature [C](Monthly): numeric, range 15.629023270616852 - 16.012350465812638
#     ZONE1_CORE_WALL_2:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -7.046190294047256 - -5.85261786931574
#     ZONE1_CORE_WALL_3:Surface Inside Face Temperature [C](Monthly): numeric, range 16.547929340558348 - 16.793782725278387
#     ZONE1_CORE_WALL_3:Surface Outside Face Temperature [C](Monthly): numeric, range 15.77085535005235 - 16.21408256902389
#     ZONE1_CORE_WALL_3:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -1.6811523395510617 - -1.2541460476509
#     ZONE1_CORE_FLOOR:Surface Inside Face Temperature [C](Monthly): numeric, range 12.321563828137048 - 13.04291807127328
#     ZONE1_CORE_FLOOR:Surface Outside Face Temperature [C](Monthly): numeric, range 2.639426798457865 - 4.550058636738284
#     ZONE1_CORE_FLOOR:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -13.774777147183842 - -12.082791814913454
#     ZONE1_CORE_CEILING:Surface Inside Face Temperature [C](Monthly): numeric, range 16.75610393826505 - 16.975437823787015
#     ZONE1_CORE_CEILING:Surface Outside Face Temperature [C](Monthly): numeric, range 16.36913303227164 - 16.837526132079955
#     ZONE1_CORE_CEILING:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -0.1898425999080489 - -0.0676575776263596
#     ZONE2_FRONTPERIMETER_WALL_0:Surface Inside Face Temperature [C](Monthly): numeric, range 16.275283613844707 - 16.97927868188507
#     ZONE2_FRONTPERIMETER_WALL_0:Surface Outside Face Temperature [C](Monthly): numeric, range 6.106474459842252 - 9.63738158654814
#     ZONE2_FRONTPERIMETER_WALL_0:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -52.51300520311652 - -38.18261310989534
#     ZONE2_FRONTPERIMETER_WALL_1:Surface Inside Face Temperature [C](Monthly): numeric, range 16.554979542265805 - 17.178805321557313
#     ZONE2_FRONTPERIMETER_WALL_1:Surface Outside Face Temperature [C](Monthly): numeric, range 16.554938810240827 - 17.17873434066135
#     ZONE2_FRONTPERIMETER_WALL_1:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -0.0013971468516238 - -0.0003211942373063
#     ZONE2_FRONTPERIMETER_WALL_2:Surface Inside Face Temperature [C](Monthly): numeric, range 16.53808937677122 - 17.132130267259246
#     ZONE2_FRONTPERIMETER_WALL_2:Surface Outside Face Temperature [C](Monthly): numeric, range 16.352715489065066 - 16.875956711930982
#     ZONE2_FRONTPERIMETER_WALL_2:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -2.0912572459403687 - -1.5132884632720536
#     ZONE2_FRONTPERIMETER_WALL_3:Surface Inside Face Temperature [C](Monthly): numeric, range 16.554979542265805 - 17.178805321557313
#     ZONE2_FRONTPERIMETER_WALL_3:Surface Outside Face Temperature [C](Monthly): numeric, range 16.55493881024083 - 17.17873434066135
#     ZONE2_FRONTPERIMETER_WALL_3:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -0.0013971468516239 - -0.0003211942373062
#     ZONE2_FRONTPERIMETER_FLOOR:Surface Inside Face Temperature [C](Monthly): numeric, range 16.365992184660563 - 17.041209891929096
#     ZONE2_FRONTPERIMETER_FLOOR:Surface Outside Face Temperature [C](Monthly): numeric, range 15.816809996871102 - 16.380101776703224
#     ZONE2_FRONTPERIMETER_FLOOR:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -5.644018905479211 - -4.688483742749029
#     ZONE2_FRONTPERIMETER_ROOF:Surface Inside Face Temperature [C](Monthly): numeric, range 15.977840033477175 - 16.756872841336932
#     ZONE2_FRONTPERIMETER_ROOF:Surface Outside Face Temperature [C](Monthly): numeric, range 2.60847252704894 - 6.4597810206073545
#     ZONE2_FRONTPERIMETER_ROOF:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -45.65483994084524 - -35.1633746851194
#     ZONE2_FRONTPERIMETER_WALL_0 WINDOW:Surface Inside Face Temperature [C](Monthly): numeric, range 12.966203347926635 - 14.07303033452692
#     ZONE2_FRONTPERIMETER_WALL_0 WINDOW:Surface Outside Face Temperature [C](Monthly): numeric, range 5.174580016249677 - 7.725725467903983
#     ZONE2_FRONTPERIMETER_WALL_0 WINDOW:Surface Shading Device Is On Time Fraction [](Monthly): numeric, range 1.0 - 1.0
#     ZONE2_FRONTPERIMETER_WALL_0 WINDOW:Surface Window Blind Slat Angle [deg](Monthly): numeric, range 45.0 - 45.0
#     ZONE2_RIGHTPERIMETER_WALL_0:Surface Inside Face Temperature [C](Monthly): numeric, range 17.439042500287233 - 17.581203935788988
#     ZONE2_RIGHTPERIMETER_WALL_0:Surface Outside Face Temperature [C](Monthly): numeric, range 17.43899172108482 - 17.58110194374351
#     ZONE2_RIGHTPERIMETER_WALL_0:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -0.0030597613635108 - 0.0023619505300315
#     ZONE2_RIGHTPERIMETER_WALL_1:Surface Inside Face Temperature [C](Monthly): numeric, range 17.457983464719508 - 17.596282983732483
#     ZONE2_RIGHTPERIMETER_WALL_1:Surface Outside Face Temperature [C](Monthly): numeric, range 17.457933264283373 - 17.596182835187168
#     ZONE2_RIGHTPERIMETER_WALL_1:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -0.0019712659698587 - 0.0015197118662214
#     ZONE2_RIGHTPERIMETER_WALL_2:Surface Inside Face Temperature [C](Monthly): numeric, range 17.257093806702724 - 17.46015672613061
#     ZONE2_RIGHTPERIMETER_WALL_2:Surface Outside Face Temperature [C](Monthly): numeric, range 16.537550411684123 - 16.97344891972324
#     ZONE2_RIGHTPERIMETER_WALL_2:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -1.556688393541995 - -1.05296275183104
#     ZONE2_RIGHTPERIMETER_WALL_3:Surface Inside Face Temperature [C](Monthly): numeric, range 17.457983464719508 - 17.596282983732483
#     ZONE2_RIGHTPERIMETER_WALL_3:Surface Outside Face Temperature [C](Monthly): numeric, range 17.457933264283373 - 17.596182835187168
#     ZONE2_RIGHTPERIMETER_WALL_3:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -0.0019712659698585 - 0.0015197118662214
#     ZONE2_RIGHTPERIMETER_FLOOR:Surface Inside Face Temperature [C](Monthly): numeric, range 17.30114964082682 - 17.44972524177055
#     ZONE2_RIGHTPERIMETER_FLOOR:Surface Outside Face Temperature [C](Monthly): numeric, range 16.50093705697464 - 16.673480426997227
#     ZONE2_RIGHTPERIMETER_FLOOR:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -4.975319132674064 - -4.811771696628939
#     ZONE2_RIGHTPERIMETER_ROOF:Surface Inside Face Temperature [C](Monthly): numeric, range 16.7304047192869 - 17.043902580729902
#     ZONE2_RIGHTPERIMETER_ROOF:Surface Outside Face Temperature [C](Monthly): numeric, range 2.625736342459442 - 6.468217280311303
#     ZONE2_RIGHTPERIMETER_ROOF:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -35.07829186961014 - -26.30171555814148
#     ZONE2_REARPERIMETER_WALL_0:Surface Inside Face Temperature [C](Monthly): numeric, range 15.827442967977454 - 16.269409068083483
#     ZONE2_REARPERIMETER_WALL_0:Surface Outside Face Temperature [C](Monthly): numeric, range 3.4634081355890647 - 6.011418744030581
#     ZONE2_REARPERIMETER_WALL_0:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -63.14597671658763 - -54.55657229593773
#     ZONE2_REARPERIMETER_WALL_1:Surface Inside Face Temperature [C](Monthly): numeric, range 16.196129735081243 - 16.60638912878664
#     ZONE2_REARPERIMETER_WALL_1:Surface Outside Face Temperature [C](Monthly): numeric, range 16.196119294557285 - 16.606268128409763
#     ZONE2_REARPERIMETER_WALL_1:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -0.0023817013470899 - 0.0005738039394856
#     ZONE2_REARPERIMETER_WALL_2:Surface Inside Face Temperature [C](Monthly): numeric, range 16.24842618245477 - 16.670799745719325
#     ZONE2_REARPERIMETER_WALL_2:Surface Outside Face Temperature [C](Monthly): numeric, range 16.298325466916364 - 16.78983273637612
#     ZONE2_REARPERIMETER_WALL_2:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range 0.4073497752872468 - 0.9717185831224284
#     ZONE2_REARPERIMETER_WALL_3:Surface Inside Face Temperature [C](Monthly): numeric, range 16.196129735081243 - 16.60638912878664
#     ZONE2_REARPERIMETER_WALL_3:Surface Outside Face Temperature [C](Monthly): numeric, range 16.196119294557285 - 16.606268128409763
#     ZONE2_REARPERIMETER_WALL_3:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -0.00238170134709 - 0.0005738039394856
#     ZONE2_REARPERIMETER_FLOOR:Surface Inside Face Temperature [C](Monthly): numeric, range 15.95692862725258 - 16.427782548461977
#     ZONE2_REARPERIMETER_FLOOR:Surface Outside Face Temperature [C](Monthly): numeric, range 15.503863103044496 - 15.93644962719496
#     ZONE2_REARPERIMETER_FLOOR:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -4.194612397955577 - -3.867915587721216
#     ZONE2_REARPERIMETER_ROOF:Surface Inside Face Temperature [C](Monthly): numeric, range 15.635420961229348 - 16.197599696772162
#     ZONE2_REARPERIMETER_ROOF:Surface Outside Face Temperature [C](Monthly): numeric, range 2.600837731292828 - 6.449314893960071
#     ZONE2_REARPERIMETER_ROOF:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -44.51159045274549 - -33.289262349633866
#     ZONE2_REARPERIMETER_WALL_0 WINDOW:Surface Inside Face Temperature [C](Monthly): numeric, range 12.439182258157343 - 13.312243786931443
#     ZONE2_REARPERIMETER_WALL_0 WINDOW:Surface Outside Face Temperature [C](Monthly): numeric, range 3.886144161095644 - 5.979699546464629
#     ZONE2_REARPERIMETER_WALL_0 WINDOW:Surface Shading Device Is On Time Fraction [](Monthly): numeric, range 1.0 - 1.0
#     ZONE2_REARPERIMETER_WALL_0 WINDOW:Surface Window Blind Slat Angle [deg](Monthly): numeric, range 45.0 - 45.0
#     ZONE2_LEFTPERIMETER_WALL_0:Surface Inside Face Temperature [C](Monthly): numeric, range 15.91589380520844 - 16.482113817135552
#     ZONE2_LEFTPERIMETER_WALL_0:Surface Outside Face Temperature [C](Monthly): numeric, range 3.902030542452636 - 7.0453242621786005
#     ZONE2_LEFTPERIMETER_WALL_0:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -51.213000050102735 - -41.73980863708393
#     ZONE2_LEFTPERIMETER_WALL_1:Surface Inside Face Temperature [C](Monthly): numeric, range 16.252812285194395 - 16.76860777991341
#     ZONE2_LEFTPERIMETER_WALL_1:Surface Outside Face Temperature [C](Monthly): numeric, range 16.252795140233246 - 16.768493812614285
#     ZONE2_LEFTPERIMETER_WALL_1:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -0.0022432663176091 - 0.0003472765900298
#     ZONE2_LEFTPERIMETER_WALL_2:Surface Inside Face Temperature [C](Monthly): numeric, range 16.319003559032698 - 16.82055905164311
#     ZONE2_LEFTPERIMETER_WALL_2:Surface Outside Face Temperature [C](Monthly): numeric, range 16.311031530839465 - 16.81749045901585
#     ZONE2_LEFTPERIMETER_WALL_2:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -0.0172469983705175 - 0.0034541341892997
#     ZONE2_LEFTPERIMETER_WALL_3:Surface Inside Face Temperature [C](Monthly): numeric, range 16.252812285194395 - 16.76860777991341
#     ZONE2_LEFTPERIMETER_WALL_3:Surface Outside Face Temperature [C](Monthly): numeric, range 16.252795140233246 - 16.768493812614285
#     ZONE2_LEFTPERIMETER_WALL_3:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -0.0022432663176091 - 0.0003472765900298
#     ZONE2_LEFTPERIMETER_FLOOR:Surface Inside Face Temperature [C](Monthly): numeric, range 16.053789845119727 - 16.63694693804658
#     ZONE2_LEFTPERIMETER_FLOOR:Surface Outside Face Temperature [C](Monthly): numeric, range 15.646743559255944 - 16.164055023111654
#     ZONE2_LEFTPERIMETER_FLOOR:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -2.9402039402285136 - -2.5308089560312697
#     ZONE2_LEFTPERIMETER_ROOF:Surface Inside Face Temperature [C](Monthly): numeric, range 15.702553112190428 - 16.363047726480804
#     ZONE2_LEFTPERIMETER_ROOF:Surface Outside Face Temperature [C](Monthly): numeric, range 2.6023678072140446 - 6.452562111355594
#     ZONE2_LEFTPERIMETER_ROOF:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -32.58014377912668 - -24.64736480781613
#     ZONE2_LEFTPERIMETER_WALL_0 WINDOW:Surface Inside Face Temperature [C](Monthly): numeric, range 12.536495091550515 - 13.546092074046358
#     ZONE2_LEFTPERIMETER_WALL_0 WINDOW:Surface Outside Face Temperature [C](Monthly): numeric, range 4.067218124568153 - 6.456710108274589
#     ZONE2_LEFTPERIMETER_WALL_0 WINDOW:Surface Shading Device Is On Time Fraction [](Monthly): numeric, range 1.0 - 1.0
#     ZONE2_LEFTPERIMETER_WALL_0 WINDOW:Surface Window Blind Slat Angle [deg](Monthly): numeric, range 45.0 - 45.0
#     ZONE2_CORE_WALL_0:Surface Inside Face Temperature [C](Monthly): numeric, range 16.352715489065066 - 16.875956711930982
#     ZONE2_CORE_WALL_0:Surface Outside Face Temperature [C](Monthly): numeric, range 16.53808937677122 - 17.132130267259246
#     ZONE2_CORE_WALL_0:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range 1.5132884632720536 - 2.0912572459403687
#     ZONE2_CORE_WALL_1:Surface Inside Face Temperature [C](Monthly): numeric, range 16.537550411684123 - 16.97344891972324
#     ZONE2_CORE_WALL_1:Surface Outside Face Temperature [C](Monthly): numeric, range 17.257093806702724 - 17.46015672613061
#     ZONE2_CORE_WALL_1:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range 1.05296275183104 - 1.556688393541995
#     ZONE2_CORE_WALL_2:Surface Inside Face Temperature [C](Monthly): numeric, range 16.298325466916364 - 16.78983273637612
#     ZONE2_CORE_WALL_2:Surface Outside Face Temperature [C](Monthly): numeric, range 16.24842618245477 - 16.670799745719325
#     ZONE2_CORE_WALL_2:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -0.9717185831224284 - -0.4073497752872468
#     ZONE2_CORE_WALL_3:Surface Inside Face Temperature [C](Monthly): numeric, range 16.311031530839465 - 16.81749045901585
#     ZONE2_CORE_WALL_3:Surface Outside Face Temperature [C](Monthly): numeric, range 16.319003559032698 - 16.82055905164311
#     ZONE2_CORE_WALL_3:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -0.0034541341892997 - 0.0172469983705175
#     ZONE2_CORE_FLOOR:Surface Inside Face Temperature [C](Monthly): numeric, range 16.36913303227164 - 16.837526132079955
#     ZONE2_CORE_FLOOR:Surface Outside Face Temperature [C](Monthly): numeric, range 16.75610393826505 - 16.975437823787015
#     ZONE2_CORE_FLOOR:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range 0.0676575776263596 - 0.1898425999080489
#     ZONE2_CORE_ROOF:Surface Inside Face Temperature [C](Monthly): numeric, range 15.499093719322484 - 16.19839449233175
#     ZONE2_CORE_ROOF:Surface Outside Face Temperature [C](Monthly): numeric, range 2.5980124089919543 - 6.448977978574685
#     ZONE2_CORE_ROOF:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly): numeric, range -2.5316371640818858 - -1.9131718172008587
#     ZONE1_FRONTPERIMETER:Zone Mean Air Temperature [C](Monthly): numeric, range 18.08295794960164 - 18.103739337086093
#     ZONE1_FRONTPERIMETER:Zone Air Heat Balance Internal Convective Heat Gain Rate [W](Monthly): numeric, range 1.1472021863164066 - 1.1705339137973427
#     ZONE1_FRONTPERIMETER:Zone Air Heat Balance Surface Convection Rate [W](Monthly): numeric, range -357.4714986258339 - -270.2352640957111
#     ZONE1_FRONTPERIMETER:Zone Air Heat Balance Interzone Air Transfer Rate [W](Monthly): numeric, range 0.0 - 0.0
#     ZONE1_FRONTPERIMETER:Zone Air Heat Balance Outdoor Air Transfer Rate [W](Monthly): numeric, range 0.0 - 0.0
#     ZONE1_FRONTPERIMETER:Zone Air Heat Balance System Air Transfer Rate [W](Monthly): numeric, range 269.3924852880551 - 356.6798827936513
#     ZONE1_FRONTPERIMETER:Zone Air Heat Balance Air Energy Storage Rate [W](Monthly): numeric, range 0.3530386526243291 - 0.3992416367881399
#     ZONE1_RIGHTPERIMETER:Zone Mean Air Temperature [C](Monthly): numeric, range 18.03366472170891 - 18.0641867846182
#     ZONE1_RIGHTPERIMETER:Zone Air Heat Balance Internal Convective Heat Gain Rate [W](Monthly): numeric, range 0.835486738373829 - 0.8524788162535483
#     ZONE1_RIGHTPERIMETER:Zone Air Heat Balance Surface Convection Rate [W](Monthly): numeric, range -165.94502507580358 - -144.24078262777329
#     ZONE1_RIGHTPERIMETER:Zone Air Heat Balance Interzone Air Transfer Rate [W](Monthly): numeric, range 0.0 - 0.0
#     ZONE1_RIGHTPERIMETER:Zone Air Heat Balance Outdoor Air Transfer Rate [W](Monthly): numeric, range 0.0 - 0.0
#     ZONE1_RIGHTPERIMETER:Zone Air Heat Balance System Air Transfer Rate [W](Monthly): numeric, range 143.47465466111126 - 165.16625714617427
# ...
#     ZONE1_REARPERIMETER_WALL_0 WINDOW:Surface Window Blind Slat Angle [deg](Monthly)
#     ZONE1_LEFTPERIMETER_WALL_0:Surface Inside Face Temperature [C](Monthly)
#     ZONE1_LEFTPERIMETER_WALL_0:Surface Outside Face Temperature [C](Monthly)
#     ZONE1_LEFTPERIMETER_WALL_0:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly)
#     ZONE1_LEFTPERIMETER_WALL_1:Surface Inside Face Temperature [C](Monthly)
#     ZONE1_LEFTPERIMETER_WALL_1:Surface Outside Face Temperature [C](Monthly)
#     ZONE1_LEFTPERIMETER_WALL_1:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly)
#     ZONE1_LEFTPERIMETER_WALL_2:Surface Inside Face Temperature [C](Monthly)
#     ZONE1_LEFTPERIMETER_WALL_2:Surface Outside Face Temperature [C](Monthly)
#     ZONE1_LEFTPERIMETER_WALL_2:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly)
#     ZONE1_LEFTPERIMETER_WALL_3:Surface Inside Face Temperature [C](Monthly)
#     ZONE1_LEFTPERIMETER_WALL_3:Surface Outside Face Temperature [C](Monthly)
#     ZONE1_LEFTPERIMETER_WALL_3:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly)
#     ZONE1_LEFTPERIMETER_FLOOR:Surface Inside Face Temperature [C](Monthly)
#     ZONE1_LEFTPERIMETER_FLOOR:Surface Outside Face Temperature [C](Monthly)
#     ZONE1_LEFTPERIMETER_FLOOR:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly)
#     ZONE1_LEFTPERIMETER_ROOF:Surface Inside Face Temperature [C](Monthly)
#     ZONE1_LEFTPERIMETER_ROOF:Surface Outside Face Temperature [C](Monthly)
#     ZONE1_LEFTPERIMETER_ROOF:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly)
#     ZONE1_LEFTPERIMETER_WALL_0 WINDOW:Surface Inside Face Temperature [C](Monthly)
#     ZONE1_LEFTPERIMETER_WALL_0 WINDOW:Surface Outside Face Temperature [C](Monthly)
#     ZONE1_LEFTPERIMETER_WALL_0 WINDOW:Surface Shading Device Is On Time Fraction [](Monthly)
#     ZONE1_LEFTPERIMETER_WALL_0 WINDOW:Surface Window Blind Slat Angle [deg](Monthly)
#     ZONE1_CORE_WALL_0:Surface Inside Face Temperature [C](Monthly)
#     ZONE1_CORE_WALL_0:Surface Outside Face Temperature [C](Monthly)
#     ZONE1_CORE_WALL_0:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly)
#     ZONE1_CORE_WALL_1:Surface Inside Face Temperature [C](Monthly)
#     ZONE1_CORE_WALL_1:Surface Outside Face Temperature [C](Monthly)
#     ZONE1_CORE_WALL_1:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly)
#     ZONE1_CORE_WALL_2:Surface Inside Face Temperature [C](Monthly)
#     ZONE1_CORE_WALL_2:Surface Outside Face Temperature [C](Monthly)
#     ZONE1_CORE_WALL_2:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly)
#     ZONE1_CORE_WALL_3:Surface Inside Face Temperature [C](Monthly)
#     ZONE1_CORE_WALL_3:Surface Outside Face Temperature [C](Monthly)
#     ZONE1_CORE_WALL_3:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly)
#     ZONE1_CORE_FLOOR:Surface Inside Face Temperature [C](Monthly)
#     ZONE1_CORE_FLOOR:Surface Outside Face Temperature [C](Monthly)
#     ZONE1_CORE_FLOOR:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly)
#     ZONE1_CORE_ROOF:Surface Inside Face Temperature [C](Monthly)
#     ZONE1_CORE_ROOF:Surface Outside Face Temperature [C](Monthly)
#     ZONE1_CORE_ROOF:Surface Inside Face Conduction Heat Transfer Rate [W](Monthly)
#     ZONE1_FRONTPERIMETER:Zone Mean Air Temperature [C](Monthly)
#     ZONE1_FRONTPERIMETER:Zone Air Heat Balance Internal Convective Heat Gain Rate [W](Monthly)
#     ZONE1_FRONTPERIMETER:Zone Air Heat Balance Surface Convection Rate [W](Monthly)
#     ZONE1_FRONTPERIMETER:Zone Air Heat Balance Interzone Air Transfer Rate [W](Monthly)
#     ZONE1_FRONTPERIMETER:Zone Air Heat Balance Outdoor Air Transfer Rate [W](Monthly)
#     ZONE1_FRONTPERIMETER:Zone Air Heat Balance System Air Transfer Rate [W](Monthly)
#     ZONE1_FRONTPERIMETER:Zone Air Heat Balance Air Energy Storage Rate [W](Monthly)
#     ZONE1_RIGHTPERIMETER:Zone Mean Air Temperature [C](Monthly)
#     ZONE1_RIGHTPERIMETER:Zone Air Heat Balance Internal Convective Heat Gain Rate [W](Monthly)
#     ZONE1_RIGHTPERIMETER:Zone Air Heat Balance Surface Convection Rate [W](Monthly)
#     ZONE1_RIGHTPERIMETER:Zone Air Heat Balance Interzone Air Transfer Rate [W](Monthly)
#     ZONE1_RIGHTPERIMETER:Zone Air Heat Balance Outdoor Air Transfer Rate [W](Monthly)
#     ZONE1_RIGHTPERIMETER:Zone Air Heat Balance System Air Transfer Rate [W](Monthly)
#     ZONE1_RIGHTPERIMETER:Zone Air Heat Balance Air Energy Storage Rate [W](Monthly)
#     ZONE1_REARPERIMETER:Zone Mean Air Temperature [C](Monthly)
#     ZONE1_REARPERIMETER:Zone Air Heat Balance Internal Convective Heat Gain Rate [W](Monthly)
#     ZONE1_REARPERIMETER:Zone Air Heat Balance Surface Convection Rate [W](Monthly)
#     ZONE1_REARPERIMETER:Zone Air Heat Balance Interzone Air Transfer Rate [W](Monthly)
#     ZONE1_REARPERIMETER:Zone Air Heat Balance Outdoor Air Transfer Rate [W](Monthly)
#     ZONE1_REARPERIMETER:Zone Air Heat Balance System Air Transfer Rate [W](Monthly)
#     ZONE1_REARPERIMETER:Zone Air Heat Balance Air Energy Storage Rate [W](Monthly)
#     ZONE1_LEFTPERIMETER:Zone Mean Air Temperature [C](Monthly)
#     ZONE1_LEFTPERIMETER:Zone Air Heat Balance Internal Convective Heat Gain Rate [W](Monthly)
#     ZONE1_LEFTPERIMETER:Zone Air Heat Balance Surface Convection Rate [W](Monthly)
#     ZONE1_LEFTPERIMETER:Zone Air Heat Balance Interzone Air Transfer Rate [W](Monthly)
#     ZONE1_LEFTPERIMETER:Zone Air Heat Balance Outdoor Air Transfer Rate [W](Monthly)
#     ZONE1_LEFTPERIMETER:Zone Air Heat Balance System Air Transfer Rate [W](Monthly)
#     ZONE1_LEFTPERIMETER:Zone Air Heat Balance Air Energy Storage Rate [W](Monthly)
#     ZONE1_CORE:Zone Mean Air Temperature [C](Monthly)
#     ZONE1_CORE:Zone Air Heat Balance Internal Convective Heat Gain Rate [W](Monthly)
#     ZONE1_CORE:Zone Air Heat Balance Surface Convection Rate [W](Monthly)
#     ZONE1_CORE:Zone Air Heat Balance Interzone Air Transfer Rate [W](Monthly)
#     ZONE1_CORE:Zone Air Heat Balance Outdoor Air Transfer Rate [W](Monthly)
#     ZONE1_CORE:Zone Air Heat Balance System Air Transfer Rate [W](Monthly)
#     ZONE1_CORE:Zone Air Heat Balance Air Energy Storage Rate [W](Monthly)
#     ZONE1_FRONTPERIMETER:Zone Infiltration Sensible Heat Loss Energy [J](Monthly)
#     ZONE1_FRONTPERIMETER:Zone Infiltration Sensible Heat Gain Energy [J](Monthly)
#     ZONE1_FRONTPERIMETER:Zone Infiltration Latent Heat Loss Energy [J](Monthly)
#     ZONE1_FRONTPERIMETER:Zone Infiltration Latent Heat Gain Energy [J](Monthly)
#     ZONE1_FRONTPERIMETER:Zone Infiltration Standard Density Volume Flow Rate [m3/s](Monthly)
#     ZONE1_RIGHTPERIMETER:Zone Infiltration Sensible Heat Loss Energy [J](Monthly)
#     ZONE1_RIGHTPERIMETER:Zone Infiltration Sensible Heat Gain Energy [J](Monthly)
#     ZONE1_RIGHTPERIMETER:Zone Infiltration Latent Heat Loss Energy [J](Monthly)
#     ZONE1_RIGHTPERIMETER:Zone Infiltration Latent Heat Gain Energy [J](Monthly)
#     ZONE1_RIGHTPERIMETER:Zone Infiltration Standard Density Volume Flow Rate [m3/s](Monthly)
#     ZONE1_REARPERIMETER:Zone Infiltration Sensible Heat Loss Energy [J](Monthly)
#     ZONE1_REARPERIMETER:Zone Infiltration Sensible Heat Gain Energy [J](Monthly)
#     ZONE1_REARPERIMETER:Zone Infiltration Latent Heat Loss Energy [J](Monthly)
#     ZONE1_REARPERIMETER:Zone Infiltration Latent Heat Gain Energy [J](Monthly)
#     ZONE1_REARPERIMETER:Zone Infiltration Standard Density Volume Flow Rate [m3/s](Monthly)
#     ZONE1_LEFTPERIMETER:Zone Infiltration Sensible Heat Loss Energy [J](Monthly)
#     ZONE1_LEFTPERIMETER:Zone Infiltration Sensible Heat Gain Energy [J](Monthly)
#     ZONE1_LEFTPERIMETER:Zone Infiltration Latent Heat Loss Energy [J](Monthly)
#     ZONE1_LEFTPERIMETER:Zone Infiltration Latent Heat Gain Energy [J](Monthly)
#     ZONE1_LEFTPERIMETER:Zone Infiltration Standard Density Volume Flow Rate [m3/s](Monthly)
#     ZONE1_CORE:Zone Infiltration Sensible Heat Loss Energy [J](Monthly)
#     ZONE1_CORE:Zone Infiltration Sensible Heat Gain Energy [J](Monthly)
#     ZONE1_CORE:Zone Infiltration Latent Heat Loss Energy [J](Monthly)
#     ZONE1_CORE:Zone Infiltration Latent Heat Gain Energy [J](Monthly)
#     ZONE1_CORE:Zone Infiltration Standard Density Volume Flow Rate [m3/s](Monthly)
#     ZONE1_FRONTPERIMETER:Zone Ventilation Sensible Heat Loss Energy [J](Monthly)
#     ZONE1_FRONTPERIMETER:Zone Ventilation Sensible Heat Gain Energy [J](Monthly)
#     ZONE1_FRONTPERIMETER:Zone Ventilation Latent Heat Loss Energy [J](Monthly)
#     ZONE1_FRONTPERIMETER:Zone Ventilation Latent Heat Gain Energy [J](Monthly)
#     ZONE1_FRONTPERIMETER:Zone Ventilation Standard Density Volume Flow Rate [m3/s](Monthly)
#     ZONE1_RIGHTPERIMETER:Zone Ventilation Sensible Heat Loss Energy [J](Monthly)
#     ZONE1_RIGHTPERIMETER:Zone Ventilation Sensible Heat Gain Energy [J](Monthly)
#     ZONE1_RIGHTPERIMETER:Zone Ventilation Latent Heat Loss Energy [J](Monthly)
#     ZONE1_RIGHTPERIMETER:Zone Ventilation Latent Heat Gain Energy [J](Monthly)
#     ZONE1_RIGHTPERIMETER:Zone Ventilation Standard Density Volume Flow Rate [m3/s](Monthly)
#     ZONE1_REARPERIMETER:Zone Ventilation Sensible Heat Loss Energy [J](Monthly)
#     ZONE1_REARPERIMETER:Zone Ventilation Sensible Heat Gain Energy [J](Monthly)
#     ZONE1_REARPERIMETER:Zone Ventilation Latent Heat Loss Energy [J](Monthly)
#     ZONE1_REARPERIMETER:Zone Ventilation Latent Heat Gain Energy [J](Monthly)
#     ZONE1_REARPERIMETER:Zone Ventilation Standard Density Volume Flow Rate [m3/s](Monthly)
#     ZONE1_LEFTPERIMETER:Zone Ventilation Sensible Heat Loss Energy [J](Monthly)
#     ZONE1_LEFTPERIMETER:Zone Ventilation Sensible Heat Gain Energy [J](Monthly)
#     ZONE1_LEFTPERIMETER:Zone Ventilation Latent Heat Loss Energy [J](Monthly)
#     ZONE1_LEFTPERIMETER:Zone Ventilation Latent Heat Gain Energy [J](Monthly)
#     ZONE1_LEFTPERIMETER:Zone Ventilation Standard Density Volume Flow Rate [m3/s](Monthly)
#     ZONE1_CORE:Zone Ventilation Sensible Heat Loss Energy [J](Monthly)
#     ZONE1_CORE:Zone Ventilation Sensible Heat Gain Energy [J](Monthly)
#     ZONE1_CORE:Zone Ventilation Latent Heat Loss Energy [J](Monthly)
#     ZONE1_CORE:Zone Ventilation Latent Heat Gain Energy [J](Monthly)
#     ZONE1_CORE:Zone Ventilation Standard Density Volume Flow Rate [m3/s](Monthly)
#     ZONE1_FRONTPERIMETER:Zone Air System Sensible Heating Energy [J](Monthly)
#     ZONE1_FRONTPERIMETER:Zone Air System Sensible Cooling Energy [J](Monthly)
#     ZONE1_FRONTPERIMETER:Zone Air System Sensible Heating Rate [W](Monthly)
#     ZONE1_FRONTPERIMETER:Zone Air System Sensible Cooling Rate [W](Monthly)
#     ZONE1_RIGHTPERIMETER:Zone Air System Sensible Heating Energy [J](Monthly)
#     ZONE1_RIGHTPERIMETER:Zone Air System Sensible Cooling Energy [J](Monthly)
#     ZONE1_RIGHTPERIMETER:Zone Air System Sensible Heating Rate [W](Monthly)
#     ZONE1_RIGHTPERIMETER:Zone Air System Sensible Cooling Rate [W](Monthly)
#     ZONE1_REARPERIMETER:Zone Air System Sensible Heating Energy [J](Monthly)
#     ZONE1_REARPERIMETER:Zone Air System Sensible Cooling Energy [J](Monthly)
#     ZONE1_REARPERIMETER:Zone Air System Sensible Heating Rate [W](Monthly)
#     ZONE1_REARPERIMETER:Zone Air System Sensible Cooling Rate [W](Monthly)
#     ZONE1_LEFTPERIMETER:Zone Air System Sensible Heating Energy [J](Monthly)
#     ZONE1_LEFTPERIMETER:Zone Air System Sensible Cooling Energy [J](Monthly)
#     ZONE1_LEFTPERIMETER:Zone Air System Sensible Heating Rate [W](Monthly)
#     ZONE1_LEFTPERIMETER:Zone Air System Sensible Cooling Rate [W](Monthly)
#     ZONE1_CORE:Zone Air System Sensible Heating Energy [J](Monthly)
#     ZONE1_CORE:Zone Air System Sensible Cooling Energy [J](Monthly)
#     ZONE1_CORE:Zone Air System Sensible Heating Rate [W](Monthly)
#     ZONE1_CORE:Zone Air System Sensible Cooling Rate [W](Monthly)
#     ZONE1_FRONTPERIMETER:Zone Mechanical Ventilation Mass Flow Rate [kg/s](Monthly)
#     ZONE1_RIGHTPERIMETER:Zone Mechanical Ventilation Mass Flow Rate [kg/s](Monthly)
#     ZONE1_REARPERIMETER:Zone Mechanical Ventilation Mass Flow Rate [kg/s](Monthly)
#     ZONE1_LEFTPERIMETER:Zone Mechanical Ventilation Mass Flow Rate [kg/s](Monthly)
#     ZONE1_CORE:Zone Mechanical Ventilation Mass Flow Rate [kg/s](Monthly)
#     ... and 246 more columns
#
# Analyzing: simulation_bldg1_4136737Meter.csv
#   Time columns found: ['Date/Time', 'Heating:EnergyTransfer [J](Monthly)', 'Cooling:EnergyTransfer [J](Monthly)']
#     Date/Time: object, samples: [' 01/01', ' 01/02', ' 01/03']
#     Heating:EnergyTransfer [J](Monthly): numeric, range 2481997768.8676586 - 3491945148.013601
#     Cooling:EnergyTransfer [J](Monthly): numeric, range 0.0 - 0.0
#   EnergyPlus Date/Time column found
#     Samples: [' 01/01', ' 01/02', ' 01/03', ' 01/04', ' 01/05']
#
#   All columns (4):
#     Date/Time
#     Heating:EnergyTransfer [J](Monthly)
#     Cooling:EnergyTransfer [J](Monthly)
#     Electricity:Facility [J](Daily)
#
# ================================================================================
# IDF PARAMETER MODIFICATION ANALYSIS
# ================================================================================
#
# Found 3 original and 9 modified IDFs
#
# Comparing: building_4136733.idf
#
#   Modified file: building_4136733_variant_0.idf
#   Size difference: 12873 characters
#
# ================================================================================
# SUMMARY OF FINDINGS
# ================================================================================
#
# 1. CURRENT PARAMETER STRUCTURE:
#    - Parameters appear to be grouped by high-level categories
#    - Need to extract specific sub-parameters like:
#      * Material properties: conductivity, density, specific heat
#      * Construction layers: individual layer properties
#      * Schedule values: time-specific values
#
# 2. TIME RESOLUTION AVAILABLE:
#    - Check simulation output files for hourly/sub-hourly data
#    - EnergyPlus typically provides hourly or sub-hourly resolution
#    - Need to identify time columns for filtering
#
# 3. REQUIRED ENHANCEMENTS:
#    a) Parameter Extraction:
#       - Parse IDF objects to extract individual properties
#       - Create mapping of high-level to sub-parameters
#       - Store parameter hierarchy in database
#
#    b) Time-Slice Analysis:
#       - Add time filtering to sensitivity calculation
#       - Define time periods (peak hours, months, day types)
#       - Store time-specific sensitivity results
#
# 4. FILES TO UPDATE:
#    - parameter_extractor.py: Add sub-parameter extraction
#    - sensitivity_analysis.py: Add time filtering
#    - database schema: Add time dimension to results
#    - API endpoints: Add time-slice query parameters
#
# ================================================================================
# ANALYSIS COMPLETE - Please run and share the output!
# ================================================================================
# D:\Drives\Temp\ipykernel_1288\1952448774.py:115: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# D:\Drives\Temp\ipykernel_1288\1952448774.py:115: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# D:\Drives\Temp\ipykernel_1288\1952448774.py:115: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# D:\Drives\Temp\ipykernel_1288\1952448774.py:115: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])
# D:\Drives\Temp\ipykernel_1288\1952448774.py:115: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col])

# %%
import os
import pandas as pd
from pathlib import Path
import pyarrow.parquet as pq

def explore_parquet_files(root_dir):
    """
    Traverse directory tree to find parquet files and display their info.
    
    Args:
        root_dir (str): Root directory path to start searching from
    """
    root_path = Path(root_dir)
    
    # Check if the directory exists
    if not root_path.exists():
        print(f"Error: Directory '{root_dir}' does not exist.")
        return
    
    # Counter for found files
    file_count = 0
    
    print(f"Scanning directory: {root_dir}")
    print("-" * 80)
    
    # Walk through all subdirectories
    for dirpath, dirnames, filenames in os.walk(root_dir):
        for filename in filenames:
            # Check if file has .parquet extension
            if filename.lower().endswith('.parquet'):
                file_count += 1
                full_path = Path(dirpath) / filename
                
                # Get relative path from root directory
                try:
                    relative_path = full_path.relative_to(root_path)
                except ValueError:
                    relative_path = full_path
                
                print(f"\nFile #{file_count}")
                print(f"Relative Path: {relative_path}")
                
                try:
                    # Read the parquet file
                    df = pd.read_parquet(full_path, engine='pyarrow')
                    
                    # Display file info
                    print(f"Shape: {df.shape} (rows: {len(df)}, columns: {len(df.columns)})")
                    print(f"Columns: {list(df.columns)}")
                    
                    # Display first row
                    if len(df) > 0:
                        print("\nFirst row data:")
                        first_row = df.iloc[0]
                        for col, value in first_row.items():
                            print(f"  {col}: {value}")
                    else:
                        print("  (File is empty)")
                        
                except Exception as e:
                    print(f"  Error reading file: {str(e)}")
                
                print("-" * 80)
    
    if file_count == 0:
        print("No parquet files found in the specified directory.")
    else:
        print(f"\nTotal parquet files found: {file_count}")


def explore_parquet_files_detailed(root_dir, max_rows_preview=5):
    """
    Enhanced version with more details and options.
    
    Args:
        root_dir (str): Root directory path to start searching from
        max_rows_preview (int): Number of rows to preview (default: 5)
    """
    root_path = Path(root_dir)
    
    if not root_path.exists():
        print(f"Error: Directory '{root_dir}' does not exist.")
        return
    
    parquet_files = []
    
    # Collect all parquet files first
    for dirpath, dirnames, filenames in os.walk(root_dir):
        for filename in filenames:
            if filename.lower().endswith('.parquet'):
                full_path = Path(dirpath) / filename
                relative_path = full_path.relative_to(root_path)
                parquet_files.append((full_path, relative_path))
    
    if not parquet_files:
        print("No parquet files found.")
        return
    
    print(f"Found {len(parquet_files)} parquet file(s)")
    print("=" * 80)
    
    for idx, (full_path, relative_path) in enumerate(parquet_files, 1):
        print(f"\n[{idx}/{len(parquet_files)}] {relative_path}")
        print("-" * 40)
        
        try:
            # Get file size
            file_size = full_path.stat().st_size / (1024 * 1024)  # Convert to MB
            print(f"File size: {file_size:.2f} MB")
            
            # Read parquet metadata without loading all data
            parquet_file = pq.ParquetFile(full_path)
            metadata = parquet_file.metadata
            
            print(f"Number of row groups: {metadata.num_row_groups}")
            print(f"Total rows: {metadata.num_rows}")
            
            # Read just the first few rows
            df_preview = pd.read_parquet(full_path, engine='pyarrow').head(max_rows_preview)
            
            print(f"\nColumn info:")
            for col in df_preview.columns:
                dtype = df_preview[col].dtype
                print(f"  - {col}: {dtype}")
            
            print(f"\nFirst {min(len(df_preview), max_rows_preview)} row(s):")
            print(df_preview.to_string())
            
        except Exception as e:
            print(f"Error processing file: {str(e)}")


# Main execution
if __name__ == "__main__":
    # Your directory path
    directory_path = r"D:\Documents\daily\E_Plus_2040_py\output\2dae68d1-4b75-4c75-9471-7b6d931af865"
    
    # Run the basic explorer
    print("=== BASIC PARQUET FILE EXPLORER ===\n")
    explore_parquet_files(directory_path)
    
    # Uncomment below to run the detailed explorer instead
    # print("\n\n=== DETAILED PARQUET FILE EXPLORER ===\n")
    # explore_parquet_files_detailed(directory_path, max_rows_preview=3)
# Out:
# === BASIC PARQUET FILE EXPLORER ===
#
# Scanning directory: D:\Documents\daily\E_Plus_2040_py\output\2dae68d1-4b75-4c75-9471-7b6d931af865
# --------------------------------------------------------------------------------
#
# File #1
# Relative Path: modified_idfs\modifications_detail_20250623_182931.parquet
# Shape: (363, 10) (rows: 363, columns: 10)
# Columns: ['building_id', 'variant_id', 'category', 'object_type', 'object_name', 'field_name', 'original_value', 'new_value', 'change_type', 'timestamp']
#
# First row data:
#   building_id: 4136733
#   variant_id: variant_0
#   category: lighting
#   object_type: LIGHTS
#   object_name: Lights_ALL_ZONES
#   field_name:
#   original_value: 0.1
#   new_value: 0.2
#   change_type: absolute
#   timestamp: 2025-06-23T18:29:31.991154
# --------------------------------------------------------------------------------
#
# File #2
# Relative Path: modified_idfs\modifications_summary_20250623_182931.parquet
# Shape: (9, 7) (rows: 9, columns: 7)
# Columns: ['building_id', 'variant_id', 'success', 'output_file', 'num_modifications', 'categories_modified', 'timestamp']
#
# First row data:
#   building_id: 4136733
#   variant_id: variant_0
#   success: True
#   output_file: /usr/src/app/output/2dae68d1-4b75-4c75-9471-7b6d931af865/modified_idfs/building_4136733_variant_0.idf
#   num_modifications: 47
#   categories_modified: ['geometry' 'shading' 'dhw' 'site_location' 'materials'
#  'simulation_control' 'ventilation' 'lighting' 'equipment']
#   timestamp: 2025-06-23T18:29:32.020707
# --------------------------------------------------------------------------------
#
# File #3
# Relative Path: parsed_data\analysis_ready\parameter_matrix.parquet
# Shape: (3, 7) (rows: 3, columns: 7)
# Columns: ['building_id', 'ventilation_design_flow_rate', 'infiltration_design_flow_rate', 'lighting_watts_per_zone_floor_area', 'equipment_watts_per_zone_floor_area', 'dhw_tank_volume', 'dhw_heater_maximum_capacity']
#
# First row data:
#   building_id: 4136733
#   ventilation_design_flow_rate: None
#   infiltration_design_flow_rate: 2.900821e-04
#   lighting_watts_per_zone_floor_area: 0
#   equipment_watts_per_zone_floor_area: 0
#   dhw_tank_volume: 0.2775029318369119
#   dhw_heater_maximum_capacity: 4223.210738148823
# --------------------------------------------------------------------------------
#
# File #4
# Relative Path: parsed_data\analysis_ready\feature_sets\extraction_statistics.parquet
# Shape: (1, 6) (rows: 1, columns: 6)
# Columns: ['building_id', 'extraction_date', 'categories_processed', 'variables_extracted', 'data_points_extracted', 'missing_variables_count']
#
# First row data:
#   building_id: 4136738
#   extraction_date: 2025-06-23T18:29:27.535264
#   categories_processed: 7
#   variables_extracted: 28
#   data_points_extracted: 660
#   missing_variables_count: 76
# --------------------------------------------------------------------------------
#
# File #5
# Relative Path: parsed_data\analysis_ready\feature_sets\missing_variables_detail.parquet
# Shape: (76, 3) (rows: 76, columns: 3)
# Columns: ['category', 'variable', 'building_id']
#
# First row data:
#   category: geometry
#   variable: Zone Air Temperature
#   building_id: 4136738
# --------------------------------------------------------------------------------
#
# File #6
# Relative Path: parsed_data\idf_data\by_building\4136733_snapshot.parquet
# Shape: (293, 7) (rows: 293, columns: 7)
# Columns: ['building_id', 'category', 'output_file', 'object_type', 'object_name', 'parameters', 'zone_name']
#
# First row data:
#   building_id: 4136733
#   category: simulation_control
#   output_file: simulation_control
#   object_type: Version
#   object_name: 22.2
#   parameters: {"Version Identifier": "22.2"}
#   zone_name: None
# --------------------------------------------------------------------------------
#
# File #7
# Relative Path: parsed_data\idf_data\by_category\dhw.parquet
# Shape: (3, 54) (rows: 3, columns: 54)
# Columns: ['building_id', 'object_type', 'object_name', 'name', 'tank_volume', 'tank_volume_numeric', 'setpoint_temperature_schedule_name', 'deadband_temperature_difference', 'deadband_temperature_difference_numeric', 'maximum_temperature_limit', 'maximum_temperature_limit_numeric', 'heater_control_type', 'heater_maximum_capacity', 'heater_maximum_capacity_numeric', 'heater_ignition_minimum_flow_rate', 'heater_ignition_minimum_flow_rate_numeric', 'heater_ignition_delay', 'heater_ignition_delay_numeric', 'heater_fuel_type', 'heater_thermal_efficiency', 'heater_thermal_efficiency_numeric', 'off_cycle_parasitic_fuel_consumption_rate', 'off_cycle_parasitic_fuel_consumption_rate_numeric', 'off_cycle_parasitic_fuel_type', 'off_cycle_parasitic_heat_fraction_to_tank', 'off_cycle_parasitic_heat_fraction_to_tank_numeric', 'on_cycle_parasitic_fuel_consumption_rate', 'on_cycle_parasitic_fuel_consumption_rate_numeric', 'on_cycle_parasitic_fuel_type', 'on_cycle_parasitic_heat_fraction_to_tank', 'on_cycle_parasitic_heat_fraction_to_tank_numeric', 'ambient_temperature_indicator', 'ambient_temperature_schedule_name', 'off_cycle_loss_coefficient_to_ambient_temperature', 'off_cycle_loss_coefficient_to_ambient_temperature_numeric', 'off_cycle_loss_fraction_to_zone', 'off_cycle_loss_fraction_to_zone_numeric', 'on_cycle_loss_coefficient_to_ambient_temperature', 'on_cycle_loss_coefficient_to_ambient_temperature_numeric', 'on_cycle_loss_fraction_to_zone', 'on_cycle_loss_fraction_to_zone_numeric', 'peak_use_flow_rate', 'peak_use_flow_rate_numeric', 'use_flow_rate_fraction_schedule_name', 'use_side_effectiveness', 'use_side_effectiveness_numeric', 'source_side_effectiveness', 'source_side_effectiveness_numeric', 'use_side_design_flow_rate', 'source_side_design_flow_rate', 'indirect_water_heating_recovery_time', 'indirect_water_heating_recovery_time_numeric', 'source_side_flow_control_mode', 'end_use_subcategory']
#
# First row data:
#   building_id: 4136733
#   object_type: WATERHEATER:MIXED
#   object_name: MyDHW_0_WaterHeater
#   name: MyDHW_0_WaterHeater
#   tank_volume: 0.2775029318369119
#   tank_volume_numeric: 0.2775029318369119
#   setpoint_temperature_schedule_name: MyDHW_0_Setpoint
#   deadband_temperature_difference: 2
#   deadband_temperature_difference_numeric: 2.0
#   maximum_temperature_limit: 80
#   maximum_temperature_limit_numeric: 80.0
#   heater_control_type: CYCLE
#   heater_maximum_capacity: 4223.210738148823
#   heater_maximum_capacity_numeric: 4223.210738148823
#   heater_ignition_minimum_flow_rate: 0
#   heater_ignition_minimum_flow_rate_numeric: 0.0
#   heater_ignition_delay: 0
#   heater_ignition_delay_numeric: 0.0
#   heater_fuel_type: NaturalGas
#   heater_thermal_efficiency: 0.9
#   heater_thermal_efficiency_numeric: 0.9
#   off_cycle_parasitic_fuel_consumption_rate: 0
#   off_cycle_parasitic_fuel_consumption_rate_numeric: 0.0
#   off_cycle_parasitic_fuel_type: Electricity
#   off_cycle_parasitic_heat_fraction_to_tank: 0
#   off_cycle_parasitic_heat_fraction_to_tank_numeric: 0.0
#   on_cycle_parasitic_fuel_consumption_rate: 0
#   on_cycle_parasitic_fuel_consumption_rate_numeric: 0.0
#   on_cycle_parasitic_fuel_type: Electricity
#   on_cycle_parasitic_heat_fraction_to_tank: 0
#   on_cycle_parasitic_heat_fraction_to_tank_numeric: 0.0
#   ambient_temperature_indicator: SCHEDULE
#   ambient_temperature_schedule_name: Always22C
#   off_cycle_loss_coefficient_to_ambient_temperature: 5
#   off_cycle_loss_coefficient_to_ambient_temperature_numeric: 5.0
#   off_cycle_loss_fraction_to_zone: 1
#   off_cycle_loss_fraction_to_zone_numeric: 1.0
#   on_cycle_loss_coefficient_to_ambient_temperature: 5
#   on_cycle_loss_coefficient_to_ambient_temperature_numeric: 5.0
#   on_cycle_loss_fraction_to_zone: 1
#   on_cycle_loss_fraction_to_zone_numeric: 1.0
#   peak_use_flow_rate: 2.745939e-06
#   peak_use_flow_rate_numeric: 2.745939e-06
#   use_flow_rate_fraction_schedule_name: MyDHW_0_UseFraction
#   use_side_effectiveness: 1
#   use_side_effectiveness_numeric: 1.0
#   source_side_effectiveness: 1
#   source_side_effectiveness_numeric: 1.0
#   use_side_design_flow_rate: autosize
#   source_side_design_flow_rate: autosize
#   indirect_water_heating_recovery_time: 1.5
#   indirect_water_heating_recovery_time_numeric: 1.5
#   source_side_flow_control_mode: IndirectHeatPrimarySetpoint
#   end_use_subcategory: General
# --------------------------------------------------------------------------------
#
# File #8
# Relative Path: parsed_data\idf_data\by_category\equipment.parquet
# Shape: (6, 17) (rows: 6, columns: 17)
# Columns: ['building_id', 'object_type', 'object_name', 'zone_name', 'name', 'zone_or_zonelist_name', 'schedule_name', 'design_level_calculation_method', 'watts_per_zone_floor_area', 'watts_per_zone_floor_area_numeric', 'fraction_latent', 'fraction_latent_numeric', 'fraction_radiant', 'fraction_radiant_numeric', 'fraction_lost', 'fraction_lost_numeric', 'end_use_subcategory']
#
# First row data:
#   building_id: 4136733
#   object_type: ELECTRICEQUIPMENT
#   object_name: Parasitic_ALL_ZONES
#   zone_name: ALL_ZONES
#   name: Parasitic_ALL_ZONES
#   zone_or_zonelist_name: ALL_ZONES
#   schedule_name: ParasiticSchedule
#   design_level_calculation_method: Watts/Area
#   watts_per_zone_floor_area: 0
#   watts_per_zone_floor_area_numeric: 0.0
#   fraction_latent: 0
#   fraction_latent_numeric: 0.0
#   fraction_radiant: 0.1
#   fraction_radiant_numeric: 0.1
#   fraction_lost: 0.8
#   fraction_lost_numeric: 0.8
#   end_use_subcategory: General
# --------------------------------------------------------------------------------
#
# File #9
# Relative Path: parsed_data\idf_data\by_category\geometry_surfaces.parquet
# Shape: (109, 47) (rows: 109, columns: 47)
# Columns: ['building_id', 'object_type', 'object_name', 'starting_vertex_position', 'vertex_entry_direction', 'coordinate_system', 'zone_name', 'name', 'surface_type', 'construction_name', 'outside_boundary_condition', 'sun_exposure', 'wind_exposure', 'view_factor_to_ground', 'number_of_vertices', 'field_12', 'field_12_numeric', 'field_13', 'field_13_numeric', 'field_14', 'field_14_numeric', 'field_15', 'field_15_numeric', 'field_16', 'field_16_numeric', 'field_17', 'field_17_numeric', 'field_18', 'field_18_numeric', 'field_19', 'field_19_numeric', 'field_20', 'field_20_numeric', 'field_21', 'field_21_numeric', 'field_22', 'field_22_numeric', 'field_23', 'field_23_numeric', 'outside_boundary_condition_object', 'building_surface_name', 'multiplier', 'multiplier_numeric', 'field_10', 'field_10_numeric', 'field_11', 'field_11_numeric']
#
# First row data:
#   building_id: 4136733
#   object_type: GlobalGeometryRules
#   object_name: UpperLeftCorner
#   starting_vertex_position: UpperLeftCorner
#   vertex_entry_direction: CounterClockWise
#   coordinate_system: Relative
#   zone_name: None
#   name: None
#   surface_type: None
#   construction_name: None
#   outside_boundary_condition: None
#   sun_exposure: None
#   wind_exposure: None
#   view_factor_to_ground: None
#   number_of_vertices: None
#   field_12: None
#   field_12_numeric: nan
#   field_13: None
#   field_13_numeric: nan
#   field_14: None
#   field_14_numeric: nan
#   field_15: None
#   field_15_numeric: nan
#   field_16: None
#   field_16_numeric: nan
#   field_17: None
#   field_17_numeric: nan
#   field_18: None
#   field_18_numeric: nan
#   field_19: None
#   field_19_numeric: nan
#   field_20: None
#   field_20_numeric: nan
#   field_21: None
#   field_21_numeric: nan
#   field_22: None
#   field_22_numeric: nan
#   field_23: None
#   field_23_numeric: nan
#   outside_boundary_condition_object: None
#   building_surface_name: None
#   multiplier: None
#   multiplier_numeric: nan
#   field_10: None
#   field_10_numeric: nan
#   field_11: None
#   field_11_numeric: nan
# --------------------------------------------------------------------------------
#
# File #10
# Relative Path: parsed_data\idf_data\by_category\geometry_zones.parquet
# Shape: (19, 31) (rows: 19, columns: 31)
# Columns: ['building_id', 'object_type', 'object_name', 'zone_name', 'name', 'direction_of_relative_north', 'direction_of_relative_north_numeric', 'x_origin', 'x_origin_numeric', 'y_origin', 'y_origin_numeric', 'z_origin', 'z_origin_numeric', 'type', 'type_numeric', 'multiplier', 'multiplier_numeric', 'ceiling_height', 'volume', 'floor_area', 'part_of_total_floor_area', 'zone_1_name', 'zone_2_name', 'zone_3_name', 'zone_4_name', 'zone_5_name', 'field_7', 'field_8', 'field_9', 'field_10', 'field_11']
#
# First row data:
#   building_id: 4136733
#   object_type: ZONE
#   object_name: Zone1_FrontPerimeter
#   zone_name: Zone1_FrontPerimeter
#   name: Zone1_FrontPerimeter
#   direction_of_relative_north: 0
#   direction_of_relative_north_numeric: 0.0
#   x_origin: 0
#   x_origin_numeric: 0.0
#   y_origin: 0
#   y_origin_numeric: 0.0
#   z_origin: 0
#   z_origin_numeric: 0.0
#   type: 1
#   type_numeric: 1.0
#   multiplier: 1
#   multiplier_numeric: 1.0
#   ceiling_height: autocalculate
#   volume: autocalculate
#   floor_area: autocalculate
#   part_of_total_floor_area: Yes
#   zone_1_name: None
#   zone_2_name: None
#   zone_3_name: None
#   zone_4_name: None
#   zone_5_name: None
#   field_7: None
#   field_8: None
#   field_9: None
#   field_10: None
#   field_11: None
# --------------------------------------------------------------------------------
#
# File #11
# Relative Path: parsed_data\idf_data\by_category\hvac_equipment.parquet
# Shape: (48, 41) (rows: 48, columns: 41)
# Columns: ['building_id', 'object_type', 'object_name', 'name', 'availability_schedule_name', 'zone_supply_air_node_name', 'maximum_heating_supply_air_temperature', 'maximum_heating_supply_air_temperature_numeric', 'minimum_cooling_supply_air_temperature', 'minimum_cooling_supply_air_temperature_numeric', 'maximum_heating_supply_air_humidity_ratio', 'maximum_heating_supply_air_humidity_ratio_numeric', 'minimum_cooling_supply_air_humidity_ratio', 'minimum_cooling_supply_air_humidity_ratio_numeric', 'heating_limit', 'maximum_heating_air_flow_rate', 'maximum_sensible_heating_capacity', 'cooling_limit', 'maximum_cooling_air_flow_rate', 'maximum_total_cooling_capacity', 'dehumidification_control_type', 'cooling_sensible_heat_ratio', 'cooling_sensible_heat_ratio_numeric', 'humidification_control_type', 'design_specification_outdoor_air_object_name', 'demand_controlled_ventilation_type', 'outdoor_air_economizer_type', 'heat_recovery_type', 'sensible_heat_recovery_effectiveness', 'sensible_heat_recovery_effectiveness_numeric', 'latent_heat_recovery_effectiveness', 'latent_heat_recovery_effectiveness_numeric', 'field_1', 'field_2', 'field_3', 'field_4', 'field_5', 'field_5_numeric', 'field_6', 'field_6_numeric', 'zone_name']
#
# First row data:
#   building_id: 4136733
#   object_type: ZONEHVAC:IDEALLOADSAIRSYSTEM
#   object_name: Zone1_FrontPerimeter_Ideal_Loads
#   name: Zone1_FrontPerimeter_Ideal_Loads
#   availability_schedule_name: VentSched_Twoandahalfstory_House
#   zone_supply_air_node_name: Zone1_FrontPerimeter_INLETS
#   maximum_heating_supply_air_temperature: 53.68235607082006
#   maximum_heating_supply_air_temperature_numeric: 53.68235607082006
#   minimum_cooling_supply_air_temperature: 13.353398974845822
#   minimum_cooling_supply_air_temperature_numeric: 13.353398974845822
#   maximum_heating_supply_air_humidity_ratio: 0.0156
#   maximum_heating_supply_air_humidity_ratio_numeric: 0.0156
#   minimum_cooling_supply_air_humidity_ratio: 0.0077
#   minimum_cooling_supply_air_humidity_ratio_numeric: 0.0077
#   heating_limit: LimitFlowRateAndCapacity
#   maximum_heating_air_flow_rate: Autosize
#   maximum_sensible_heating_capacity: Autosize
#   cooling_limit: LimitFlowRateAndCapacity
#   maximum_cooling_air_flow_rate: Autosize
#   maximum_total_cooling_capacity: Autosize
#   dehumidification_control_type: None
#   cooling_sensible_heat_ratio: 0.7
#   cooling_sensible_heat_ratio_numeric: 0.7
#   humidification_control_type: None
#   design_specification_outdoor_air_object_name: DSOA_Global
#   demand_controlled_ventilation_type: None
#   outdoor_air_economizer_type: NoEconomizer
#   heat_recovery_type: Sensible
#   sensible_heat_recovery_effectiveness: 0.7676699487422911
#   sensible_heat_recovery_effectiveness_numeric: 0.7676699487422911
#   latent_heat_recovery_effectiveness: 0
#   latent_heat_recovery_effectiveness_numeric: 0.0
#   field_1: None
#   field_2: None
#   field_3: None
#   field_4: None
#   field_5: None
#   field_5_numeric: nan
#   field_6: None
#   field_6_numeric: nan
#   zone_name: None
# --------------------------------------------------------------------------------
#
# File #12
# Relative Path: parsed_data\idf_data\by_category\hvac_systems.parquet
# Shape: (19, 51) (rows: 19, columns: 51)
# Columns: ['building_id', 'object_type', 'object_name', 'field_1', 'field_2', 'field_3', 'field_3_numeric', 'field_5', 'field_6', 'field_6_numeric', 'field_8', 'field_8_numeric', 'field_9', 'field_9_numeric', 'field_10', 'field_11', 'field_11_numeric', 'field_12', 'field_12_numeric', 'field_13', 'field_14', 'field_14_numeric', 'field_15', 'field_15_numeric', 'field_16', 'field_16_numeric', 'field_17', 'field_17_numeric', 'field_18', 'field_19', 'field_19_numeric', 'field_20', 'field_20_numeric', 'field_21', 'field_21_numeric', 'field_22', 'field_22_numeric', 'field_23', 'field_24', 'field_25', 'field_26', 'field_27', 'field_28', 'field_29', 'field_31', 'field_31_numeric', 'field_32', 'field_34', 'field_34_numeric', 'name', 'node_1_name']
#
# First row data:
#   building_id: 4136733
#   object_type: SIZING:ZONE
#   object_name: ALL_ZONES
#   field_1: ALL_ZONES
#   field_2: SupplyAirTemperature
#   field_3: 14.139426798457883
#   field_3_numeric: 14.139426798457883
#   field_5: SupplyAirTemperature
#   field_6: 48.100043020890666
#   field_6_numeric: 48.100043020890666
#   field_8: 8.775029e-03
#   field_8_numeric: 0.008775029
#   field_9: 3.723211e-03
#   field_9_numeric: 0.003723211
#   field_10: DSOA_Global
#   field_11: 1
#   field_11_numeric: 1.0
#   field_12: 1
#   field_12_numeric: 1.0
#   field_13: DesignDayWithLimit
#   field_14: 0
#   field_14_numeric: 0.0
#   field_15: 0.000762
#   field_15_numeric: 0.000762
#   field_16: 0
#   field_16_numeric: 0.0
#   field_17: 0.2
#   field_17_numeric: 0.2
#   field_18: DesignDay
#   field_19: 0
#   field_19_numeric: 0.0
#   field_20: 0.002032
#   field_20_numeric: 0.002032
#   field_21: 0.1415762
#   field_21_numeric: 0.1415762
#   field_22: 0.3
#   field_22_numeric: 0.3
#   field_23: DSZAD_Global
#   field_24: No
#   field_25: NeutralSupplyAir
#   field_26: autosize
#   field_27: autosize
#   field_28: Sensible Load Only No Latent Load
#   field_29: HumidityRatioDifference
#   field_31: 0.005
#   field_31_numeric: 0.005
#   field_32: HumidityRatioDifference
#   field_34: 0.005
#   field_34_numeric: 0.005
#   name: None
#   node_1_name: None
# --------------------------------------------------------------------------------
#
# File #13
# Relative Path: parsed_data\idf_data\by_category\hvac_thermostats.parquet
# Shape: (32, 13) (rows: 32, columns: 13)
# Columns: ['building_id', 'object_type', 'object_name', 'field_1', 'field_2', 'field_3', 'field_4', 'field_5', 'field_12', 'field_12_numeric', 'name', 'heating_setpoint_temperature_schedule_name', 'cooling_setpoint_temperature_schedule_name']
#
# First row data:
#   building_id: 4136733
#   object_type: ZONECONTROL:THERMOSTAT
#   object_name: Zone1_FrontPerimeter_CONTROLS
#   field_1: Zone1_FrontPerimeter_CONTROLS
#   field_2: Zone1_FrontPerimeter
#   field_3: ZONE_CONTROL_TYPE_SCHEDULE
#   field_4: ThermostatSetpoint:DualSetpoint
#   field_5: Zone1_FrontPerimeter_SETPOINTS
#   field_12: 0
#   field_12_numeric: 0.0
#   name: None
#   heating_setpoint_temperature_schedule_name: None
#   cooling_setpoint_temperature_schedule_name: None
# --------------------------------------------------------------------------------
#
# File #14
# Relative Path: parsed_data\idf_data\by_category\infiltration.parquet
# Shape: (16, 18) (rows: 16, columns: 18)
# Columns: ['building_id', 'object_type', 'object_name', 'zone_name', 'name', 'zone_or_zonelist_name', 'schedule_name', 'design_flow_rate_calculation_method', 'design_flow_rate', 'design_flow_rate_numeric', 'constant_term_coefficient', 'constant_term_coefficient_numeric', 'temperature_term_coefficient', 'temperature_term_coefficient_numeric', 'velocity_term_coefficient', 'velocity_term_coefficient_numeric', 'velocity_squared_term_coefficient', 'velocity_squared_term_coefficient_numeric']
#
# First row data:
#   building_id: 4136733
#   object_type: ZONEINFILTRATION:DESIGNFLOWRATE
#   object_name: Infil_resi_D_Zone1_FrontPerimeter
#   zone_name: Zone1_FrontPerimeter
#   name: Infil_resi_D_Zone1_FrontPerimeter
#   zone_or_zonelist_name: Zone1_FrontPerimeter
#   schedule_name: InfilSched_Twoandahalfstory_House
#   design_flow_rate_calculation_method: Flow/Area
#   design_flow_rate: 2.900821e-04
#   design_flow_rate_numeric: 0.0002900821
#   constant_term_coefficient: 0
#   constant_term_coefficient_numeric: 0.0
#   temperature_term_coefficient: 7.142857e-02
#   temperature_term_coefficient_numeric: 0.07142857
#   velocity_term_coefficient: 9.523810e-02
#   velocity_term_coefficient_numeric: 0.0952381
#   velocity_squared_term_coefficient: 0
#   velocity_squared_term_coefficient_numeric: 0.0
# --------------------------------------------------------------------------------
#
# File #15
# Relative Path: parsed_data\idf_data\by_category\lighting.parquet
# Shape: (3, 24) (rows: 3, columns: 24)
# Columns: ['building_id', 'object_type', 'object_name', 'zone_name', 'name', 'zone_or_zonelist_name', 'schedule_name', 'design_level_calculation_method', 'watts_per_zone_floor_area', 'watts_per_zone_floor_area_numeric', 'return_air_fraction', 'return_air_fraction_numeric', 'fraction_radiant', 'fraction_radiant_numeric', 'fraction_visible', 'fraction_visible_numeric', 'fraction_replaceable', 'fraction_replaceable_numeric', 'end_use_subcategory', 'return_air_fraction_calculated_from_plenum_temperature', 'return_air_fraction_function_of_plenum_temperature_coefficient_1', 'return_air_fraction_function_of_plenum_temperature_coefficient_1_numeric', 'return_air_fraction_function_of_plenum_temperature_coefficient_2', 'return_air_fraction_function_of_plenum_temperature_coefficient_2_numeric']
#
# First row data:
#   building_id: 4136733
#   object_type: LIGHTS
#   object_name: Lights_ALL_ZONES
#   zone_name: ALL_ZONES
#   name: Lights_ALL_ZONES
#   zone_or_zonelist_name: ALL_ZONES
#   schedule_name: LightsSchedule
#   design_level_calculation_method: Watts/Area
#   watts_per_zone_floor_area: 0
#   watts_per_zone_floor_area_numeric: 0.0
#   return_air_fraction: 0.8
#   return_air_fraction_numeric: 0.8
#   fraction_radiant: 0.1
#   fraction_radiant_numeric: 0.1
#   fraction_visible: 0.1
#   fraction_visible_numeric: 0.1
#   fraction_replaceable: 1
#   fraction_replaceable_numeric: 1.0
#   end_use_subcategory: General
#   return_air_fraction_calculated_from_plenum_temperature: No
#   return_air_fraction_function_of_plenum_temperature_coefficient_1: 0
#   return_air_fraction_function_of_plenum_temperature_coefficient_1_numeric: 0.0
#   return_air_fraction_function_of_plenum_temperature_coefficient_2: 0
#   return_air_fraction_function_of_plenum_temperature_coefficient_2_numeric: 0.0
# --------------------------------------------------------------------------------
#
# File #16
# Relative Path: parsed_data\idf_data\by_category\materials_constructions.parquet
# Shape: (45, 5) (rows: 45, columns: 5)
# Columns: ['building_id', 'object_type', 'object_name', 'name', 'outside_layer']
#
# First row data:
#   building_id: 4136733
#   object_type: CONSTRUCTION
#   object_name: CEILING1C
#   name: CEILING1C
#   outside_layer: Roof_R2.5
# --------------------------------------------------------------------------------
#
# File #17
# Relative Path: parsed_data\idf_data\by_category\materials_materials.parquet
# Shape: (18, 21) (rows: 18, columns: 21)
# Columns: ['building_id', 'object_type', 'object_name', 'name', 'roughness', 'thickness', 'thickness_numeric', 'conductivity', 'conductivity_numeric', 'density', 'density_numeric', 'specific_heat', 'specific_heat_numeric', 'thermal_absorptance', 'thermal_absorptance_numeric', 'solar_absorptance', 'solar_absorptance_numeric', 'visible_absorptance', 'visible_absorptance_numeric', 'thermal_resistance', 'thermal_resistance_numeric']
#
# First row data:
#   building_id: 4136733
#   object_type: MATERIAL
#   object_name: Concrete_200mm
#   name: Concrete_200mm
#   roughness: MediumRough
#   thickness: 1.952980e-01
#   thickness_numeric: 0.195298
#   conductivity: 0.0781191888777523
#   conductivity_numeric: 0.0781191888777523
#   density: 2300.535528810336
#   density_numeric: 2300.535528810336
#   specific_heat: 852.6535969683864
#   specific_heat_numeric: 852.6535969683864
#   thermal_absorptance: 0.9
#   thermal_absorptance_numeric: 0.9
#   solar_absorptance: 0.7
#   solar_absorptance_numeric: 0.7
#   visible_absorptance: 0.7
#   visible_absorptance_numeric: 0.7
#   thermal_resistance: None
#   thermal_resistance_numeric: nan
# --------------------------------------------------------------------------------
#
# File #18
# Relative Path: parsed_data\idf_data\by_category\materials_windowmaterials.parquet
# Shape: (13, 65) (rows: 13, columns: 65)
# Columns: ['building_id', 'object_type', 'object_name', 'name', 'u_factor', 'u_factor_numeric', 'solar_heat_gain_coefficient', 'solar_heat_gain_coefficient_numeric', 'visible_transmittance', 'visible_transmittance_numeric', 'slat_orientation', 'slat_width', 'slat_width_numeric', 'slat_separation', 'slat_separation_numeric', 'slat_thickness', 'slat_thickness_numeric', 'slat_angle', 'slat_angle_numeric', 'slat_conductivity', 'slat_conductivity_numeric', 'slat_beam_solar_transmittance', 'slat_beam_solar_transmittance_numeric', 'front_side_slat_beam_solar_reflectance', 'front_side_slat_beam_solar_reflectance_numeric', 'back_side_slat_beam_solar_reflectance', 'back_side_slat_beam_solar_reflectance_numeric', 'slat_diffuse_solar_transmittance', 'slat_diffuse_solar_transmittance_numeric', 'front_side_slat_diffuse_solar_reflectance', 'front_side_slat_diffuse_solar_reflectance_numeric', 'back_side_slat_diffuse_solar_reflectance', 'back_side_slat_diffuse_solar_reflectance_numeric', 'slat_beam_visible_transmittance', 'slat_beam_visible_transmittance_numeric', 'front_side_slat_beam_visible_reflectance', 'front_side_slat_beam_visible_reflectance_numeric', 'back_side_slat_beam_visible_reflectance', 'back_side_slat_beam_visible_reflectance_numeric', 'slat_diffuse_visible_transmittance', 'slat_diffuse_visible_transmittance_numeric', 'front_side_slat_diffuse_visible_reflectance', 'front_side_slat_diffuse_visible_reflectance_numeric', 'back_side_slat_diffuse_visible_reflectance', 'back_side_slat_diffuse_visible_reflectance_numeric', 'slat_infrared_hemispherical_transmittance', 'slat_infrared_hemispherical_transmittance_numeric', 'front_side_slat_infrared_hemispherical_emissivity', 'front_side_slat_infrared_hemispherical_emissivity_numeric', 'back_side_slat_infrared_hemispherical_emissivity', 'back_side_slat_infrared_hemispherical_emissivity_numeric', 'blind_to_glass_distance', 'blind_to_glass_distance_numeric', 'blind_top_opening_multiplier', 'blind_top_opening_multiplier_numeric', 'blind_bottom_opening_multiplier', 'blind_bottom_opening_multiplier_numeric', 'blind_left_side_opening_multiplier', 'blind_left_side_opening_multiplier_numeric', 'blind_right_side_opening_multiplier', 'blind_right_side_opening_multiplier_numeric', 'minimum_slat_angle', 'minimum_slat_angle_numeric', 'maximum_slat_angle', 'maximum_slat_angle_numeric']
#
# First row data:
#   building_id: 4136733
#   object_type: WINDOWMATERIAL:SIMPLEGLAZINGSYSTEM
#   object_name: Window_U2.9
#   name: Window_U2.9
#   u_factor: 2.9
#   u_factor_numeric: 2.9
#   solar_heat_gain_coefficient: 0.7014521644391364
#   solar_heat_gain_coefficient_numeric: 0.7014521644391364
#   visible_transmittance: 0.7
#   visible_transmittance_numeric: 0.7
#   slat_orientation: None
#   slat_width: None
#   slat_width_numeric: nan
#   slat_separation: None
#   slat_separation_numeric: nan
#   slat_thickness: None
#   slat_thickness_numeric: nan
#   slat_angle: None
#   slat_angle_numeric: nan
#   slat_conductivity: None
#   slat_conductivity_numeric: nan
#   slat_beam_solar_transmittance: None
#   slat_beam_solar_transmittance_numeric: nan
#   front_side_slat_beam_solar_reflectance: None
#   front_side_slat_beam_solar_reflectance_numeric: nan
#   back_side_slat_beam_solar_reflectance: None
#   back_side_slat_beam_solar_reflectance_numeric: nan
#   slat_diffuse_solar_transmittance: None
#   slat_diffuse_solar_transmittance_numeric: nan
#   front_side_slat_diffuse_solar_reflectance: None
#   front_side_slat_diffuse_solar_reflectance_numeric: nan
#   back_side_slat_diffuse_solar_reflectance: None
#   back_side_slat_diffuse_solar_reflectance_numeric: nan
#   slat_beam_visible_transmittance: None
#   slat_beam_visible_transmittance_numeric: nan
#   front_side_slat_beam_visible_reflectance: None
#   front_side_slat_beam_visible_reflectance_numeric: nan
#   back_side_slat_beam_visible_reflectance: None
#   back_side_slat_beam_visible_reflectance_numeric: nan
#   slat_diffuse_visible_transmittance: None
#   slat_diffuse_visible_transmittance_numeric: nan
#   front_side_slat_diffuse_visible_reflectance: None
#   front_side_slat_diffuse_visible_reflectance_numeric: nan
#   back_side_slat_diffuse_visible_reflectance: None
#   back_side_slat_diffuse_visible_reflectance_numeric: nan
#   slat_infrared_hemispherical_transmittance: None
#   slat_infrared_hemispherical_transmittance_numeric: nan
#   front_side_slat_infrared_hemispherical_emissivity: None
#   front_side_slat_infrared_hemispherical_emissivity_numeric: nan
#   back_side_slat_infrared_hemispherical_emissivity: None
#   back_side_slat_infrared_hemispherical_emissivity_numeric: nan
#   blind_to_glass_distance: None
#   blind_to_glass_distance_numeric: nan
#   blind_top_opening_multiplier: None
#   blind_top_opening_multiplier_numeric: nan
#   blind_bottom_opening_multiplier: None
#   blind_bottom_opening_multiplier_numeric: nan
#   blind_left_side_opening_multiplier: None
#   blind_left_side_opening_multiplier_numeric: nan
#   blind_right_side_opening_multiplier: None
#   blind_right_side_opening_multiplier_numeric: nan
#   minimum_slat_angle: None
#   minimum_slat_angle_numeric: nan
#   maximum_slat_angle: None
#   maximum_slat_angle_numeric: nan
# --------------------------------------------------------------------------------
#
# File #19
# Relative Path: parsed_data\idf_data\by_category\outputs_all.parquet
# Shape: (51, 29) (rows: 51, columns: 29)
# Columns: ['building_id', 'object_type', 'object_name', 'key_field', 'report_1_name', 'name', 'digits_after_decimal', 'digits_after_decimal_numeric', 'variable_or_meter_1_name', 'aggregation_type_for_variable_or_meter_1', 'variable_or_meter_2_name', 'aggregation_type_for_variable_or_meter_2', 'variable_or_meter_3_name', 'aggregation_type_for_variable_or_meter_3', 'variable_or_meter_4_name', 'aggregation_type_for_variable_or_meter_4', 'variable_or_meter_5_name', 'aggregation_type_for_variable_or_meter_5', 'variable_or_meter_6_name', 'aggregation_type_for_variable_or_meter_6', 'column_separator', 'key_value', 'variable_name', 'reporting_frequency', 'key_name', 'option_type', 'output_type', 'output_subtype', 'schedule_name']
#
# First row data:
#   building_id: 4136733
#   object_type: Output:VariableDictionary
#   object_name: Regular
#   key_field: Regular
#   report_1_name: None
#   name: None
#   digits_after_decimal: None
#   digits_after_decimal_numeric: nan
#   variable_or_meter_1_name: None
#   aggregation_type_for_variable_or_meter_1: None
#   variable_or_meter_2_name: None
#   aggregation_type_for_variable_or_meter_2: None
#   variable_or_meter_3_name: None
#   aggregation_type_for_variable_or_meter_3: None
#   variable_or_meter_4_name: None
#   aggregation_type_for_variable_or_meter_4: None
#   variable_or_meter_5_name: None
#   aggregation_type_for_variable_or_meter_5: None
#   variable_or_meter_6_name: None
#   aggregation_type_for_variable_or_meter_6: None
#   column_separator: None
#   key_value: None
#   variable_name: None
#   reporting_frequency: None
#   key_name: None
#   option_type: None
#   output_type: None
#   output_subtype: None
#   schedule_name: None
# --------------------------------------------------------------------------------
#
# File #20
# Relative Path: parsed_data\idf_data\by_category\schedules.parquet
# Shape: (48, 35) (rows: 48, columns: 35)
# Columns: ['building_id', 'object_type', 'object_name', 'name', 'lower_limit_value', 'lower_limit_value_numeric', 'upper_limit_value', 'upper_limit_value_numeric', 'numeric_type', 'unit_type', 'schedule_type_limits_name', 'field_3', 'field_4', 'field_5', 'field_6', 'field_6_numeric', 'field_7', 'field_8', 'field_9', 'field_10', 'field_11', 'field_12', 'field_13', 'field_14', 'field_15', 'field_16', 'field_17', 'field_18', 'field_19', 'field_20', 'field_21', 'field_22', 'field_23', 'hourly_value', 'hourly_value_numeric']
#
# First row data:
#   building_id: 4136733
#   object_type: SCHEDULETYPELIMITS
#   object_name: Temperature
#   name: Temperature
#   lower_limit_value: -100
#   lower_limit_value_numeric: -100.0
#   upper_limit_value: 200
#   upper_limit_value_numeric: 200.0
#   numeric_type: CONTINUOUS
#   unit_type: Dimensionless
#   schedule_type_limits_name: None
#   field_3: None
#   field_4: None
#   field_5: None
#   field_6: None
#   field_6_numeric: nan
#   field_7: None
#   field_8: None
#   field_9: None
#   field_10: None
#   field_11: None
#   field_12: None
#   field_13: None
#   field_14: None
#   field_15: None
#   field_16: None
#   field_17: None
#   field_18: None
#   field_19: None
#   field_20: None
#   field_21: None
#   field_22: None
#   field_23: None
#   hourly_value: None
#   hourly_value_numeric: nan
# --------------------------------------------------------------------------------
#
# File #21
# Relative Path: parsed_data\idf_data\by_category\shading.parquet
# Shape: (10, 16) (rows: 10, columns: 16)
# Columns: ['building_id', 'object_type', 'object_name', 'zone_name', 'name', 'zone_or_zonelist_name', 'sequential_shading_control_number', 'sequential_shading_control_number_numeric', 'shading_type', 'shading_control_type', 'shading_control_is_scheduled', 'glare_control_is_active', 'shading_device_material_name', 'type_of_slat_angle_control_for_blinds', 'multiple_surface_control_type', 'fenestration_surface_1_name']
#
# First row data:
#   building_id: 4136733
#   object_type: WINDOWSHADINGCONTROL
#   object_name: ShadingCtrl_Zone1_FrontPerimeter_Wall_0_window
#   zone_name: Zone1_FrontPerimeter
#   name: ShadingCtrl_Zone1_FrontPerimeter_Wall_0_window
#   zone_or_zonelist_name: Zone1_FrontPerimeter
#   sequential_shading_control_number: 1
#   sequential_shading_control_number_numeric: 1.0
#   shading_type: ExteriorBlind
#   shading_control_type: AlwaysOn
#   shading_control_is_scheduled: No
#   glare_control_is_active: No
#   shading_device_material_name: MyExternalLouvers_Zone1_FrontPerimeter_Wall_0_window
#   type_of_slat_angle_control_for_blinds: FixedSlatAngle
#   multiple_surface_control_type: Sequential
#   fenestration_surface_1_name: Zone1_FrontPerimeter_Wall_0 window
# --------------------------------------------------------------------------------
#
# File #22
# Relative Path: parsed_data\idf_data\by_category\simulation_control.parquet
# Shape: (15, 40) (rows: 15, columns: 40)
# Columns: ['building_id', 'object_type', 'object_name', 'version_identifier', 'version_identifier_numeric', 'do_zone_sizing_calculation', 'do_system_sizing_calculation', 'do_plant_sizing_calculation', 'run_simulation_for_sizing_periods', 'run_simulation_for_weather_file_run_periods', 'do_hvac_sizing_simulation_for_sizing_periods', 'name', 'north_axis', 'north_axis_numeric', 'terrain', 'loads_convergence_tolerance_value', 'loads_convergence_tolerance_value_numeric', 'temperature_convergence_tolerance_value', 'temperature_convergence_tolerance_value_numeric', 'solar_distribution', 'maximum_number_of_warmup_days', 'maximum_number_of_warmup_days_numeric', 'minimum_number_of_warmup_days', 'minimum_number_of_warmup_days_numeric', 'number_of_timesteps_per_hour', 'number_of_timesteps_per_hour_numeric', 'begin_month', 'begin_month_numeric', 'begin_day_of_month', 'begin_day_of_month_numeric', 'end_month', 'end_month_numeric', 'end_day_of_month', 'end_day_of_month_numeric', 'day_of_week_for_start_day', 'use_weather_file_holidays_and_special_days', 'use_weather_file_daylight_saving_period', 'apply_weekend_holiday_rule', 'use_weather_file_rain_indicators', 'use_weather_file_snow_indicators']
#
# First row data:
#   building_id: 4136733
#   object_type: Version
#   object_name: 22.2
#   version_identifier: 22.2
#   version_identifier_numeric: 22.2
#   do_zone_sizing_calculation: None
#   do_system_sizing_calculation: None
#   do_plant_sizing_calculation: None
#   run_simulation_for_sizing_periods: None
#   run_simulation_for_weather_file_run_periods: None
#   do_hvac_sizing_simulation_for_sizing_periods: None
#   name: None
#   north_axis: None
#   north_axis_numeric: nan
#   terrain: None
#   loads_convergence_tolerance_value: None
#   loads_convergence_tolerance_value_numeric: nan
#   temperature_convergence_tolerance_value: None
#   temperature_convergence_tolerance_value_numeric: nan
#   solar_distribution: None
#   maximum_number_of_warmup_days: None
#   maximum_number_of_warmup_days_numeric: nan
#   minimum_number_of_warmup_days: None
#   minimum_number_of_warmup_days_numeric: nan
#   number_of_timesteps_per_hour: None
#   number_of_timesteps_per_hour_numeric: nan
#   begin_month: None
#   begin_month_numeric: nan
#   begin_day_of_month: None
#   begin_day_of_month_numeric: nan
#   end_month: None
#   end_month_numeric: nan
#   end_day_of_month: None
#   end_day_of_month_numeric: nan
#   day_of_week_for_start_day: None
#   use_weather_file_holidays_and_special_days: None
#   use_weather_file_daylight_saving_period: None
#   apply_weekend_holiday_rule: None
#   use_weather_file_rain_indicators: None
#   use_weather_file_snow_indicators: None
# --------------------------------------------------------------------------------
#
# File #23
# Relative Path: parsed_data\idf_data\by_category\site_location.parquet
# Shape: (12, 60) (rows: 12, columns: 60)
# Columns: ['building_id', 'object_type', 'object_name', 'name', 'latitude', 'latitude_numeric', 'longitude', 'longitude_numeric', 'time_zone', 'time_zone_numeric', 'elevation', 'elevation_numeric', 'month', 'month_numeric', 'day_of_month', 'day_of_month_numeric', 'day_type', 'maximum_dry_bulb_temperature', 'maximum_dry_bulb_temperature_numeric', 'daily_dry_bulb_temperature_range', 'daily_dry_bulb_temperature_range_numeric', 'humidity_condition_type', 'wetbulb_or_dewpoint_at_maximum_dry_bulb', 'wetbulb_or_dewpoint_at_maximum_dry_bulb_numeric', 'barometric_pressure', 'barometric_pressure_numeric', 'wind_speed', 'wind_speed_numeric', 'wind_direction', 'wind_direction_numeric', 'rain_indicator', 'snow_indicator', 'daylight_saving_time_indicator', 'solar_model_indicator', 'sky_clearness', 'sky_clearness_numeric', 'january_ground_temperature', 'january_ground_temperature_numeric', 'february_ground_temperature', 'february_ground_temperature_numeric', 'march_ground_temperature', 'march_ground_temperature_numeric', 'april_ground_temperature', 'april_ground_temperature_numeric', 'may_ground_temperature', 'may_ground_temperature_numeric', 'june_ground_temperature', 'june_ground_temperature_numeric', 'july_ground_temperature', 'july_ground_temperature_numeric', 'august_ground_temperature', 'august_ground_temperature_numeric', 'september_ground_temperature', 'september_ground_temperature_numeric', 'october_ground_temperature', 'october_ground_temperature_numeric', 'november_ground_temperature', 'november_ground_temperature_numeric', 'december_ground_temperature', 'december_ground_temperature_numeric']
#
# First row data:
#   building_id: 4136733
#   object_type: Site:Location
#   object_name: Amsterdam_Netherlands
#   name: Amsterdam_Netherlands
#   latitude: 52.37
#   latitude_numeric: 52.37
#   longitude: 4.89
#   longitude_numeric: 4.89
#   time_zone: 1
#   time_zone_numeric: 1.0
#   elevation: -2
#   elevation_numeric: -2.0
#   month: None
#   month_numeric: nan
#   day_of_month: None
#   day_of_month_numeric: nan
#   day_type: None
#   maximum_dry_bulb_temperature: None
#   maximum_dry_bulb_temperature_numeric: nan
#   daily_dry_bulb_temperature_range: None
#   daily_dry_bulb_temperature_range_numeric: nan
#   humidity_condition_type: None
#   wetbulb_or_dewpoint_at_maximum_dry_bulb: None
#   wetbulb_or_dewpoint_at_maximum_dry_bulb_numeric: nan
#   barometric_pressure: None
#   barometric_pressure_numeric: nan
#   wind_speed: None
#   wind_speed_numeric: nan
#   wind_direction: None
#   wind_direction_numeric: nan
#   rain_indicator: None
#   snow_indicator: None
#   daylight_saving_time_indicator: None
#   solar_model_indicator: None
#   sky_clearness: None
#   sky_clearness_numeric: nan
#   january_ground_temperature: None
#   january_ground_temperature_numeric: nan
#   february_ground_temperature: None
#   february_ground_temperature_numeric: nan
#   march_ground_temperature: None
#   march_ground_temperature_numeric: nan
#   april_ground_temperature: None
#   april_ground_temperature_numeric: nan
#   may_ground_temperature: None
#   may_ground_temperature_numeric: nan
#   june_ground_temperature: None
#   june_ground_temperature_numeric: nan
#   july_ground_temperature: None
#   july_ground_temperature_numeric: nan
#   august_ground_temperature: None
#   august_ground_temperature_numeric: nan
#   september_ground_temperature: None
#   september_ground_temperature_numeric: nan
#   october_ground_temperature: None
#   october_ground_temperature_numeric: nan
#   november_ground_temperature: None
#   november_ground_temperature_numeric: nan
#   december_ground_temperature: None
#   december_ground_temperature_numeric: nan
# --------------------------------------------------------------------------------
#
# File #24
# Relative Path: parsed_data\idf_data\by_category\ventilation.parquet
# Shape: (12, 53) (rows: 12, columns: 53)
# Columns: ['building_id', 'object_type', 'object_name', 'name', 'outdoor_air_method', 'outdoor_air_flow_per_person', 'outdoor_air_flow_per_person_numeric', 'outdoor_air_flow_per_zone_floor_area', 'outdoor_air_flow_per_zone_floor_area_numeric', 'outdoor_air_flow_per_zone', 'outdoor_air_flow_per_zone_numeric', 'outdoor_air_flow_air_changes_per_hour', 'outdoor_air_flow_air_changes_per_hour_numeric', 'field_1', 'field_2', 'field_2_numeric', 'field_3', 'field_3_numeric', 'field_5', 'field_5_numeric', 'field_6', 'field_6_numeric', 'zone_name', 'zone_or_zonelist_name', 'schedule_name', 'design_flow_rate_calculation_method', 'design_flow_rate', 'design_flow_rate_numeric', 'ventilation_type', 'fan_pressure_rise', 'fan_pressure_rise_numeric', 'fan_total_efficiency', 'fan_total_efficiency_numeric', 'constant_term_coefficient', 'constant_term_coefficient_numeric', 'temperature_term_coefficient', 'temperature_term_coefficient_numeric', 'velocity_term_coefficient', 'velocity_term_coefficient_numeric', 'velocity_squared_term_coefficient', 'velocity_squared_term_coefficient_numeric', 'minimum_indoor_temperature', 'minimum_indoor_temperature_numeric', 'maximum_indoor_temperature', 'maximum_indoor_temperature_numeric', 'delta_temperature', 'delta_temperature_numeric', 'minimum_outdoor_temperature', 'minimum_outdoor_temperature_numeric', 'maximum_outdoor_temperature', 'maximum_outdoor_temperature_numeric', 'maximum_wind_speed', 'maximum_wind_speed_numeric']
#
# First row data:
#   building_id: 4136733
#   object_type: DESIGNSPECIFICATION:OUTDOORAIR
#   object_name: DSOA_Global
#   name: DSOA_Global
#   outdoor_air_method: Sum
#   outdoor_air_flow_per_person: 0.00236
#   outdoor_air_flow_per_person_numeric: 0.00236
#   outdoor_air_flow_per_zone_floor_area: 0.000305
#   outdoor_air_flow_per_zone_floor_area_numeric: 0.000305
#   outdoor_air_flow_per_zone: 0
#   outdoor_air_flow_per_zone_numeric: 0.0
#   outdoor_air_flow_air_changes_per_hour: 0
#   outdoor_air_flow_air_changes_per_hour_numeric: 0.0
#   field_1: None
#   field_2: None
#   field_2_numeric: nan
#   field_3: None
#   field_3_numeric: nan
#   field_5: None
#   field_5_numeric: nan
#   field_6: None
#   field_6_numeric: nan
#   zone_name: None
#   zone_or_zonelist_name: None
#   schedule_name: None
#   design_flow_rate_calculation_method: None
#   design_flow_rate: None
#   design_flow_rate_numeric: nan
#   ventilation_type: None
#   fan_pressure_rise: None
#   fan_pressure_rise_numeric: nan
#   fan_total_efficiency: None
#   fan_total_efficiency_numeric: nan
#   constant_term_coefficient: None
#   constant_term_coefficient_numeric: nan
#   temperature_term_coefficient: None
#   temperature_term_coefficient_numeric: nan
#   velocity_term_coefficient: None
#   velocity_term_coefficient_numeric: nan
#   velocity_squared_term_coefficient: None
#   velocity_squared_term_coefficient_numeric: nan
#   minimum_indoor_temperature: None
#   minimum_indoor_temperature_numeric: nan
#   maximum_indoor_temperature: None
#   maximum_indoor_temperature_numeric: nan
#   delta_temperature: None
#   delta_temperature_numeric: nan
#   minimum_outdoor_temperature: None
#   minimum_outdoor_temperature_numeric: nan
#   maximum_outdoor_temperature: None
#   maximum_outdoor_temperature_numeric: nan
#   maximum_wind_speed: None
#   maximum_wind_speed_numeric: nan
# --------------------------------------------------------------------------------
#
# File #25
# Relative Path: parsed_data\metadata\building_registry.parquet
# Shape: (3, 9) (rows: 3, columns: 9)
# Columns: ['building_id', 'ogc_fid', 'idf_path', 'sql_path', 'zone_count', 'output_variables', 'output_meters', 'status', 'last_modified']
#
# First row data:
#   building_id: 4136733
#   ogc_fid: 4136733
#   idf_path: /usr/src/app/output/2dae68d1-4b75-4c75-9471-7b6d931af865/output_IDFs/building_4136733.idf
#   sql_path: /usr/src/app/output/2dae68d1-4b75-4c75-9471-7b6d931af865/Sim_Results/2020/simulation_bldg0_4136733.sql
#   zone_count: 10
#   output_variables: 65
#   output_meters: 7
#   status: completed
#   last_modified: 2025-06-23 18:29:20.304755
# --------------------------------------------------------------------------------
#
# File #26
# Relative Path: parsed_data\metadata\missing_outputs.parquet
# Shape: (71, 4) (rows: 71, columns: 4)
# Columns: ['variable', 'key', 'frequency', 'building_id']
#
# First row data:
#   variable: Boiler Heating Energy
#   key: *
#   frequency: Monthly
#   building_id: 4136733
# --------------------------------------------------------------------------------
#
# File #27
# Relative Path: parsed_data\metadata\output_validation.parquet
# Shape: (3, 6) (rows: 3, columns: 6)
# Columns: ['building_id', 'total_requested', 'found', 'missing', 'partial', 'coverage']
#
# First row data:
#   building_id: 4136733
#   total_requested: 65
#   found: 38
#   missing: [{'frequency': 'Monthly', 'key': '*', 'variable': 'Boiler Heating Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Air System Latent Cooling Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Ventilation Standard Density Volume Flow Rate'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Ventilation Sensible Heat Loss Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Ventilation Sensible Heat Gain Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Ventilation Latent Heat Loss Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Ventilation Latent Heat Gain Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Outdoor Air Volume Flow Rate'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Surface Inside Face Conduction Heat Gain Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Surface Inside Face Conduction Heat Loss Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone People Sensible Heating Rate'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone People Sensible Heating Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone People Latent Heat Gain Rate'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone People Latent Heat Gain Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Lights Sensible Heating Rate'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Lights Sensible Heating Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Electric Equipment Sensible Heating Rate'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Electric Equipment Sensible Heating Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Electric Equipment Latent Heat Gain Rate'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Electric Equipment Latent Heat Gain Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Total Internal Sensible Heat Gain Rate'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Total Internal Sensible Heat Gain Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Total Internal Latent Heat Gain Rate'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Total Internal Latent Heat Gain Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Window Shading Control Status'}
# ...
#
# First row data:
#   building_id: building_4136733_variant_0
#   object_type: DESIGNSPECIFICATION:OUTDOORAIR
#   object_name: DSOA_Global
#   name: DSOA_Global
#   outdoor_air_method: Sum
#   outdoor_air_flow_per_person: 0.0025
#   outdoor_air_flow_per_person_numeric: 0.0025
#   outdoor_air_flow_per_zone_floor_area: 0.0003
#   outdoor_air_flow_per_zone_floor_area_numeric: 0.0003
#   outdoor_air_flow_per_zone: 0
#   outdoor_air_flow_per_zone_numeric: 0.0
#   outdoor_air_flow_air_changes_per_hour: 0
#   outdoor_air_flow_air_changes_per_hour_numeric: 0.0
#   field_1: None
#   field_2: None
#   field_2_numeric: nan
#   field_3: None
#   field_3_numeric: nan
#   field_5: None
#   field_5_numeric: nan
#   field_6: None
#   field_6_numeric: nan
#   zone_name: None
#   zone_or_zonelist_name: None
#   schedule_name: None
#   design_flow_rate_calculation_method: None
#   design_flow_rate: None
#   design_flow_rate_numeric: nan
#   ventilation_type: None
#   fan_pressure_rise: None
#   fan_pressure_rise_numeric: nan
#   fan_total_efficiency: None
#   fan_total_efficiency_numeric: nan
#   constant_term_coefficient: None
#   constant_term_coefficient_numeric: nan
#   temperature_term_coefficient: None
#   temperature_term_coefficient_numeric: nan
#   velocity_term_coefficient: None
#   velocity_term_coefficient_numeric: nan
#   velocity_squared_term_coefficient: None
#   velocity_squared_term_coefficient_numeric: nan
#   minimum_indoor_temperature: None
#   minimum_indoor_temperature_numeric: nan
#   maximum_indoor_temperature: None
#   maximum_indoor_temperature_numeric: nan
#   delta_temperature: None
#   delta_temperature_numeric: nan
#   minimum_outdoor_temperature: None
#   minimum_outdoor_temperature_numeric: nan
#   maximum_outdoor_temperature: None
#   maximum_outdoor_temperature_numeric: nan
#   maximum_wind_speed: None
#   maximum_wind_speed_numeric: nan
# --------------------------------------------------------------------------------
#
# File #66
# Relative Path: parsed_modified_results\metadata\building_registry.parquet
# Shape: (9, 9) (rows: 9, columns: 9)
# Columns: ['building_id', 'ogc_fid', 'idf_path', 'sql_path', 'zone_count', 'output_variables', 'output_meters', 'status', 'last_modified']
#
# First row data:
#   building_id: 4136733
#   ogc_fid: 4136733
#   idf_path: /usr/src/app/output/2dae68d1-4b75-4c75-9471-7b6d931af865/modified_idfs/building_4136733_variant_0.idf
#   sql_path: /usr/src/app/output/2dae68d1-4b75-4c75-9471-7b6d931af865/Modified_Sim_Results/2020/simulation_bldg0_4136733.sql
#   zone_count: 10
#   output_variables: 65
#   output_meters: 7
#   status: completed
#   last_modified: 2025-06-23 18:29:49.674426
# --------------------------------------------------------------------------------
#
# File #67
# Relative Path: parsed_modified_results\metadata\missing_outputs.parquet
# Shape: (213, 4) (rows: 213, columns: 4)
# Columns: ['variable', 'key', 'frequency', 'building_id']
#
# First row data:
#   variable: Boiler Heating Energy
#   key: *
#   frequency: Monthly
#   building_id: 4136733
# --------------------------------------------------------------------------------
#
# File #68
# Relative Path: parsed_modified_results\metadata\output_validation.parquet
# Shape: (9, 6) (rows: 9, columns: 6)
# Columns: ['building_id', 'total_requested', 'found', 'missing', 'partial', 'coverage']
#
# First row data:
#   building_id: 4136733
#   total_requested: 65
#   found: 38
#   missing: [{'frequency': 'Monthly', 'key': '*', 'variable': 'Boiler Heating Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Air System Latent Cooling Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Ventilation Standard Density Volume Flow Rate'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Ventilation Sensible Heat Loss Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Ventilation Sensible Heat Gain Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Ventilation Latent Heat Loss Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Ventilation Latent Heat Gain Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Outdoor Air Volume Flow Rate'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Surface Inside Face Conduction Heat Gain Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Surface Inside Face Conduction Heat Loss Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone People Sensible Heating Rate'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone People Sensible Heating Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone People Latent Heat Gain Rate'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone People Latent Heat Gain Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Lights Sensible Heating Rate'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Lights Sensible Heating Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Electric Equipment Sensible Heating Rate'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Electric Equipment Sensible Heating Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Electric Equipment Latent Heat Gain Rate'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Electric Equipment Latent Heat Gain Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Total Internal Sensible Heat Gain Rate'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Total Internal Sensible Heat Gain Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Total Internal Latent Heat Gain Rate'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Total Internal Latent Heat Gain Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Window Shading Control Status'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Surface Window Shading Device Transmitted Diffuse Solar Radiation Rate'}
#  {'frequency': 'Daily', 'key': '*', 'variable': 'Facility Total Electric Demand Power'}]
#   partial: []
#   coverage: 58.46153846153847
# --------------------------------------------------------------------------------
#
# File #69
# Relative Path: parsed_modified_results\relationships\equipment_assignments.parquet
# Shape: (70, 5) (rows: 70, columns: 5)
# Columns: ['building_id', 'equipment_name', 'equipment_type', 'assigned_zone', 'schedule']
#
# First row data:
#   building_id: building_4136733_variant_0
#   equipment_name: Lights_ALL_ZONES
#   equipment_type: LIGHTS
#   assigned_zone: Zone1_FrontPerimeter
#   schedule: ALWAYS_ON
# --------------------------------------------------------------------------------
#
# File #70
# Relative Path: parsed_modified_results\relationships\zone_mappings.parquet
# Shape: (35, 6) (rows: 35, columns: 6)
# Columns: ['building_id', 'idf_zone_name', 'sql_zone_name', 'zone_type', 'multiplier', 'mapping_confidence']
#
# First row data:
#   building_id: building_4136733_variant_0
#   idf_zone_name: Zone1_FrontPerimeter
#   sql_zone_name: ZONE1_FRONTPERIMETER
#   zone_type: Perimeter
#   multiplier: 1.0
#   mapping_confidence: nan
# --------------------------------------------------------------------------------
#
# File #71
# Relative Path: parsed_modified_results\sql_results\schedules\all_schedules.parquet
# Shape: (39, 6) (rows: 39, columns: 6)
# Columns: ['ScheduleIndex', 'ScheduleName', 'ScheduleType', 'ScheduleMinimum', 'ScheduleMaximum', 'building_id']
#
# First row data:
#   ScheduleIndex: 1
#   ScheduleName: ALWAYS22C
#   ScheduleType: TEMPERATURE
#   ScheduleMinimum: 22.0
#   ScheduleMaximum: 22.0
#   building_id: 4136733
# --------------------------------------------------------------------------------
#
# File #72
# Relative Path: parsed_modified_results\sql_results\summary_metrics\building_metrics.parquet
# Shape: (3, 21) (rows: 3, columns: 21)
# Columns: ['building_id', 'sql_file', 'extraction_date', 'energyplus_version', 'simulation_timestamp', 'timesteps_per_hour', 'zone_count', 'total_floor_area', 'total_volume', 'total_heating_energy', 'avg_heating_power', 'peak_heating_power', 'total_cooling_energy', 'avg_cooling_power', 'peak_cooling_power', 'total_water_heating_energy', 'avg_water_heating_power', 'peak_water_heating_power', 'total_outputs_available', 'outputs_with_data', 'output_coverage']
#
# First row data:
#   building_id: 4136733
#   sql_file: /usr/src/app/output/2dae68d1-4b75-4c75-9471-7b6d931af865/Modified_Sim_Results/2020/simulation_bldg2_4136733.sql
#   extraction_date: 2025-06-23T18:29:57.243842
#   energyplus_version: EnergyPlus, Version 22.2.0-c249759bad, YMD=2025.06.23 18:29
#   simulation_timestamp:  YMD=2025.06.23 18:29
#   timesteps_per_hour: 6
#   zone_count: 10
#   total_floor_area: 60.0
#   total_volume: 180.0
#   total_heating_energy: 48342160345.12939
#   avg_heating_power: 335709446.8411763
#   peak_heating_power: 3941013537.7375417
#   total_cooling_energy: 5563188726.391966
#   avg_cooling_power: 42145369.13933308
#   peak_cooling_power: 524331525.2913948
#   total_water_heating_energy: 10976486965.940071
#   avg_water_heating_power: 914707247.1616726
#   peak_water_heating_power: 934186222.4803627
#   total_outputs_available: 476
#   outputs_with_data: 476
#   output_coverage: 100.0
# --------------------------------------------------------------------------------
#
# File #73
# Relative Path: parsed_modified_results\sql_results\summary_metrics\zone_metrics.parquet
# Shape: (3, 11) (rows: 3, columns: 11)
# Columns: ['building_id', 'zone_name', 'floor_area', 'volume', 'heating_energy', 'heating_peak_power', 'cooling_energy', 'cooling_peak_power', 'avg_temperature', 'min_temperature', 'max_temperature']
#
# First row data:
#   building_id: 4136733
#   zone_name: ZONE2_CORE
#   floor_area: 0.49058623521244726
#   volume: 1.4717587056373418
#   heating_energy: 0.0
#   heating_peak_power: 0.0
#   cooling_energy: 38882385.60361744
#   cooling_peak_power: 5590736.456576329
#   avg_temperature: 20.32551550587339
#   min_temperature: 16.723264010398157
#   max_temperature: 25.77544953670956
# --------------------------------------------------------------------------------
#
# File #74
# Relative Path: parsed_modified_results\sql_results\timeseries\aggregated\daily\hvac_daily.parquet
# Shape: (27805, 6) (rows: 27805, columns: 6)
# Columns: ['building_id', 'Zone', 'Variable', 'DateTime', 'TimeIndex', 'Value']
#
# First row data:
#   building_id: 4136733
#   Zone: MYDHW_0_WATERHEATER
#   Variable: Water Heater Heating Energy
#   DateTime: 2013-02-01 00:00:00
#   TimeIndex: 32.0
#   Value: 931723138.7617693
# --------------------------------------------------------------------------------
#
# File #75
# Relative Path: parsed_modified_results\sql_results\timeseries\aggregated\daily\ventilation_daily.parquet
# Shape: (42210, 6) (rows: 42210, columns: 6)
# Columns: ['building_id', 'Zone', 'Variable', 'DateTime', 'TimeIndex', 'Value']
#
# First row data:
#   building_id: 4136733
#   Zone: ZONE1_CORE
#   Variable: Zone Mechanical Ventilation Mass Flow Rate
#   DateTime: 2013-02-01 00:00:00
#   TimeIndex: 32.0
#   Value: 0.0001773271572355944
# --------------------------------------------------------------------------------
#
# File #76
# Relative Path: parsed_modified_results\sql_results\timeseries\aggregated\daily\zones_daily.parquet
# Shape: (143045, 6) (rows: 143045, columns: 6)
# Columns: ['building_id', 'Zone', 'Variable', 'DateTime', 'TimeIndex', 'Value']
#
# First row data:
#   building_id: 4136733
#   Zone: ZONE1_CORE
#   Variable: Zone Mean Air Temperature
#   DateTime: 2013-02-01 00:00:00
#   TimeIndex: 32.0
#   Value: 15.485632002948556
# --------------------------------------------------------------------------------
#
# File #77
# Relative Path: parsed_modified_results\sql_results\timeseries\aggregated\monthly\hvac_monthly.parquet
# Shape: (996, 6) (rows: 996, columns: 6)
# Columns: ['building_id', 'Zone', 'Variable', 'DateTime', 'TimeIndex', 'Value']
#
# First row data:
#   building_id: 4136733
#   Zone: MYDHW_0_WATERHEATER
#   Variable: Water Heater Heating Energy
#   DateTime: 2013-02-28 00:00:00
#   TimeIndex: 32.0
#   Value: 931723138.7617693
# --------------------------------------------------------------------------------
#
# File #78
# Relative Path: parsed_modified_results\sql_results\timeseries\aggregated\monthly\ventilation_monthly.parquet
# Shape: (1512, 6) (rows: 1512, columns: 6)
# Columns: ['building_id', 'Zone', 'Variable', 'DateTime', 'TimeIndex', 'Value']
#
# First row data:
#   building_id: 4136733
#   Zone: ZONE1_CORE
#   Variable: Zone Mechanical Ventilation Mass Flow Rate
#   DateTime: 2013-02-28 00:00:00
#   TimeIndex: 32.0
#   Value: 0.0001773271572355944
# --------------------------------------------------------------------------------
#
# File #79
# Relative Path: parsed_modified_results\sql_results\timeseries\aggregated\monthly\zones_monthly.parquet
# Shape: (5124, 6) (rows: 5124, columns: 6)
# Columns: ['building_id', 'Zone', 'Variable', 'DateTime', 'TimeIndex', 'Value']
#
# First row data:
#   building_id: 4136733
#   Zone: ZONE1_CORE
#   Variable: Zone Mean Air Temperature
#   DateTime: 2013-02-28 00:00:00
#   TimeIndex: 32.0
#   Value: 15.485632002948556
# --------------------------------------------------------------------------------
#
# File #80
# Relative Path: parsed_modified_results\sql_results\timeseries\hourly\hvac_2013.parquet
# Shape: (996, 9) (rows: 996, columns: 9)
# Columns: ['TimeIndex', 'DateTime', 'Variable', 'Zone', 'Value', 'Units', 'ReportingFrequency', 'IDF_Zone', 'building_id']
#
# First row data:
#   TimeIndex: 32
#   DateTime: 2013-02-01 00:00:00
#   Variable: Water Heater Heating Energy
#   Zone: MYDHW_0_WATERHEATER
#   Value: 931723138.7617693
#   Units: J
#   ReportingFrequency: Monthly
#   IDF_Zone: MYDHW_0_WATERHEATER
#   building_id: 4136733
# --------------------------------------------------------------------------------
#
# File #81
# Relative Path: parsed_modified_results\sql_results\timeseries\hourly\ventilation_2013.parquet
# Shape: (1512, 9) (rows: 1512, columns: 9)
# Columns: ['TimeIndex', 'DateTime', 'Variable', 'Zone', 'Value', 'Units', 'ReportingFrequency', 'IDF_Zone', 'building_id']
#
# First row data:
#   TimeIndex: 32
#   DateTime: 2013-02-01 00:00:00
#   Variable: Zone Mechanical Ventilation Mass Flow Rate
#   Zone: ZONE1_FRONTPERIMETER
#   Value: 0.003085857483011965
#   Units: kg/s
#   ReportingFrequency: Monthly
#   IDF_Zone: Zone1_FrontPerimeter
#   building_id: 4136733
# --------------------------------------------------------------------------------
#
# File #82
# Relative Path: parsed_modified_results\sql_results\timeseries\hourly\zones_2013.parquet
# Shape: (5124, 9) (rows: 5124, columns: 9)
# Columns: ['TimeIndex', 'DateTime', 'Variable', 'Zone', 'Value', 'Units', 'ReportingFrequency', 'IDF_Zone', 'building_id']
#
# First row data:
#   TimeIndex: 32
#   DateTime: 2013-02-01 00:00:00
#   Variable: Zone Mean Air Temperature
#   Zone: ZONE1_FRONTPERIMETER
#   Value: 18.185341331465718
#   Units: C
#   ReportingFrequency: Monthly
#   IDF_Zone: Zone1_FrontPerimeter
#   building_id: 4136733
# --------------------------------------------------------------------------------
#
# File #83
# Relative Path: sensitivity_results\modification_sensitivity_results.parquet
# Shape: (688, 18) (rows: 688, columns: 18)
# Columns: ['level', 'parameter', 'category', 'output_variable', 'sensitivity_score', 'p_value', 'ci_lower', 'ci_upper', 'n_samples', 'elasticity', 'r_squared', 'zone_name', 'building_id', 'interaction_type', 'avg_zone_param_change', 'avg_output_change', 'significance', 'confidence_level']
#
# First row data:
#   level: building
#   parameter: param_mean
#   category: param
#   output_variable: Zone Air System Sensible Heating Energy
#   sensitivity_score: 18907693196.31405
#   p_value: 0.1
#   ci_lower: 15126154557.051239
#   ci_upper: 22689231835.57686
#   n_samples: 1
#   elasticity: 18907693196.31405
#   r_squared: 1.0
#   zone_name: None
#   building_id: None
#   interaction_type: None
#   avg_zone_param_change: nan
#   avg_output_change: nan
#   significance:
#   confidence_level: low
# --------------------------------------------------------------------------------
#
# Total parquet files found: 83

# %%
import os
import pandas as pd
from pathlib import Path
import pyarrow.parquet as pq

def explore_parquet_files(root_dir):
    """
    Traverse directory tree to find parquet files and display their info.
    
    Args:
        root_dir (str): Root directory path to start searching from
    """
    root_path = Path(root_dir)
    
    # Check if the directory exists
    if not root_path.exists():
        print(f"Error: Directory '{root_dir}' does not exist.")
        return
    
    # Counter for found files
    file_count = 0
    
    print(f"Scanning directory: {root_dir}")
    print("-" * 80)
    
    # Walk through all subdirectories
    for dirpath, dirnames, filenames in os.walk(root_dir):
        for filename in filenames:
            # Check if file has .parquet extension
            if filename.lower().endswith('.parquet'):
                file_count += 1
                full_path = Path(dirpath) / filename
                
                # Get relative path from root directory
                try:
                    relative_path = full_path.relative_to(root_path)
                except ValueError:
                    relative_path = full_path
                
                print(f"\nFile #{file_count}")
                print(f"Relative Path: {relative_path}")
                
                try:
                    # Read the parquet file
                    df = pd.read_parquet(full_path, engine='pyarrow')
                    
                    # Display file info
                    print(f"Shape: {df.shape} (rows: {len(df)}, columns: {len(df.columns)})")
                    
                    # Display first row
                    if len(df) > 0:
                        print("\nFirst row data:")
                        first_row = df.iloc[0]
                        for col, value in first_row.items():
                            dtype = df[col].dtype
                            print(f"  {col} ({dtype}): {value}")
                    else:
                        print("  (File is empty)")
                        
                except Exception as e:
                    print(f"  Error reading file: {str(e)}")
                
                print("-" * 80)
    
    if file_count == 0:
        print("No parquet files found in the specified directory.")
    else:
        print(f"\nTotal parquet files found: {file_count}")


def explore_parquet_files_detailed(root_dir, max_rows_preview=5):
    """
    Enhanced version with more details and options.
    
    Args:
        root_dir (str): Root directory path to start searching from
        max_rows_preview (int): Number of rows to preview (default: 5)
    """
    root_path = Path(root_dir)
    
    if not root_path.exists():
        print(f"Error: Directory '{root_dir}' does not exist.")
        return
    
    parquet_files = []
    
    # Collect all parquet files first
    for dirpath, dirnames, filenames in os.walk(root_dir):
        for filename in filenames:
            if filename.lower().endswith('.parquet'):
                full_path = Path(dirpath) / filename
                relative_path = full_path.relative_to(root_path)
                parquet_files.append((full_path, relative_path))
    
    if not parquet_files:
        print("No parquet files found.")
        return
    
    print(f"Found {len(parquet_files)} parquet file(s)")
    print("=" * 80)
    
    for idx, (full_path, relative_path) in enumerate(parquet_files, 1):
        print(f"\n[{idx}/{len(parquet_files)}] {relative_path}")
        print("-" * 40)
        
        try:
            # Get file size
            file_size = full_path.stat().st_size / (1024 * 1024)  # Convert to MB
            print(f"File size: {file_size:.2f} MB")
            
            # Read parquet metadata without loading all data
            parquet_file = pq.ParquetFile(full_path)
            metadata = parquet_file.metadata
            
            print(f"Number of row groups: {metadata.num_row_groups}")
            print(f"Total rows: {metadata.num_rows}")
            
            # Read just the first few rows
            df_preview = pd.read_parquet(full_path, engine='pyarrow').head(max_rows_preview)
            
            print(f"\nColumn info:")
            for col in df_preview.columns:
                dtype = df_preview[col].dtype
                print(f"  - {col}: {dtype}")
            
            print(f"\nFirst {min(len(df_preview), max_rows_preview)} row(s):")
            print(df_preview.to_string())
            
        except Exception as e:
            print(f"Error processing file: {str(e)}")


# Main execution
if __name__ == "__main__":
    # Your directory path
    directory_path = r"D:\Documents\daily\E_Plus_2040_py\output\2dae68d1-4b75-4c75-9471-7b6d931af865"
    
    # Run the basic explorer
    print("=== BASIC PARQUET FILE EXPLORER ===\n")
    explore_parquet_files(directory_path)
    
    # Uncomment below to run the detailed explorer instead
    print("\n\n=== DETAILED PARQUET FILE EXPLORER ===\n")
    # explore_parquet_files_detailed(directory_path, max_rows_preview=3)
# Out:
# === BASIC PARQUET FILE EXPLORER ===
#
# Scanning directory: D:\Documents\daily\E_Plus_2040_py\output\2dae68d1-4b75-4c75-9471-7b6d931af865
# --------------------------------------------------------------------------------
#
# File #1
# Relative Path: modified_idfs\modifications_detail_20250623_182931.parquet
# Shape: (363, 10) (rows: 363, columns: 10)
#
# First row data:
#   building_id (object): 4136733
#   variant_id (object): variant_0
#   category (object): lighting
#   object_type (object): LIGHTS
#   object_name (object): Lights_ALL_ZONES
#   field_name (object):
#   original_value (object): 0.1
#   new_value (object): 0.2
#   change_type (object): absolute
#   timestamp (object): 2025-06-23T18:29:31.991154
# --------------------------------------------------------------------------------
#
# File #2
# Relative Path: modified_idfs\modifications_summary_20250623_182931.parquet
# Shape: (9, 7) (rows: 9, columns: 7)
#
# First row data:
#   building_id (object): 4136733
#   variant_id (object): variant_0
#   success (bool): True
#   output_file (object): /usr/src/app/output/2dae68d1-4b75-4c75-9471-7b6d931af865/modified_idfs/building_4136733_variant_0.idf
#   num_modifications (int64): 47
#   categories_modified (object): ['geometry' 'shading' 'dhw' 'site_location' 'materials'
#  'simulation_control' 'ventilation' 'lighting' 'equipment']
#   timestamp (object): 2025-06-23T18:29:32.020707
# --------------------------------------------------------------------------------
#
# File #3
# Relative Path: parsed_data\analysis_ready\parameter_matrix.parquet
# Shape: (3, 7) (rows: 3, columns: 7)
#
# First row data:
#   building_id (object): 4136733
#   ventilation_design_flow_rate (object): None
#   infiltration_design_flow_rate (object): 2.900821e-04
#   lighting_watts_per_zone_floor_area (object): 0
#   equipment_watts_per_zone_floor_area (object): 0
#   dhw_tank_volume (object): 0.2775029318369119
#   dhw_heater_maximum_capacity (object): 4223.210738148823
# --------------------------------------------------------------------------------
#
# File #4
# Relative Path: parsed_data\analysis_ready\feature_sets\extraction_statistics.parquet
# Shape: (1, 6) (rows: 1, columns: 6)
#
# First row data:
#   building_id (object): 4136738
#   extraction_date (object): 2025-06-23T18:29:27.535264
#   categories_processed (int64): 7
#   variables_extracted (int64): 28
#   data_points_extracted (int64): 660
#   missing_variables_count (int64): 76
# --------------------------------------------------------------------------------
#
# File #5
# Relative Path: parsed_data\analysis_ready\feature_sets\missing_variables_detail.parquet
# Shape: (76, 3) (rows: 76, columns: 3)
#
# First row data:
#   category (object): geometry
#   variable (object): Zone Air Temperature
#   building_id (object): 4136738
# --------------------------------------------------------------------------------
#
# File #6
# Relative Path: parsed_data\idf_data\by_building\4136733_snapshot.parquet
# Shape: (293, 7) (rows: 293, columns: 7)
#
# First row data:
#   building_id (object): 4136733
#   category (object): simulation_control
#   output_file (object): simulation_control
#   object_type (object): Version
#   object_name (object): 22.2
#   parameters (object): {"Version Identifier": "22.2"}
#   zone_name (object): None
# --------------------------------------------------------------------------------
#
# File #7
# Relative Path: parsed_data\idf_data\by_category\dhw.parquet
# Shape: (3, 54) (rows: 3, columns: 54)
#
# First row data:
#   building_id (object): 4136733
#   object_type (object): WATERHEATER:MIXED
#   object_name (object): MyDHW_0_WaterHeater
#   name (object): MyDHW_0_WaterHeater
#   tank_volume (object): 0.2775029318369119
#   tank_volume_numeric (float64): 0.2775029318369119
#   setpoint_temperature_schedule_name (object): MyDHW_0_Setpoint
#   deadband_temperature_difference (object): 2
#   deadband_temperature_difference_numeric (float64): 2.0
#   maximum_temperature_limit (object): 80
#   maximum_temperature_limit_numeric (float64): 80.0
#   heater_control_type (object): CYCLE
#   heater_maximum_capacity (object): 4223.210738148823
#   heater_maximum_capacity_numeric (float64): 4223.210738148823
#   heater_ignition_minimum_flow_rate (object): 0
#   heater_ignition_minimum_flow_rate_numeric (float64): 0.0
#   heater_ignition_delay (object): 0
#   heater_ignition_delay_numeric (float64): 0.0
#   heater_fuel_type (object): NaturalGas
#   heater_thermal_efficiency (object): 0.9
#   heater_thermal_efficiency_numeric (float64): 0.9
#   off_cycle_parasitic_fuel_consumption_rate (object): 0
#   off_cycle_parasitic_fuel_consumption_rate_numeric (float64): 0.0
#   off_cycle_parasitic_fuel_type (object): Electricity
#   off_cycle_parasitic_heat_fraction_to_tank (object): 0
#   off_cycle_parasitic_heat_fraction_to_tank_numeric (float64): 0.0
#   on_cycle_parasitic_fuel_consumption_rate (object): 0
#   on_cycle_parasitic_fuel_consumption_rate_numeric (float64): 0.0
#   on_cycle_parasitic_fuel_type (object): Electricity
#   on_cycle_parasitic_heat_fraction_to_tank (object): 0
#   on_cycle_parasitic_heat_fraction_to_tank_numeric (float64): 0.0
#   ambient_temperature_indicator (object): SCHEDULE
#   ambient_temperature_schedule_name (object): Always22C
#   off_cycle_loss_coefficient_to_ambient_temperature (object): 5
#   off_cycle_loss_coefficient_to_ambient_temperature_numeric (float64): 5.0
#   off_cycle_loss_fraction_to_zone (object): 1
#   off_cycle_loss_fraction_to_zone_numeric (float64): 1.0
#   on_cycle_loss_coefficient_to_ambient_temperature (object): 5
#   on_cycle_loss_coefficient_to_ambient_temperature_numeric (float64): 5.0
#   on_cycle_loss_fraction_to_zone (object): 1
#   on_cycle_loss_fraction_to_zone_numeric (float64): 1.0
#   peak_use_flow_rate (object): 2.745939e-06
#   peak_use_flow_rate_numeric (float64): 2.745939e-06
#   use_flow_rate_fraction_schedule_name (object): MyDHW_0_UseFraction
#   use_side_effectiveness (object): 1
#   use_side_effectiveness_numeric (float64): 1.0
#   source_side_effectiveness (object): 1
#   source_side_effectiveness_numeric (float64): 1.0
#   use_side_design_flow_rate (object): autosize
#   source_side_design_flow_rate (object): autosize
#   indirect_water_heating_recovery_time (object): 1.5
#   indirect_water_heating_recovery_time_numeric (float64): 1.5
#   source_side_flow_control_mode (object): IndirectHeatPrimarySetpoint
#   end_use_subcategory (object): General
# --------------------------------------------------------------------------------
#
# File #8
# Relative Path: parsed_data\idf_data\by_category\equipment.parquet
# Shape: (6, 17) (rows: 6, columns: 17)
#
# First row data:
#   building_id (object): 4136733
#   object_type (object): ELECTRICEQUIPMENT
#   object_name (object): Parasitic_ALL_ZONES
#   zone_name (object): ALL_ZONES
#   name (object): Parasitic_ALL_ZONES
#   zone_or_zonelist_name (object): ALL_ZONES
#   schedule_name (object): ParasiticSchedule
#   design_level_calculation_method (object): Watts/Area
#   watts_per_zone_floor_area (object): 0
#   watts_per_zone_floor_area_numeric (float64): 0.0
#   fraction_latent (object): 0
#   fraction_latent_numeric (float64): 0.0
#   fraction_radiant (object): 0.1
#   fraction_radiant_numeric (float64): 0.1
#   fraction_lost (object): 0.8
#   fraction_lost_numeric (float64): 0.8
#   end_use_subcategory (object): General
# --------------------------------------------------------------------------------
#
# File #9
# Relative Path: parsed_data\idf_data\by_category\geometry_surfaces.parquet
# Shape: (109, 47) (rows: 109, columns: 47)
#
# First row data:
#   building_id (object): 4136733
#   object_type (object): GlobalGeometryRules
#   object_name (object): UpperLeftCorner
#   starting_vertex_position (object): UpperLeftCorner
#   vertex_entry_direction (object): CounterClockWise
#   coordinate_system (object): Relative
#   zone_name (object): None
#   name (object): None
#   surface_type (object): None
#   construction_name (object): None
#   outside_boundary_condition (object): None
#   sun_exposure (object): None
#   wind_exposure (object): None
#   view_factor_to_ground (object): None
#   number_of_vertices (object): None
#   field_12 (object): None
#   field_12_numeric (float64): nan
#   field_13 (object): None
#   field_13_numeric (float64): nan
#   field_14 (object): None
#   field_14_numeric (float64): nan
#   field_15 (object): None
#   field_15_numeric (float64): nan
#   field_16 (object): None
#   field_16_numeric (float64): nan
#   field_17 (object): None
#   field_17_numeric (float64): nan
#   field_18 (object): None
#   field_18_numeric (float64): nan
#   field_19 (object): None
#   field_19_numeric (float64): nan
#   field_20 (object): None
#   field_20_numeric (float64): nan
#   field_21 (object): None
#   field_21_numeric (float64): nan
#   field_22 (object): None
#   field_22_numeric (float64): nan
#   field_23 (object): None
#   field_23_numeric (float64): nan
#   outside_boundary_condition_object (object): None
#   building_surface_name (object): None
#   multiplier (object): None
#   multiplier_numeric (float64): nan
#   field_10 (object): None
#   field_10_numeric (float64): nan
#   field_11 (object): None
#   field_11_numeric (float64): nan
# --------------------------------------------------------------------------------
#
# File #10
# Relative Path: parsed_data\idf_data\by_category\geometry_zones.parquet
# Shape: (19, 31) (rows: 19, columns: 31)
#
# First row data:
#   building_id (object): 4136733
#   object_type (object): ZONE
#   object_name (object): Zone1_FrontPerimeter
#   zone_name (object): Zone1_FrontPerimeter
#   name (object): Zone1_FrontPerimeter
#   direction_of_relative_north (object): 0
#   direction_of_relative_north_numeric (float64): 0.0
#   x_origin (object): 0
#   x_origin_numeric (float64): 0.0
#   y_origin (object): 0
#   y_origin_numeric (float64): 0.0
#   z_origin (object): 0
#   z_origin_numeric (float64): 0.0
#   type (object): 1
#   type_numeric (float64): 1.0
#   multiplier (object): 1
#   multiplier_numeric (float64): 1.0
#   ceiling_height (object): autocalculate
#   volume (object): autocalculate
#   floor_area (object): autocalculate
#   part_of_total_floor_area (object): Yes
#   zone_1_name (object): None
#   zone_2_name (object): None
#   zone_3_name (object): None
#   zone_4_name (object): None
#   zone_5_name (object): None
#   field_7 (object): None
#   field_8 (object): None
#   field_9 (object): None
#   field_10 (object): None
#   field_11 (object): None
# --------------------------------------------------------------------------------
#
# File #11
# Relative Path: parsed_data\idf_data\by_category\hvac_equipment.parquet
# Shape: (48, 41) (rows: 48, columns: 41)
#
# First row data:
#   building_id (object): 4136733
#   object_type (object): ZONEHVAC:IDEALLOADSAIRSYSTEM
#   object_name (object): Zone1_FrontPerimeter_Ideal_Loads
#   name (object): Zone1_FrontPerimeter_Ideal_Loads
#   availability_schedule_name (object): VentSched_Twoandahalfstory_House
#   zone_supply_air_node_name (object): Zone1_FrontPerimeter_INLETS
#   maximum_heating_supply_air_temperature (object): 53.68235607082006
#   maximum_heating_supply_air_temperature_numeric (float64): 53.68235607082006
#   minimum_cooling_supply_air_temperature (object): 13.353398974845822
#   minimum_cooling_supply_air_temperature_numeric (float64): 13.353398974845822
#   maximum_heating_supply_air_humidity_ratio (object): 0.0156
#   maximum_heating_supply_air_humidity_ratio_numeric (float64): 0.0156
#   minimum_cooling_supply_air_humidity_ratio (object): 0.0077
#   minimum_cooling_supply_air_humidity_ratio_numeric (float64): 0.0077
#   heating_limit (object): LimitFlowRateAndCapacity
#   maximum_heating_air_flow_rate (object): Autosize
#   maximum_sensible_heating_capacity (object): Autosize
#   cooling_limit (object): LimitFlowRateAndCapacity
#   maximum_cooling_air_flow_rate (object): Autosize
#   maximum_total_cooling_capacity (object): Autosize
#   dehumidification_control_type (object): None
#   cooling_sensible_heat_ratio (object): 0.7
#   cooling_sensible_heat_ratio_numeric (float64): 0.7
#   humidification_control_type (object): None
#   design_specification_outdoor_air_object_name (object): DSOA_Global
#   demand_controlled_ventilation_type (object): None
#   outdoor_air_economizer_type (object): NoEconomizer
#   heat_recovery_type (object): Sensible
#   sensible_heat_recovery_effectiveness (object): 0.7676699487422911
#   sensible_heat_recovery_effectiveness_numeric (float64): 0.7676699487422911
#   latent_heat_recovery_effectiveness (object): 0
#   latent_heat_recovery_effectiveness_numeric (float64): 0.0
#   field_1 (object): None
#   field_2 (object): None
#   field_3 (object): None
#   field_4 (object): None
#   field_5 (object): None
#   field_5_numeric (float64): nan
#   field_6 (object): None
#   field_6_numeric (float64): nan
#   zone_name (object): None
# --------------------------------------------------------------------------------
#
# File #12
# Relative Path: parsed_data\idf_data\by_category\hvac_systems.parquet
# Shape: (19, 51) (rows: 19, columns: 51)
#
# First row data:
#   building_id (object): 4136733
#   object_type (object): SIZING:ZONE
#   object_name (object): ALL_ZONES
#   field_1 (object): ALL_ZONES
#   field_2 (object): SupplyAirTemperature
#   field_3 (object): 14.139426798457883
#   field_3_numeric (float64): 14.139426798457883
#   field_5 (object): SupplyAirTemperature
#   field_6 (object): 48.100043020890666
#   field_6_numeric (float64): 48.100043020890666
#   field_8 (object): 8.775029e-03
#   field_8_numeric (float64): 0.008775029
#   field_9 (object): 3.723211e-03
#   field_9_numeric (float64): 0.003723211
#   field_10 (object): DSOA_Global
#   field_11 (object): 1
#   field_11_numeric (float64): 1.0
#   field_12 (object): 1
#   field_12_numeric (float64): 1.0
#   field_13 (object): DesignDayWithLimit
#   field_14 (object): 0
#   field_14_numeric (float64): 0.0
#   field_15 (object): 0.000762
#   field_15_numeric (float64): 0.000762
#   field_16 (object): 0
#   field_16_numeric (float64): 0.0
#   field_17 (object): 0.2
#   field_17_numeric (float64): 0.2
#   field_18 (object): DesignDay
#   field_19 (object): 0
#   field_19_numeric (float64): 0.0
#   field_20 (object): 0.002032
#   field_20_numeric (float64): 0.002032
#   field_21 (object): 0.1415762
#   field_21_numeric (float64): 0.1415762
#   field_22 (object): 0.3
#   field_22_numeric (float64): 0.3
#   field_23 (object): DSZAD_Global
#   field_24 (object): No
#   field_25 (object): NeutralSupplyAir
#   field_26 (object): autosize
#   field_27 (object): autosize
#   field_28 (object): Sensible Load Only No Latent Load
#   field_29 (object): HumidityRatioDifference
#   field_31 (object): 0.005
#   field_31_numeric (float64): 0.005
#   field_32 (object): HumidityRatioDifference
#   field_34 (object): 0.005
#   field_34_numeric (float64): 0.005
#   name (object): None
#   node_1_name (object): None
# --------------------------------------------------------------------------------
#
# File #13
# Relative Path: parsed_data\idf_data\by_category\hvac_thermostats.parquet
# Shape: (32, 13) (rows: 32, columns: 13)
#
# First row data:
#   building_id (object): 4136733
#   object_type (object): ZONECONTROL:THERMOSTAT
#   object_name (object): Zone1_FrontPerimeter_CONTROLS
#   field_1 (object): Zone1_FrontPerimeter_CONTROLS
#   field_2 (object): Zone1_FrontPerimeter
#   field_3 (object): ZONE_CONTROL_TYPE_SCHEDULE
#   field_4 (object): ThermostatSetpoint:DualSetpoint
#   field_5 (object): Zone1_FrontPerimeter_SETPOINTS
#   field_12 (object): 0
#   field_12_numeric (float64): 0.0
#   name (object): None
#   heating_setpoint_temperature_schedule_name (object): None
#   cooling_setpoint_temperature_schedule_name (object): None
# --------------------------------------------------------------------------------
#
# File #14
# Relative Path: parsed_data\idf_data\by_category\infiltration.parquet
# Shape: (16, 18) (rows: 16, columns: 18)
#
# First row data:
#   building_id (object): 4136733
#   object_type (object): ZONEINFILTRATION:DESIGNFLOWRATE
#   object_name (object): Infil_resi_D_Zone1_FrontPerimeter
#   zone_name (object): Zone1_FrontPerimeter
#   name (object): Infil_resi_D_Zone1_FrontPerimeter
#   zone_or_zonelist_name (object): Zone1_FrontPerimeter
#   schedule_name (object): InfilSched_Twoandahalfstory_House
#   design_flow_rate_calculation_method (object): Flow/Area
#   design_flow_rate (object): 2.900821e-04
#   design_flow_rate_numeric (float64): 0.0002900821
#   constant_term_coefficient (object): 0
#   constant_term_coefficient_numeric (float64): 0.0
#   temperature_term_coefficient (object): 7.142857e-02
#   temperature_term_coefficient_numeric (float64): 0.07142857
#   velocity_term_coefficient (object): 9.523810e-02
#   velocity_term_coefficient_numeric (float64): 0.0952381
#   velocity_squared_term_coefficient (object): 0
#   velocity_squared_term_coefficient_numeric (float64): 0.0
# --------------------------------------------------------------------------------
#
# File #15
# Relative Path: parsed_data\idf_data\by_category\lighting.parquet
# Shape: (3, 24) (rows: 3, columns: 24)
#
# First row data:
#   building_id (object): 4136733
#   object_type (object): LIGHTS
#   object_name (object): Lights_ALL_ZONES
#   zone_name (object): ALL_ZONES
#   name (object): Lights_ALL_ZONES
#   zone_or_zonelist_name (object): ALL_ZONES
#   schedule_name (object): LightsSchedule
#   design_level_calculation_method (object): Watts/Area
#   watts_per_zone_floor_area (object): 0
#   watts_per_zone_floor_area_numeric (float64): 0.0
#   return_air_fraction (object): 0.8
#   return_air_fraction_numeric (float64): 0.8
#   fraction_radiant (object): 0.1
#   fraction_radiant_numeric (float64): 0.1
#   fraction_visible (object): 0.1
#   fraction_visible_numeric (float64): 0.1
#   fraction_replaceable (object): 1
#   fraction_replaceable_numeric (float64): 1.0
#   end_use_subcategory (object): General
#   return_air_fraction_calculated_from_plenum_temperature (object): No
#   return_air_fraction_function_of_plenum_temperature_coefficient_1 (object): 0
#   return_air_fraction_function_of_plenum_temperature_coefficient_1_numeric (float64): 0.0
#   return_air_fraction_function_of_plenum_temperature_coefficient_2 (object): 0
#   return_air_fraction_function_of_plenum_temperature_coefficient_2_numeric (float64): 0.0
# --------------------------------------------------------------------------------
#
# File #16
# Relative Path: parsed_data\idf_data\by_category\materials_constructions.parquet
# Shape: (45, 5) (rows: 45, columns: 5)
#
# First row data:
#   building_id (object): 4136733
#   object_type (object): CONSTRUCTION
#   object_name (object): CEILING1C
#   name (object): CEILING1C
#   outside_layer (object): Roof_R2.5
# --------------------------------------------------------------------------------
#
# File #17
# Relative Path: parsed_data\idf_data\by_category\materials_materials.parquet
# Shape: (18, 21) (rows: 18, columns: 21)
#
# First row data:
#   building_id (object): 4136733
#   object_type (object): MATERIAL
#   object_name (object): Concrete_200mm
#   name (object): Concrete_200mm
#   roughness (object): MediumRough
#   thickness (object): 1.952980e-01
#   thickness_numeric (float64): 0.195298
#   conductivity (object): 0.0781191888777523
#   conductivity_numeric (float64): 0.0781191888777523
#   density (object): 2300.535528810336
#   density_numeric (float64): 2300.535528810336
#   specific_heat (object): 852.6535969683864
#   specific_heat_numeric (float64): 852.6535969683864
#   thermal_absorptance (object): 0.9
#   thermal_absorptance_numeric (float64): 0.9
#   solar_absorptance (object): 0.7
#   solar_absorptance_numeric (float64): 0.7
#   visible_absorptance (object): 0.7
#   visible_absorptance_numeric (float64): 0.7
#   thermal_resistance (object): None
#   thermal_resistance_numeric (float64): nan
# --------------------------------------------------------------------------------
#
# File #18
# Relative Path: parsed_data\idf_data\by_category\materials_windowmaterials.parquet
# Shape: (13, 65) (rows: 13, columns: 65)
#
# First row data:
#   building_id (object): 4136733
#   object_type (object): WINDOWMATERIAL:SIMPLEGLAZINGSYSTEM
#   object_name (object): Window_U2.9
#   name (object): Window_U2.9
#   u_factor (object): 2.9
#   u_factor_numeric (float64): 2.9
#   solar_heat_gain_coefficient (object): 0.7014521644391364
#   solar_heat_gain_coefficient_numeric (float64): 0.7014521644391364
#   visible_transmittance (object): 0.7
#   visible_transmittance_numeric (float64): 0.7
#   slat_orientation (object): None
#   slat_width (object): None
#   slat_width_numeric (float64): nan
#   slat_separation (object): None
#   slat_separation_numeric (float64): nan
#   slat_thickness (object): None
#   slat_thickness_numeric (float64): nan
#   slat_angle (object): None
#   slat_angle_numeric (float64): nan
#   slat_conductivity (object): None
#   slat_conductivity_numeric (float64): nan
#   slat_beam_solar_transmittance (object): None
#   slat_beam_solar_transmittance_numeric (float64): nan
#   front_side_slat_beam_solar_reflectance (object): None
#   front_side_slat_beam_solar_reflectance_numeric (float64): nan
#   back_side_slat_beam_solar_reflectance (object): None
#   back_side_slat_beam_solar_reflectance_numeric (float64): nan
#   slat_diffuse_solar_transmittance (object): None
#   slat_diffuse_solar_transmittance_numeric (float64): nan
#   front_side_slat_diffuse_solar_reflectance (object): None
#   front_side_slat_diffuse_solar_reflectance_numeric (float64): nan
#   back_side_slat_diffuse_solar_reflectance (object): None
#   back_side_slat_diffuse_solar_reflectance_numeric (float64): nan
#   slat_beam_visible_transmittance (object): None
#   slat_beam_visible_transmittance_numeric (float64): nan
#   front_side_slat_beam_visible_reflectance (object): None
#   front_side_slat_beam_visible_reflectance_numeric (float64): nan
#   back_side_slat_beam_visible_reflectance (object): None
#   back_side_slat_beam_visible_reflectance_numeric (float64): nan
#   slat_diffuse_visible_transmittance (object): None
#   slat_diffuse_visible_transmittance_numeric (float64): nan
#   front_side_slat_diffuse_visible_reflectance (object): None
#   front_side_slat_diffuse_visible_reflectance_numeric (float64): nan
#   back_side_slat_diffuse_visible_reflectance (object): None
#   back_side_slat_diffuse_visible_reflectance_numeric (float64): nan
#   slat_infrared_hemispherical_transmittance (object): None
#   slat_infrared_hemispherical_transmittance_numeric (float64): nan
#   front_side_slat_infrared_hemispherical_emissivity (object): None
#   front_side_slat_infrared_hemispherical_emissivity_numeric (float64): nan
#   back_side_slat_infrared_hemispherical_emissivity (object): None
#   back_side_slat_infrared_hemispherical_emissivity_numeric (float64): nan
#   blind_to_glass_distance (object): None
#   blind_to_glass_distance_numeric (float64): nan
#   blind_top_opening_multiplier (object): None
#   blind_top_opening_multiplier_numeric (float64): nan
#   blind_bottom_opening_multiplier (object): None
#   blind_bottom_opening_multiplier_numeric (float64): nan
#   blind_left_side_opening_multiplier (object): None
#   blind_left_side_opening_multiplier_numeric (float64): nan
#   blind_right_side_opening_multiplier (object): None
#   blind_right_side_opening_multiplier_numeric (float64): nan
#   minimum_slat_angle (object): None
#   minimum_slat_angle_numeric (float64): nan
#   maximum_slat_angle (object): None
#   maximum_slat_angle_numeric (float64): nan
# --------------------------------------------------------------------------------
#
# File #19
# Relative Path: parsed_data\idf_data\by_category\outputs_all.parquet
# Shape: (51, 29) (rows: 51, columns: 29)
#
# First row data:
#   building_id (object): 4136733
#   object_type (object): Output:VariableDictionary
#   object_name (object): Regular
#   key_field (object): Regular
#   report_1_name (object): None
#   name (object): None
#   digits_after_decimal (object): None
#   digits_after_decimal_numeric (float64): nan
#   variable_or_meter_1_name (object): None
#   aggregation_type_for_variable_or_meter_1 (object): None
#   variable_or_meter_2_name (object): None
#   aggregation_type_for_variable_or_meter_2 (object): None
#   variable_or_meter_3_name (object): None
#   aggregation_type_for_variable_or_meter_3 (object): None
#   variable_or_meter_4_name (object): None
#   aggregation_type_for_variable_or_meter_4 (object): None
#   variable_or_meter_5_name (object): None
#   aggregation_type_for_variable_or_meter_5 (object): None
#   variable_or_meter_6_name (object): None
#   aggregation_type_for_variable_or_meter_6 (object): None
#   column_separator (object): None
#   key_value (object): None
#   variable_name (object): None
#   reporting_frequency (object): None
#   key_name (object): None
#   option_type (object): None
#   output_type (object): None
#   output_subtype (object): None
#   schedule_name (object): None
# --------------------------------------------------------------------------------
#
# File #20
# Relative Path: parsed_data\idf_data\by_category\schedules.parquet
# Shape: (48, 35) (rows: 48, columns: 35)
#
# First row data:
#   building_id (object): 4136733
#   object_type (object): SCHEDULETYPELIMITS
#   object_name (object): Temperature
#   name (object): Temperature
#   lower_limit_value (object): -100
#   lower_limit_value_numeric (float64): -100.0
#   upper_limit_value (object): 200
#   upper_limit_value_numeric (float64): 200.0
#   numeric_type (object): CONTINUOUS
#   unit_type (object): Dimensionless
#   schedule_type_limits_name (object): None
#   field_3 (object): None
#   field_4 (object): None
#   field_5 (object): None
#   field_6 (object): None
#   field_6_numeric (float64): nan
#   field_7 (object): None
#   field_8 (object): None
#   field_9 (object): None
#   field_10 (object): None
#   field_11 (object): None
#   field_12 (object): None
#   field_13 (object): None
#   field_14 (object): None
#   field_15 (object): None
#   field_16 (object): None
#   field_17 (object): None
#   field_18 (object): None
#   field_19 (object): None
#   field_20 (object): None
#   field_21 (object): None
#   field_22 (object): None
#   field_23 (object): None
#   hourly_value (object): None
#   hourly_value_numeric (float64): nan
# --------------------------------------------------------------------------------
#
# File #21
# Relative Path: parsed_data\idf_data\by_category\shading.parquet
# Shape: (10, 16) (rows: 10, columns: 16)
#
# First row data:
#   building_id (object): 4136733
#   object_type (object): WINDOWSHADINGCONTROL
#   object_name (object): ShadingCtrl_Zone1_FrontPerimeter_Wall_0_window
#   zone_name (object): Zone1_FrontPerimeter
#   name (object): ShadingCtrl_Zone1_FrontPerimeter_Wall_0_window
#   zone_or_zonelist_name (object): Zone1_FrontPerimeter
#   sequential_shading_control_number (object): 1
#   sequential_shading_control_number_numeric (float64): 1.0
#   shading_type (object): ExteriorBlind
#   shading_control_type (object): AlwaysOn
#   shading_control_is_scheduled (object): No
#   glare_control_is_active (object): No
#   shading_device_material_name (object): MyExternalLouvers_Zone1_FrontPerimeter_Wall_0_window
#   type_of_slat_angle_control_for_blinds (object): FixedSlatAngle
#   multiple_surface_control_type (object): Sequential
#   fenestration_surface_1_name (object): Zone1_FrontPerimeter_Wall_0 window
# --------------------------------------------------------------------------------
#
# File #22
# Relative Path: parsed_data\idf_data\by_category\simulation_control.parquet
# Shape: (15, 40) (rows: 15, columns: 40)
#
# First row data:
#   building_id (object): 4136733
#   object_type (object): Version
#   object_name (object): 22.2
#   version_identifier (object): 22.2
#   version_identifier_numeric (float64): 22.2
#   do_zone_sizing_calculation (object): None
#   do_system_sizing_calculation (object): None
#   do_plant_sizing_calculation (object): None
#   run_simulation_for_sizing_periods (object): None
#   run_simulation_for_weather_file_run_periods (object): None
#   do_hvac_sizing_simulation_for_sizing_periods (object): None
#   name (object): None
#   north_axis (object): None
#   north_axis_numeric (float64): nan
#   terrain (object): None
#   loads_convergence_tolerance_value (object): None
#   loads_convergence_tolerance_value_numeric (float64): nan
#   temperature_convergence_tolerance_value (object): None
#   temperature_convergence_tolerance_value_numeric (float64): nan
#   solar_distribution (object): None
#   maximum_number_of_warmup_days (object): None
#   maximum_number_of_warmup_days_numeric (float64): nan
#   minimum_number_of_warmup_days (object): None
#   minimum_number_of_warmup_days_numeric (float64): nan
#   number_of_timesteps_per_hour (object): None
#   number_of_timesteps_per_hour_numeric (float64): nan
#   begin_month (object): None
#   begin_month_numeric (float64): nan
#   begin_day_of_month (object): None
#   begin_day_of_month_numeric (float64): nan
#   end_month (object): None
#   end_month_numeric (float64): nan
#   end_day_of_month (object): None
#   end_day_of_month_numeric (float64): nan
#   day_of_week_for_start_day (object): None
#   use_weather_file_holidays_and_special_days (object): None
#   use_weather_file_daylight_saving_period (object): None
#   apply_weekend_holiday_rule (object): None
#   use_weather_file_rain_indicators (object): None
#   use_weather_file_snow_indicators (object): None
# --------------------------------------------------------------------------------
#
# File #23
# Relative Path: parsed_data\idf_data\by_category\site_location.parquet
# Shape: (12, 60) (rows: 12, columns: 60)
#
# First row data:
#   building_id (object): 4136733
#   object_type (object): Site:Location
#   object_name (object): Amsterdam_Netherlands
#   name (object): Amsterdam_Netherlands
#   latitude (object): 52.37
#   latitude_numeric (float64): 52.37
#   longitude (object): 4.89
#   longitude_numeric (float64): 4.89
#   time_zone (object): 1
#   time_zone_numeric (float64): 1.0
#   elevation (object): -2
#   elevation_numeric (float64): -2.0
#   month (object): None
#   month_numeric (float64): nan
#   day_of_month (object): None
#   day_of_month_numeric (float64): nan
#   day_type (object): None
#   maximum_dry_bulb_temperature (object): None
#   maximum_dry_bulb_temperature_numeric (float64): nan
#   daily_dry_bulb_temperature_range (object): None
#   daily_dry_bulb_temperature_range_numeric (float64): nan
#   humidity_condition_type (object): None
#   wetbulb_or_dewpoint_at_maximum_dry_bulb (object): None
#   wetbulb_or_dewpoint_at_maximum_dry_bulb_numeric (float64): nan
#   barometric_pressure (object): None
#   barometric_pressure_numeric (float64): nan
#   wind_speed (object): None
#   wind_speed_numeric (float64): nan
#   wind_direction (object): None
#   wind_direction_numeric (float64): nan
#   rain_indicator (object): None
#   snow_indicator (object): None
#   daylight_saving_time_indicator (object): None
#   solar_model_indicator (object): None
#   sky_clearness (object): None
#   sky_clearness_numeric (float64): nan
#   january_ground_temperature (object): None
#   january_ground_temperature_numeric (float64): nan
#   february_ground_temperature (object): None
#   february_ground_temperature_numeric (float64): nan
#   march_ground_temperature (object): None
#   march_ground_temperature_numeric (float64): nan
#   april_ground_temperature (object): None
#   april_ground_temperature_numeric (float64): nan
#   may_ground_temperature (object): None
#   may_ground_temperature_numeric (float64): nan
#   june_ground_temperature (object): None
#   june_ground_temperature_numeric (float64): nan
#   july_ground_temperature (object): None
#   july_ground_temperature_numeric (float64): nan
#   august_ground_temperature (object): None
#   august_ground_temperature_numeric (float64): nan
#   september_ground_temperature (object): None
#   september_ground_temperature_numeric (float64): nan
#   october_ground_temperature (object): None
#   october_ground_temperature_numeric (float64): nan
#   november_ground_temperature (object): None
#   november_ground_temperature_numeric (float64): nan
#   december_ground_temperature (object): None
#   december_ground_temperature_numeric (float64): nan
# --------------------------------------------------------------------------------
#
# File #24
# Relative Path: parsed_data\idf_data\by_category\ventilation.parquet
# Shape: (12, 53) (rows: 12, columns: 53)
#
# First row data:
#   building_id (object): 4136733
#   object_type (object): DESIGNSPECIFICATION:OUTDOORAIR
#   object_name (object): DSOA_Global
#   name (object): DSOA_Global
#   outdoor_air_method (object): Sum
#   outdoor_air_flow_per_person (object): 0.00236
#   outdoor_air_flow_per_person_numeric (float64): 0.00236
#   outdoor_air_flow_per_zone_floor_area (object): 0.000305
#   outdoor_air_flow_per_zone_floor_area_numeric (float64): 0.000305
#   outdoor_air_flow_per_zone (object): 0
#   outdoor_air_flow_per_zone_numeric (float64): 0.0
#   outdoor_air_flow_air_changes_per_hour (object): 0
#   outdoor_air_flow_air_changes_per_hour_numeric (float64): 0.0
#   field_1 (object): None
#   field_2 (object): None
#   field_2_numeric (float64): nan
#   field_3 (object): None
#   field_3_numeric (float64): nan
#   field_5 (object): None
#   field_5_numeric (float64): nan
#   field_6 (object): None
#   field_6_numeric (float64): nan
#   zone_name (object): None
#   zone_or_zonelist_name (object): None
#   schedule_name (object): None
#   design_flow_rate_calculation_method (object): None
#   design_flow_rate (object): None
#   design_flow_rate_numeric (float64): nan
#   ventilation_type (object): None
#   fan_pressure_rise (object): None
#   fan_pressure_rise_numeric (float64): nan
#   fan_total_efficiency (object): None
#   fan_total_efficiency_numeric (float64): nan
#   constant_term_coefficient (object): None
#   constant_term_coefficient_numeric (float64): nan
#   temperature_term_coefficient (object): None
#   temperature_term_coefficient_numeric (float64): nan
#   velocity_term_coefficient (object): None
#   velocity_term_coefficient_numeric (float64): nan
#   velocity_squared_term_coefficient (object): None
#   velocity_squared_term_coefficient_numeric (float64): nan
#   minimum_indoor_temperature (object): None
#   minimum_indoor_temperature_numeric (float64): nan
#   maximum_indoor_temperature (object): None
#   maximum_indoor_temperature_numeric (float64): nan
#   delta_temperature (object): None
#   delta_temperature_numeric (float64): nan
#   minimum_outdoor_temperature (object): None
#   minimum_outdoor_temperature_numeric (float64): nan
#   maximum_outdoor_temperature (object): None
#   maximum_outdoor_temperature_numeric (float64): nan
#   maximum_wind_speed (object): None
#   maximum_wind_speed_numeric (float64): nan
# --------------------------------------------------------------------------------
#
# File #25
# Relative Path: parsed_data\metadata\building_registry.parquet
# Shape: (3, 9) (rows: 3, columns: 9)
#
# First row data:
#   building_id (object): 4136733
#   ogc_fid (object): 4136733
#   idf_path (object): /usr/src/app/output/2dae68d1-4b75-4c75-9471-7b6d931af865/output_IDFs/building_4136733.idf
#   sql_path (object): /usr/src/app/output/2dae68d1-4b75-4c75-9471-7b6d931af865/Sim_Results/2020/simulation_bldg0_4136733.sql
#   zone_count (int64): 10
#   output_variables (int64): 65
#   output_meters (int64): 7
#   status (object): completed
#   last_modified (datetime64[ns]): 2025-06-23 18:29:20.304755
# --------------------------------------------------------------------------------
#
# File #26
# Relative Path: parsed_data\metadata\missing_outputs.parquet
# Shape: (71, 4) (rows: 71, columns: 4)
#
# First row data:
#   variable (object): Boiler Heating Energy
#   key (object): *
#   frequency (object): Monthly
#   building_id (object): 4136733
# --------------------------------------------------------------------------------
#
# File #27
# Relative Path: parsed_data\metadata\output_validation.parquet
# Shape: (3, 6) (rows: 3, columns: 6)
#
# First row data:
#   building_id (object): 4136733
#   total_requested (int64): 65
#   found (int64): 38
#   missing (object): [{'frequency': 'Monthly', 'key': '*', 'variable': 'Boiler Heating Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Air System Latent Cooling Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Ventilation Standard Density Volume Flow Rate'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Ventilation Sensible Heat Loss Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Ventilation Sensible Heat Gain Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Ventilation Latent Heat Loss Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Ventilation Latent Heat Gain Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Outdoor Air Volume Flow Rate'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Surface Inside Face Conduction Heat Gain Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Surface Inside Face Conduction Heat Loss Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone People Sensible Heating Rate'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone People Sensible Heating Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone People Latent Heat Gain Rate'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone People Latent Heat Gain Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Lights Sensible Heating Rate'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Lights Sensible Heating Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Electric Equipment Sensible Heating Rate'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Electric Equipment Sensible Heating Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Electric Equipment Latent Heat Gain Rate'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Electric Equipment Latent Heat Gain Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Total Internal Sensible Heat Gain Rate'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Total Internal Sensible Heat Gain Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Total Internal Latent Heat Gain Rate'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Total Internal Latent Heat Gain Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Window Shading Control Status'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Surface Window Shading Device Transmitted Diffuse Solar Radiation Rate'}
#  {'frequency': 'Daily', 'key': '*', 'variable': 'Facility Total Electric Demand Power'}]
#   partial (object): []
#   coverage (float64): 58.46153846153847
# --------------------------------------------------------------------------------
#
# File #28
# Relative Path: parsed_data\relationships\equipment_assignments.parquet
# Shape: (70, 5) (rows: 70, columns: 5)
#
# First row data:
#   building_id (object): 4136733
#   equipment_name (object): Lights_ALL_ZONES
#   equipment_type (object): LIGHTS
#   assigned_zone (object): Zone1_FrontPerimeter
#   schedule (object): ALWAYS_ON
# --------------------------------------------------------------------------------
#
# File #29
# Relative Path: parsed_data\relationships\zone_mappings.parquet
# Shape: (19, 6) (rows: 19, columns: 6)
#
# First row data:
#   building_id (object): 4136733
#   idf_zone_name (object): Zone1_FrontPerimeter
#   sql_zone_name (object): ZONE1_FRONTPERIMETER
#   zone_type (object): None
#   multiplier (float64): nan
#   mapping_confidence (float64): 0.8
# --------------------------------------------------------------------------------
#
# File #30
# Relative Path: parsed_data\sql_results\schedules\all_schedules.parquet
# Shape: (39, 6) (rows: 39, columns: 6)
#
# First row data:
#   ScheduleIndex (int64): 1
#   ScheduleName (object): ALWAYS22C
#   ScheduleType (object): TEMPERATURE
#   ScheduleMinimum (float64): 22.0
#   ScheduleMaximum (float64): 22.0
#   building_id (object): 4136733
# --------------------------------------------------------------------------------
#
# File #31
# Relative Path: parsed_data\sql_results\summary_metrics\building_metrics.parquet
# Shape: (3, 21) (rows: 3, columns: 21)
#
# First row data:
#   building_id (object): 4136733
#   sql_file (object): /usr/src/app/output/2dae68d1-4b75-4c75-9471-7b6d931af865/Sim_Results/2020/simulation_bldg0_4136733.sql
#   extraction_date (object): 2025-06-23T18:29:20.126741
#   energyplus_version (object): EnergyPlus, Version 22.2.0-c249759bad, YMD=2025.06.23 18:29
#   simulation_timestamp (object):  YMD=2025.06.23 18:29
#   timesteps_per_hour (int64): 4
#   zone_count (int64): 10
#   total_floor_area (float64): 60.0
#   total_volume (float64): 180.0
#   total_heating_energy (float64): 70465950843.21967
#   avg_heating_power (float64): 489346880.85569215
#   peak_heating_power (float64): 5319407580.050322
#   total_cooling_energy (float64): 1834889569.8913205
#   avg_cooling_power (float64): 13900678.55978273
#   peak_cooling_power (float64): 189985221.11711425
#   total_water_heating_energy (float64): 12498381221.011944
#   avg_water_heating_power (float64): 1041531768.417662
#   peak_water_heating_power (float64): 1062031232.4982021
#   total_outputs_available (int64): 476
#   outputs_with_data (int64): 476
#   output_coverage (float64): 100.0
# --------------------------------------------------------------------------------
#
# File #32
# Relative Path: parsed_data\sql_results\summary_metrics\zone_metrics.parquet
# Shape: (3, 11) (rows: 3, columns: 11)
#
# First row data:
#   building_id (object): 4136733
#   zone_name (object): ZONE2_CORE
#   floor_area (float64): 0.49058623521244726
#   volume (float64): 1.4717587056373418
#   heating_energy (float64): 3965.7405350979134
#   heating_peak_power (float64): 3744.725608696884
#   cooling_energy (float64): 19110358.184373673
#   cooling_peak_power (float64): 2035290.5544151966
#   avg_temperature (float64): 18.395834832659858
#   min_temperature (float64): 16.219110421074685
#   max_temperature (float64): 22.25151897458584
# --------------------------------------------------------------------------------
#
# File #33
# Relative Path: parsed_data\sql_results\timeseries\aggregated\daily\hvac_daily.parquet
# Shape: (27805, 6) (rows: 27805, columns: 6)
#
# First row data:
#   building_id (object): 4136733
#   Zone (object): MYDHW_0_WATERHEATER
#   Variable (object): Water Heater Heating Energy
#   DateTime (datetime64[ns]): 2013-02-01 00:00:00
#   TimeIndex (float64): 32.0
#   Value (float64): 1059503368.855152
# --------------------------------------------------------------------------------
#
# File #34
# Relative Path: parsed_data\sql_results\timeseries\aggregated\daily\ventilation_daily.parquet
# Shape: (42210, 6) (rows: 42210, columns: 6)
#
# First row data:
#   building_id (object): 4136733
#   Zone (object): ZONE1_CORE
#   Variable (object): Zone Mechanical Ventilation Mass Flow Rate
#   DateTime (datetime64[ns]): 2013-02-01 00:00:00
#   TimeIndex (float64): 32.0
#   Value (float64): 0.00018028260985619395
# --------------------------------------------------------------------------------
#
# File #35
# Relative Path: parsed_data\sql_results\timeseries\aggregated\daily\zones_daily.parquet
# Shape: (143045, 6) (rows: 143045, columns: 6)
#
# First row data:
#   building_id (object): 4136733
#   Zone (object): ZONE1_CORE
#   Variable (object): Zone Mean Air Temperature
#   DateTime (datetime64[ns]): 2013-02-01 00:00:00
#   TimeIndex (float64): 32.0
#   Value (float64): 18.05311368414512
# --------------------------------------------------------------------------------
#
# File #36
# Relative Path: parsed_data\sql_results\timeseries\aggregated\monthly\hvac_monthly.parquet
# Shape: (996, 6) (rows: 996, columns: 6)
#
# First row data:
#   building_id (object): 4136733
#   Zone (object): MYDHW_0_WATERHEATER
#   Variable (object): Water Heater Heating Energy
#   DateTime (datetime64[ns]): 2013-02-28 00:00:00
#   TimeIndex (float64): 32.0
#   Value (float64): 1059503368.855152
# --------------------------------------------------------------------------------
#
# File #37
# Relative Path: parsed_data\sql_results\timeseries\aggregated\monthly\ventilation_monthly.parquet
# Shape: (1512, 6) (rows: 1512, columns: 6)
#
# First row data:
#   building_id (object): 4136733
#   Zone (object): ZONE1_CORE
#   Variable (object): Zone Mechanical Ventilation Mass Flow Rate
#   DateTime (datetime64[ns]): 2013-02-28 00:00:00
#   TimeIndex (float64): 32.0
#   Value (float64): 0.00018028260985619395
# --------------------------------------------------------------------------------
#
# File #38
# Relative Path: parsed_data\sql_results\timeseries\aggregated\monthly\zones_monthly.parquet
# Shape: (5124, 6) (rows: 5124, columns: 6)
#
# First row data:
#   building_id (object): 4136733
#   Zone (object): ZONE1_CORE
#   Variable (object): Zone Mean Air Temperature
#   DateTime (datetime64[ns]): 2013-02-28 00:00:00
#   TimeIndex (float64): 32.0
#   Value (float64): 18.05311368414512
# --------------------------------------------------------------------------------
#
# File #39
# Relative Path: parsed_data\sql_results\timeseries\hourly\hvac_2013.parquet
# Shape: (996, 9) (rows: 996, columns: 9)
#
# First row data:
#   TimeIndex (int64): 32
#   DateTime (datetime64[ns]): 2013-02-01 00:00:00
#   Variable (object): Water Heater Heating Energy
#   Zone (object): MYDHW_0_WATERHEATER
#   Value (float64): 1059503368.855152
#   Units (object): J
#   ReportingFrequency (object): Monthly
#   IDF_Zone (object): MYDHW_0_WATERHEATER
#   building_id (object): 4136733
# --------------------------------------------------------------------------------
#
# File #40
# Relative Path: parsed_data\sql_results\timeseries\hourly\ventilation_2013.parquet
# Shape: (1512, 9) (rows: 1512, columns: 9)
#
# First row data:
#   TimeIndex (int64): 32
#   DateTime (datetime64[ns]): 2013-02-01 00:00:00
#   Variable (object): Zone Mechanical Ventilation Mass Flow Rate
#   Zone (object): ZONE1_FRONTPERIMETER
#   Value (float64): 0.0031372884410621592
#   Units (object): kg/s
#   ReportingFrequency (object): Monthly
#   IDF_Zone (object): Zone1_FrontPerimeter
#   building_id (object): 4136733
# --------------------------------------------------------------------------------
#
# File #41
# Relative Path: parsed_data\sql_results\timeseries\hourly\zones_2013.parquet
# Shape: (5124, 9) (rows: 5124, columns: 9)
#
# First row data:
#   TimeIndex (int64): 32
#   DateTime (datetime64[ns]): 2013-02-01 00:00:00
#   Variable (object): Zone Mean Air Temperature
#   Zone (object): ZONE1_FRONTPERIMETER
#   Value (float64): 18.082957949601642
#   Units (object): C
#   ReportingFrequency (object): Monthly
#   IDF_Zone (object): Zone1_FrontPerimeter
#   building_id (object): 4136733
# --------------------------------------------------------------------------------
#
# File #42
# Relative Path: parsed_modified_results\analysis_ready\parameter_matrix.parquet
# Shape: (3, 7) (rows: 3, columns: 7)
#
# First row data:
#   building_id (object): building_4136733_variant_0
#   ventilation_design_flow_rate (object): None
#   infiltration_design_flow_rate (object): 2.900821e-04
#   lighting_watts_per_zone_floor_area (object): 0
#   equipment_watts_per_zone_floor_area (object): 0
#   dhw_tank_volume (object): 0.2775029318369119
#   dhw_heater_maximum_capacity (object): 4223.210738148823
# --------------------------------------------------------------------------------
#
# File #43
# Relative Path: parsed_modified_results\analysis_ready\feature_sets\extraction_statistics.parquet
# Shape: (1, 6) (rows: 1, columns: 6)
#
# First row data:
#   building_id (object): 4136738
#   extraction_date (object): 2025-06-23T18:30:20.004546
#   categories_processed (int64): 7
#   variables_extracted (int64): 28
#   data_points_extracted (int64): 660
#   missing_variables_count (int64): 76
# --------------------------------------------------------------------------------
#
# File #44
# Relative Path: parsed_modified_results\analysis_ready\feature_sets\missing_variables_detail.parquet
# Shape: (76, 3) (rows: 76, columns: 3)
#
# First row data:
#   category (object): geometry
#   variable (object): Zone Air Temperature
#   building_id (object): 4136738
# --------------------------------------------------------------------------------
#
# File #45
# Relative Path: parsed_modified_results\idf_data\by_building\building_4136733_variant_0_snapshot.parquet
# Shape: (293, 7) (rows: 293, columns: 7)
#
# First row data:
#   building_id (object): building_4136733_variant_0
#   category (object): simulation_control
#   output_file (object): simulation_control
#   object_type (object): Version
#   object_name (object): 22.2
#   parameters (object): {"Version Identifier": "22.2"}
#   zone_name (object): None
# --------------------------------------------------------------------------------
#
# File #46
# Relative Path: parsed_modified_results\idf_data\by_building\building_4136737_variant_0_snapshot.parquet
# Shape: (216, 7) (rows: 216, columns: 7)
#
# First row data:
#   building_id (object): building_4136737_variant_0
#   category (object): simulation_control
#   output_file (object): simulation_control
#   object_type (object): Version
#   object_name (object): 22.2
#   parameters (object): {"Version Identifier": "22.2"}
#   zone_name (object): None
# --------------------------------------------------------------------------------
#
# File #47
# Relative Path: parsed_modified_results\idf_data\by_building\building_4136738_variant_0_snapshot.parquet
# Shape: (156, 7) (rows: 156, columns: 7)
#
# First row data:
#   building_id (object): building_4136738_variant_0
# ...
#   wetbulb_or_dewpoint_at_maximum_dry_bulb (object): None
#   wetbulb_or_dewpoint_at_maximum_dry_bulb_numeric (float64): nan
#   barometric_pressure (object): None
#   barometric_pressure_numeric (float64): nan
#   wind_speed (object): None
#   wind_speed_numeric (float64): nan
#   wind_direction (object): None
#   wind_direction_numeric (float64): nan
#   rain_indicator (object): None
#   snow_indicator (object): None
#   daylight_saving_time_indicator (object): None
#   solar_model_indicator (object): None
#   sky_clearness (object): None
#   sky_clearness_numeric (float64): nan
# --------------------------------------------------------------------------------
#
# File #65
# Relative Path: parsed_modified_results\idf_data\by_category\ventilation.parquet
# Shape: (12, 53) (rows: 12, columns: 53)
#
# First row data:
#   building_id (object): building_4136733_variant_0
#   object_type (object): DESIGNSPECIFICATION:OUTDOORAIR
#   object_name (object): DSOA_Global
#   name (object): DSOA_Global
#   outdoor_air_method (object): Sum
#   outdoor_air_flow_per_person (object): 0.0025
#   outdoor_air_flow_per_person_numeric (float64): 0.0025
#   outdoor_air_flow_per_zone_floor_area (object): 0.0003
#   outdoor_air_flow_per_zone_floor_area_numeric (float64): 0.0003
#   outdoor_air_flow_per_zone (object): 0
#   outdoor_air_flow_per_zone_numeric (float64): 0.0
#   outdoor_air_flow_air_changes_per_hour (object): 0
#   outdoor_air_flow_air_changes_per_hour_numeric (float64): 0.0
#   field_1 (object): None
#   field_2 (object): None
#   field_2_numeric (float64): nan
#   field_3 (object): None
#   field_3_numeric (float64): nan
#   field_5 (object): None
#   field_5_numeric (float64): nan
#   field_6 (object): None
#   field_6_numeric (float64): nan
#   zone_name (object): None
#   zone_or_zonelist_name (object): None
#   schedule_name (object): None
#   design_flow_rate_calculation_method (object): None
#   design_flow_rate (object): None
#   design_flow_rate_numeric (float64): nan
#   ventilation_type (object): None
#   fan_pressure_rise (object): None
#   fan_pressure_rise_numeric (float64): nan
#   fan_total_efficiency (object): None
#   fan_total_efficiency_numeric (float64): nan
#   constant_term_coefficient (object): None
#   constant_term_coefficient_numeric (float64): nan
#   temperature_term_coefficient (object): None
#   temperature_term_coefficient_numeric (float64): nan
#   velocity_term_coefficient (object): None
#   velocity_term_coefficient_numeric (float64): nan
#   velocity_squared_term_coefficient (object): None
#   velocity_squared_term_coefficient_numeric (float64): nan
#   minimum_indoor_temperature (object): None
#   minimum_indoor_temperature_numeric (float64): nan
#   maximum_indoor_temperature (object): None
#   maximum_indoor_temperature_numeric (float64): nan
#   delta_temperature (object): None
#   delta_temperature_numeric (float64): nan
#   minimum_outdoor_temperature (object): None
#   minimum_outdoor_temperature_numeric (float64): nan
#   maximum_outdoor_temperature (object): None
#   maximum_outdoor_temperature_numeric (float64): nan
#   maximum_wind_speed (object): None
#   maximum_wind_speed_numeric (float64): nan
# --------------------------------------------------------------------------------
#
# File #66
# Relative Path: parsed_modified_results\metadata\building_registry.parquet
# Shape: (9, 9) (rows: 9, columns: 9)
#
# First row data:
#   building_id (object): 4136733
#   ogc_fid (object): 4136733
#   idf_path (object): /usr/src/app/output/2dae68d1-4b75-4c75-9471-7b6d931af865/modified_idfs/building_4136733_variant_0.idf
#   sql_path (object): /usr/src/app/output/2dae68d1-4b75-4c75-9471-7b6d931af865/Modified_Sim_Results/2020/simulation_bldg0_4136733.sql
#   zone_count (int64): 10
#   output_variables (int64): 65
#   output_meters (int64): 7
#   status (object): completed
#   last_modified (datetime64[ns]): 2025-06-23 18:29:49.674426
# --------------------------------------------------------------------------------
#
# File #67
# Relative Path: parsed_modified_results\metadata\missing_outputs.parquet
# Shape: (213, 4) (rows: 213, columns: 4)
#
# First row data:
#   variable (object): Boiler Heating Energy
#   key (object): *
#   frequency (object): Monthly
#   building_id (object): 4136733
# --------------------------------------------------------------------------------
#
# File #68
# Relative Path: parsed_modified_results\metadata\output_validation.parquet
# Shape: (9, 6) (rows: 9, columns: 6)
#
# First row data:
#   building_id (object): 4136733
#   total_requested (int64): 65
#   found (int64): 38
#   missing (object): [{'frequency': 'Monthly', 'key': '*', 'variable': 'Boiler Heating Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Air System Latent Cooling Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Ventilation Standard Density Volume Flow Rate'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Ventilation Sensible Heat Loss Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Ventilation Sensible Heat Gain Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Ventilation Latent Heat Loss Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Ventilation Latent Heat Gain Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Outdoor Air Volume Flow Rate'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Surface Inside Face Conduction Heat Gain Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Surface Inside Face Conduction Heat Loss Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone People Sensible Heating Rate'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone People Sensible Heating Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone People Latent Heat Gain Rate'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone People Latent Heat Gain Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Lights Sensible Heating Rate'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Lights Sensible Heating Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Electric Equipment Sensible Heating Rate'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Electric Equipment Sensible Heating Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Electric Equipment Latent Heat Gain Rate'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Electric Equipment Latent Heat Gain Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Total Internal Sensible Heat Gain Rate'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Total Internal Sensible Heat Gain Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Total Internal Latent Heat Gain Rate'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Zone Total Internal Latent Heat Gain Energy'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Window Shading Control Status'}
#  {'frequency': 'Monthly', 'key': '*', 'variable': 'Surface Window Shading Device Transmitted Diffuse Solar Radiation Rate'}
#  {'frequency': 'Daily', 'key': '*', 'variable': 'Facility Total Electric Demand Power'}]
#   partial (object): []
#   coverage (float64): 58.46153846153847
# --------------------------------------------------------------------------------
#
# File #69
# Relative Path: parsed_modified_results\relationships\equipment_assignments.parquet
# Shape: (70, 5) (rows: 70, columns: 5)
#
# First row data:
#   building_id (object): building_4136733_variant_0
#   equipment_name (object): Lights_ALL_ZONES
#   equipment_type (object): LIGHTS
#   assigned_zone (object): Zone1_FrontPerimeter
#   schedule (object): ALWAYS_ON
# --------------------------------------------------------------------------------
#
# File #70
# Relative Path: parsed_modified_results\relationships\zone_mappings.parquet
# Shape: (35, 6) (rows: 35, columns: 6)
#
# First row data:
#   building_id (object): building_4136733_variant_0
#   idf_zone_name (object): Zone1_FrontPerimeter
#   sql_zone_name (object): ZONE1_FRONTPERIMETER
#   zone_type (object): Perimeter
#   multiplier (float64): 1.0
#   mapping_confidence (float64): nan
# --------------------------------------------------------------------------------
#
# File #71
# Relative Path: parsed_modified_results\sql_results\schedules\all_schedules.parquet
# Shape: (39, 6) (rows: 39, columns: 6)
#
# First row data:
#   ScheduleIndex (int64): 1
#   ScheduleName (object): ALWAYS22C
#   ScheduleType (object): TEMPERATURE
#   ScheduleMinimum (float64): 22.0
#   ScheduleMaximum (float64): 22.0
#   building_id (object): 4136733
# --------------------------------------------------------------------------------
#
# File #72
# Relative Path: parsed_modified_results\sql_results\summary_metrics\building_metrics.parquet
# Shape: (3, 21) (rows: 3, columns: 21)
#
# First row data:
#   building_id (object): 4136733
#   sql_file (object): /usr/src/app/output/2dae68d1-4b75-4c75-9471-7b6d931af865/Modified_Sim_Results/2020/simulation_bldg2_4136733.sql
#   extraction_date (object): 2025-06-23T18:29:57.243842
#   energyplus_version (object): EnergyPlus, Version 22.2.0-c249759bad, YMD=2025.06.23 18:29
#   simulation_timestamp (object):  YMD=2025.06.23 18:29
#   timesteps_per_hour (int64): 6
#   zone_count (int64): 10
#   total_floor_area (float64): 60.0
#   total_volume (float64): 180.0
#   total_heating_energy (float64): 48342160345.12939
#   avg_heating_power (float64): 335709446.8411763
#   peak_heating_power (float64): 3941013537.7375417
#   total_cooling_energy (float64): 5563188726.391966
#   avg_cooling_power (float64): 42145369.13933308
#   peak_cooling_power (float64): 524331525.2913948
#   total_water_heating_energy (float64): 10976486965.940071
#   avg_water_heating_power (float64): 914707247.1616726
#   peak_water_heating_power (float64): 934186222.4803627
#   total_outputs_available (int64): 476
#   outputs_with_data (int64): 476
#   output_coverage (float64): 100.0
# --------------------------------------------------------------------------------
#
# File #73
# Relative Path: parsed_modified_results\sql_results\summary_metrics\zone_metrics.parquet
# Shape: (3, 11) (rows: 3, columns: 11)
#
# First row data:
#   building_id (object): 4136733
#   zone_name (object): ZONE2_CORE
#   floor_area (float64): 0.49058623521244726
#   volume (float64): 1.4717587056373418
#   heating_energy (float64): 0.0
#   heating_peak_power (float64): 0.0
#   cooling_energy (float64): 38882385.60361744
#   cooling_peak_power (float64): 5590736.456576329
#   avg_temperature (float64): 20.32551550587339
#   min_temperature (float64): 16.723264010398157
#   max_temperature (float64): 25.77544953670956
# --------------------------------------------------------------------------------
#
# File #74
# Relative Path: parsed_modified_results\sql_results\timeseries\aggregated\daily\hvac_daily.parquet
# Shape: (27805, 6) (rows: 27805, columns: 6)
#
# First row data:
#   building_id (object): 4136733
#   Zone (object): MYDHW_0_WATERHEATER
#   Variable (object): Water Heater Heating Energy
#   DateTime (datetime64[ns]): 2013-02-01 00:00:00
#   TimeIndex (float64): 32.0
#   Value (float64): 931723138.7617693
# --------------------------------------------------------------------------------
#
# File #75
# Relative Path: parsed_modified_results\sql_results\timeseries\aggregated\daily\ventilation_daily.parquet
# Shape: (42210, 6) (rows: 42210, columns: 6)
#
# First row data:
#   building_id (object): 4136733
#   Zone (object): ZONE1_CORE
#   Variable (object): Zone Mechanical Ventilation Mass Flow Rate
#   DateTime (datetime64[ns]): 2013-02-01 00:00:00
#   TimeIndex (float64): 32.0
#   Value (float64): 0.0001773271572355944
# --------------------------------------------------------------------------------
#
# File #76
# Relative Path: parsed_modified_results\sql_results\timeseries\aggregated\daily\zones_daily.parquet
# Shape: (143045, 6) (rows: 143045, columns: 6)
#
# First row data:
#   building_id (object): 4136733
#   Zone (object): ZONE1_CORE
#   Variable (object): Zone Mean Air Temperature
#   DateTime (datetime64[ns]): 2013-02-01 00:00:00
#   TimeIndex (float64): 32.0
#   Value (float64): 15.485632002948556
# --------------------------------------------------------------------------------
#
# File #77
# Relative Path: parsed_modified_results\sql_results\timeseries\aggregated\monthly\hvac_monthly.parquet
# Shape: (996, 6) (rows: 996, columns: 6)
#
# First row data:
#   building_id (object): 4136733
#   Zone (object): MYDHW_0_WATERHEATER
#   Variable (object): Water Heater Heating Energy
#   DateTime (datetime64[ns]): 2013-02-28 00:00:00
#   TimeIndex (float64): 32.0
#   Value (float64): 931723138.7617693
# --------------------------------------------------------------------------------
#
# File #78
# Relative Path: parsed_modified_results\sql_results\timeseries\aggregated\monthly\ventilation_monthly.parquet
# Shape: (1512, 6) (rows: 1512, columns: 6)
#
# First row data:
#   building_id (object): 4136733
#   Zone (object): ZONE1_CORE
#   Variable (object): Zone Mechanical Ventilation Mass Flow Rate
#   DateTime (datetime64[ns]): 2013-02-28 00:00:00
#   TimeIndex (float64): 32.0
#   Value (float64): 0.0001773271572355944
# --------------------------------------------------------------------------------
#
# File #79
# Relative Path: parsed_modified_results\sql_results\timeseries\aggregated\monthly\zones_monthly.parquet
# Shape: (5124, 6) (rows: 5124, columns: 6)
#
# First row data:
#   building_id (object): 4136733
#   Zone (object): ZONE1_CORE
#   Variable (object): Zone Mean Air Temperature
#   DateTime (datetime64[ns]): 2013-02-28 00:00:00
#   TimeIndex (float64): 32.0
#   Value (float64): 15.485632002948556
# --------------------------------------------------------------------------------
#
# File #80
# Relative Path: parsed_modified_results\sql_results\timeseries\hourly\hvac_2013.parquet
# Shape: (996, 9) (rows: 996, columns: 9)
#
# First row data:
#   TimeIndex (int64): 32
#   DateTime (datetime64[ns]): 2013-02-01 00:00:00
#   Variable (object): Water Heater Heating Energy
#   Zone (object): MYDHW_0_WATERHEATER
#   Value (float64): 931723138.7617693
#   Units (object): J
#   ReportingFrequency (object): Monthly
#   IDF_Zone (object): MYDHW_0_WATERHEATER
#   building_id (object): 4136733
# --------------------------------------------------------------------------------
#
# File #81
# Relative Path: parsed_modified_results\sql_results\timeseries\hourly\ventilation_2013.parquet
# Shape: (1512, 9) (rows: 1512, columns: 9)
#
# First row data:
#   TimeIndex (int64): 32
#   DateTime (datetime64[ns]): 2013-02-01 00:00:00
#   Variable (object): Zone Mechanical Ventilation Mass Flow Rate
#   Zone (object): ZONE1_FRONTPERIMETER
#   Value (float64): 0.003085857483011965
#   Units (object): kg/s
#   ReportingFrequency (object): Monthly
#   IDF_Zone (object): Zone1_FrontPerimeter
#   building_id (object): 4136733
# --------------------------------------------------------------------------------
#
# File #82
# Relative Path: parsed_modified_results\sql_results\timeseries\hourly\zones_2013.parquet
# Shape: (5124, 9) (rows: 5124, columns: 9)
#
# First row data:
#   TimeIndex (int64): 32
#   DateTime (datetime64[ns]): 2013-02-01 00:00:00
#   Variable (object): Zone Mean Air Temperature
#   Zone (object): ZONE1_FRONTPERIMETER
#   Value (float64): 18.185341331465718
#   Units (object): C
#   ReportingFrequency (object): Monthly
#   IDF_Zone (object): Zone1_FrontPerimeter
#   building_id (object): 4136733
# --------------------------------------------------------------------------------
#
# File #83
# Relative Path: sensitivity_results\modification_sensitivity_results.parquet
# Shape: (688, 18) (rows: 688, columns: 18)
#
# First row data:
#   level (object): building
#   parameter (object): param_mean
#   category (object): param
#   output_variable (object): Zone Air System Sensible Heating Energy
#   sensitivity_score (float64): 18907693196.31405
#   p_value (float64): 0.1
#   ci_lower (float64): 15126154557.051239
#   ci_upper (float64): 22689231835.57686
#   n_samples (int64): 1
#   elasticity (float64): 18907693196.31405
#   r_squared (float64): 1.0
#   zone_name (object): None
#   building_id (object): None
#   interaction_type (object): None
#   avg_zone_param_change (float64): nan
#   avg_output_change (float64): nan
#   significance (object):
#   confidence_level (object): low
# --------------------------------------------------------------------------------
#
# Total parquet files found: 83
#
#
# === DETAILED PARQUET FILE EXPLORER ===
